# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from scipy.constants import h, k, atomic_mass, hbar
from scipy.integrate import odeint
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

import warnings
from sklearn.exceptions import ConvergenceWarning

warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %%
# Constants
m = 87 * atomic_mass  # Mass of Rb-87
kb = k  # Boltzmann constant
a_s = 5.77e-9  # Scattering length for Rb-87 (m)
lambda_laser = 1064e-9  # Wavelength of trapping laser (m)

# Simulation parameters
N_initial = 2.7e5  # Initial number of atoms (from paper)
T_initial = 20e-6  # Initial temperature (K), estimate
time_step = 1e-3  # Time step for simulation (s)
total_time = 0.575  # Total simulation time (s), matching paper

# Noise parameters
hardware_noise_level = 0.02
environmental_noise_level = 0.01

# Define the parameter space for optimization
param_space = {
    'P_y': (1e-3, 3),  # Horizontal trap power (W)
    'P_z': (1e-3, 3),  # Vertical trap power (W)
    'P_R': (1e-6, 1e-2),  # Raman coupling power (W)
    'P_p': (1e-6, 1e-2),  # Optical pumping power (W)
    'B_z': (0, 1e-3),  # Magnetic field (T)
    'trap_freq_x': (1, 1e3),  # Trap frequency in x-direction (Hz)
    'trap_freq_y': (1, 1e3),  # Trap frequency in y-direction (Hz)
    'trap_freq_z': (1, 1e3),  # Trap frequency in z-direction (Hz)
    'loading_rate': (0, 1e6)  # Loading rate (atoms/s)
}

# %%
def safe_log(x):
    """Safely compute logarithm, avoiding domain errors."""
    return np.log(np.maximum(x, 1e-10))

def trap_potential(r, P_y, P_z, trap_freq_x, trap_freq_y, trap_freq_z):
    """Calculate the trapping potential."""
    w_x = np.sqrt(2 * hbar / (m * 2 * np.pi * trap_freq_x))
    w_y = np.sqrt(2 * hbar / (m * 2 * np.pi * trap_freq_y))
    w_z = np.sqrt(2 * hbar / (m * 2 * np.pi * trap_freq_z))
    
    return 0.5 * m * (
        (2 * np.pi * trap_freq_x)**2 * r[0]**2 +
        (2 * np.pi * trap_freq_y)**2 * r[1]**2 +
        (2 * np.pi * trap_freq_z)**2 * r[2]**2
    )

def raman_cooling_rate(v, P_R, P_p, B_z):
    """Calculate the Raman cooling rate."""
    v_r = hbar * 2 * np.pi / (m * lambda_laser)
    gamma_r = 2 * np.pi * 6.065e6
    delta = 2 * np.pi * 4.33e9
    
    return gamma_r * (P_R + P_p) / (1 + (2 * v / v_r)**2 + (2 * delta / gamma_r)**2) * np.exp(-v**2 / v_r**2)

def collision_rate(n, T):
    """Calculate the collision rate."""
    sigma = 8 * np.pi * a_s**2
    v_rms = np.sqrt(3 * kb * T / m)
    return n * sigma * v_rms

def bec_fraction(N, T, trap_freq_x, trap_freq_y, trap_freq_z):
    """Calculate the BEC fraction."""
    omega_bar = (trap_freq_x * trap_freq_y * trap_freq_z)**(1/3) * 2 * np.pi
    T_c = 0.94 * hbar * omega_bar * (N / zeta(3))**(1/3) / kb
    return max(0, 1 - (T / T_c)**3) if T < T_c else 0

def zeta(x):
    """Riemann zeta function."""
    return np.sum(1 / np.arange(1, 1000)**x)

def system_dynamics(y, t, params):
    N, T = y
    P_y, P_z, P_R, P_p, B_z, trap_freq_x, trap_freq_y, trap_freq_z, loading_rate = params
    
    # Ensure positive values
    N = max(N, 1e-10)
    T = max(T, 1e-10)
    
    # Calculate trap properties
    omega_bar = (trap_freq_x * trap_freq_y * trap_freq_z)**(1/3) * 2 * np.pi
    V_eff = (2 * np.pi * kb * T / (m * omega_bar**2))**(3/2)
    n = N / V_eff
    
    # Calculate rates
    gamma_col = collision_rate(n, T)
    gamma_cool = raman_cooling_rate(np.sqrt(3 * kb * T / m), P_R, P_p, B_z)
    gamma_heat = 1e-3 * (P_y + P_z)
    gamma_loss = 1e-2 * np.exp(-safe_log(P_y + P_z) + safe_log(kb * T))
    
    # System dynamics
    dNdt = loading_rate - gamma_loss * N
    dTdt = gamma_heat - gamma_cool * T + (gamma_col / 3) * (hbar * omega_bar / kb - T)
    
    return [dNdt, dTdt]

def simulate_bec(params, t):
    try:
        # Add hardware noise
        params_with_noise = [max(p * (1 + np.random.normal(0, hardware_noise_level)), 1e-10) for p in params]
        
        # Solve ODE
        y0 = [N_initial, T_initial]
        solution = odeint(system_dynamics, y0, [0, t], args=(params_with_noise,))
        
        N, T = solution[-1]
        
        # Add environmental noise
        N = max(N * (1 + np.random.normal(0, environmental_noise_level)), 1e-10)
        T = max(T * (1 + np.random.normal(0, environmental_noise_level)), 1e-10)
        
        # Calculate phase space density
        omega_bar = (params[5] * params[6] * params[7])**(1/3) * 2 * np.pi
        V_eff = (2 * np.pi * kb * T / (m * omega_bar**2))**(3/2)
        n = N / V_eff
        lambda_dB = h / np.sqrt(2 * np.pi * m * kb * T)
        PSD = n * lambda_dB**3
        
        # Calculate BEC fraction
        f_bec = bec_fraction(N, T, params[5], params[6], params[7])
        
        return N, T, PSD, f_bec
    except Exception as e:
        print(f"Error in simulate_bec: {e}")
        return 1e-10, 1e-10, 1e-10, 0

# %%
def objective_function(params, alpha):
    try:
        N, T, PSD, f_bec = simulate_bec(params, total_time)
        
        # Calculate optical depth (simplified model)
        OD = N**(2/5) / T
        
        # Cost function (to be minimized)
        cost = -(OD**3 * N**(alpha - 9/5))
        
        return cost if np.isfinite(cost) else 1e10
    except Exception as e:
        print(f"Error in objective_function: {e}")
        return 1e10

# %%
def generate_od_image(N, T, f_bec, trap_freq_x, trap_freq_y, trap_freq_z, image_size=128, tof=0.025):
    """Generate a simulated optical density (OD) image of the BEC and thermal cloud."""
    N_bec = N * f_bec
    N_thermal = N - N_bec
    
    # Calculate cloud sizes after time of flight
    omega_bar = (trap_freq_x * trap_freq_y * trap_freq_z)**(1/3) * 2 * np.pi
    R_tf = (15 * N_bec * a_s * hbar**2 / (m**2 * omega_bar**2))**(1/5)  # Thomas-Fermi radius
    sigma_thermal = np.sqrt(kb * T / (m * omega_bar**2))
    
    x = np.linspace(-3*R_tf, 3*R_tf, image_size)
    y = np.linspace(-3*R_tf, 3*R_tf, image_size)
    X, Y = np.meshgrid(x, y)
    R = np.sqrt(X**2 + Y**2)
    
    # BEC component (Thomas-Fermi profile)
    od_bec = np.maximum(0, (1 - (R / R_tf)**2))**(3/2)
    od_bec *= N_bec / np.sum(od_bec)  # Normalize
    
    # Thermal component (Gaussian profile)
    od_thermal = np.exp(-(X**2 + Y**2) / (2 * sigma_thermal**2))
    od_thermal *= N_thermal / np.sum(od_thermal)  # Normalize
    
    # Combine BEC and thermal components
    od_total = od_bec + od_thermal
    
    return od_total

# %%
def bayesian_optimization(n_iterations=100, n_images=5, alpha=0.5):
    def obj_wrapper(x):
        return objective_function(x.flatten(), alpha)
    
    bounds = np.array(list(param_space.values()))
    n_params = len(bounds)
    
    kernel = C(1.0, (1e-3, 1e3)) * RBF(np.ones(n_params), (1e-3, 1e3))
    gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10, alpha=1e-6)
    
    X_sample = np.random.uniform(bounds[:, 0], bounds[:, 1], size=(10, n_params))
    y_sample = np.array([obj_wrapper(x) for x in X_sample])
    
    best_params = X_sample[np.argmin(y_sample)]
    best_images = []
    best_N_list = []
    best_T_list = []
    best_PSD_list = []
    best_f_bec_list = []
    
    all_costs = []
    all_N = []
    all_T = []
    all_f_bec = []
    
    image_indices = [0, n_iterations // 4, n_iterations // 2, 3 * n_iterations // 4, n_iterations - 1]
    
    for i in range(n_iterations):
        print(f"Running {i}th iteration of Bayesian optimization (alpha={alpha})...")
        try:
            gp.fit(X_sample, y_sample)
            
            def acquisition(x):
                mean, std = gp.predict(x.reshape(1, -1), return_std=True)
                return mean - 1.96 * std
            
            result = minimize(acquisition, X_sample[np.argmin(y_sample)], method='L-BFGS-B', bounds=bounds)
            
            if result.success:
                X_next = result.x
            else:
                X_next = np.random.uniform(bounds[:, 0], bounds[:, 1], size=(1, n_params))
            
            y_next = obj_wrapper(X_next)
            
            X_sample = np.vstack((X_sample, X_next))
            y_sample = np.append(y_sample, y_next)
            
            best_cost = np.min(y_sample)
            best_params = X_sample[np.argmin(y_sample)]
            
            N, T, PSD, f_bec = simulate_bec(best_params, total_time)
            all_costs.append(-best_cost)
            all_N.append(N)
            all_T.append(T)
            all_f_bec.append(f_bec)
            
            if i in image_indices:
                od_image = generate_od_image(N, T, f_bec, best_params[5], best_params[6], best_params[7])
                best_images.append(od_image)
                best_N_list.append(N)
                best_T_list.append(T)
                best_PSD_list.append(PSD)
                best_f_bec_list.append(f_bec)
        
        except Exception as e:
            print(f"Error in iteration {i}: {e}")
            continue
    
    return best_params, best_images, best_N_list, best_T_list, best_PSD_list, best_f_bec_list, all_costs, all_N, all_T, all_f_bec

# %%
def plot_optimization_performance(all_costs, all_N, all_T, all_f_bec, alpha):
    fig, axs = plt.subplots(2, 2, figsize=(15, 15))
    iterations = range(1, len(all_costs) + 1)
    
    axs[0, 0].plot(iterations, all_costs)
    axs[0, 0].set_xlabel('Iteration')
    axs[0, 0].set_ylabel('Objective Function (maximization)')
    axs[0, 0].set_title(f'Optimization Progress (α = {alpha})')
    
    axs[0, 1].semilogy(iterations, all_N)
    axs[0, 1].set_xlabel('Iteration')
    axs[0, 1].set_ylabel('Atom Number')
    axs[0, 1].set_title(f'Atom Number Evolution (α = {alpha})')
    
    axs[1, 0].semilogy(iterations, all_T)
    axs[1, 0].set_xlabel('Iteration')
    axs[1, 0].set_ylabel('Temperature (K)')
    axs[1, 0].set_title(f'Temperature Evolution (α = {alpha})')
    
    axs[1, 1].plot(iterations, all_f_bec)
    axs[1, 1].set_xlabel('Iteration')
    axs[1, 1].set_ylabel('BEC Fraction')
    axs[1, 1].set_title(f'BEC Fraction Evolution (α = {alpha})')
    
    plt.tight_layout()
    plt.show()

# %%
def plot_optimization_images(images, N_list, T_list, PSD_list, f_bec_list, n_iterations, alpha):
    n_images = len(images)
    fig, axs = plt.subplots(2, 3, figsize=(18, 12))
    axs = axs.ravel()
    
    for i, (image, N, T, PSD, f_bec) in enumerate(zip(images, N_list, T_list, PSD_list, f_bec_list)):
        if i < n_images:
            im = axs[i].imshow(image, cmap='jet', extent=[-128, 128, -128, 128])
            iteration = [0, n_iterations // 4, n_iterations // 2, 3 * n_iterations // 4, n_iterations - 1][i]
            axs[i].set_title(f"Iteration {iteration}")
            axs[i].set_xlabel('Position (μm)')
            axs[i].set_ylabel('Position (μm)')
            plt.colorbar(im, ax=axs[i], label='Optical Density')
            
            axs[i].text(0.05, 0.95, f"N: {N:.2e}\nT: {T:.2e} K\nPSD: {PSD:.2e}\nBEC: {f_bec:.2%}", 
                        transform=axs[i].transAxes, verticalalignment='top', 
                        bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))
    
    for i in range(n_images, 6):
        fig.delaxes(axs[i])
    
    fig.suptitle(f'Optimization Images (α = {alpha})', fontsize=16)
    plt.tight_layout()
    plt.show()

# %%
def run_simulation(optimized_params):
    time_points = np.arange(0, total_time + time_step, time_step)
    N_values = []
    T_values = []
    PSD_values = []
    f_bec_values = []
    
    for t in time_points:
        N, T, PSD, f_bec = simulate_bec(optimized_params, t)
        N_values.append(N)
        T_values.append(T)
        PSD_values.append(PSD)
        f_bec_values.append(f_bec)
    
    return time_points, N_values, T_values, PSD_values, f_bec_values

# %%
def plot_final_results(time_points, N_values, T_values, PSD_values, f_bec_values, optimized_params, alpha):
    fig, axs = plt.subplots(3, 2, figsize=(15, 20))
    
    axs[0, 0].semilogy(time_points * 1e3, N_values)
    axs[0, 0].set_ylabel('Atom Number')
    axs[0, 0].set_title(f'BEC Formation Dynamics (α = {alpha})')
    
    axs[1, 0].semilogy(time_points * 1e3, T_values)
    axs[1, 0].set_ylabel('Temperature (K)')
    
    axs[2, 0].semilogy(time_points * 1e3, PSD_values)
    axs[2, 0].set_ylabel('Phase Space Density')
    axs[2, 0].set_xlabel('Time (ms)')
    
    axs[0, 1].plot(time_points * 1e3, f_bec_values)
    axs[0, 1].set_ylabel('BEC Fraction')
    axs[0, 1].set_xlabel('Time (ms)')
    
    N_final, T_final = N_values[-1], T_values[-1]
    f_bec_final = f_bec_values[-1]
    trap_freq_x, trap_freq_y, trap_freq_z = optimized_params[5:8]
    
    od_image = generate_od_image(N_final, T_final, f_bec_final, trap_freq_x, trap_freq_y, trap_freq_z)
    im = axs[1, 1].imshow(od_image, cmap='jet', extent=[-128, 128, -128, 128])
    axs[1, 1].set_title(f'Final OD Image (α = {alpha})')
    axs[1, 1].set_xlabel('Position (μm)')
    axs[1, 1].set_ylabel('Position (μm)')
    plt.colorbar(im, ax=axs[1, 1], label='Optical Density')
    
    center_row = od_image[od_image.shape[0]//2, :]
    axs[2, 1].plot(np.linspace(-128, 128, len(center_row)), center_row)
    axs[2, 1].set_title(f'1D Cross-section of Final OD Image (α = {alpha})')
    axs[2, 1].set_xlabel('Position (μm)')
    axs[2, 1].set_ylabel('Optical Density')
    
    plt.tight_layout()
    plt.show()

# %%
def plot_od_comparison(all_results):
    plt.figure(figsize=(12, 8))
    
    colors = ['b', 'g', 'r']  # Colors for different alpha values
    for (alpha, results), color in zip(all_results.items(), colors):
        params = results['params']
        N, T, _, f_bec = simulate_bec(params, total_time)
        trap_freq_x, trap_freq_y, trap_freq_z = params[5:8]
        
        od_image = generate_od_image(N, T, f_bec, trap_freq_x, trap_freq_y, trap_freq_z)
        center_row = od_image[od_image.shape[0]//2, :]
        
        plt.plot(np.linspace(-128, 128, len(center_row)), center_row, color=color, label=f'α = {alpha}')
    
    plt.title('Comparison of OD Profiles for Different α Values')
    plt.xlabel('Position (μm)')
    plt.ylabel('Optical Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
alphas = [0.25, 0.5, 1.0]
n_iterations = 1000  # Reduced for demonstration, increase for better results
n_images = 5

all_results = {}

for alpha in alphas:
    print(f"\nRunning optimization for alpha = {alpha}")
    
    # Run Bayesian optimization
    print("Optimizing parameters...")
    optimized_params, evolution_images, best_N_list, best_T_list, best_PSD_list, best_f_bec_list, all_costs, all_N, all_T, all_f_bec = bayesian_optimization(n_iterations=n_iterations, n_images=n_images, alpha=alpha)
    
    # Store results
    all_results[alpha] = {
        'params': optimized_params,
        'images': evolution_images,
        'N_list': best_N_list,
        'T_list': best_T_list,
        'PSD_list': best_PSD_list,
        'f_bec_list': best_f_bec_list,
        'costs': all_costs,
        'N': all_N,
        'T': all_T,
        'f_bec': all_f_bec
    }
    
    print("Optimization complete. Plotting optimization performance...")
    plot_optimization_performance(all_costs, all_N, all_T, all_f_bec, alpha)
    
    print("Plotting optimization images...")
    plot_optimization_images(evolution_images, best_N_list, best_T_list, best_PSD_list, best_f_bec_list, n_iterations, alpha)
    
    print("Running final simulation...")
    time_points, N_values, T_values, PSD_values, f_bec_values = run_simulation(optimized_params)
    plot_final_results(time_points, N_values, T_values, PSD_values, f_bec_values, optimized_params, alpha)

    print(f"Final atom number: {N_values[-1]:.2e}")
    print(f"Final temperature: {T_values[-1]:.2e} K")
    print(f"Final phase space density: {PSD_values[-1]:.2e}")
    print(f"Final BEC fraction: {f_bec_values[-1]:.2%}")

    # Print optimized parameters
    param_names = list(param_space.keys())
    print("\nOptimized Parameters:")
    for name, value in zip(param_names, optimized_params):
        print(f"{name}: {value:.4e}")

# After generating all previous plots for each alpha, create the comparison plot
print("\nPlotting OD comparison for different alpha values...")
plot_od_comparison(all_results)
# Out:
# Running optimization for alpha = 0.25
# Optimizing parameters...
# Running 0th iteration of Bayesian optimization (alpha=0.25)...
# Running 1th iteration of Bayesian optimization (alpha=0.25)...
# Running 2th iteration of Bayesian optimization (alpha=0.25)...
# Running 3th iteration of Bayesian optimization (alpha=0.25)...
# Running 4th iteration of Bayesian optimization (alpha=0.25)...
# Running 5th iteration of Bayesian optimization (alpha=0.25)...
# Running 6th iteration of Bayesian optimization (alpha=0.25)...
# Running 7th iteration of Bayesian optimization (alpha=0.25)...
# Running 8th iteration of Bayesian optimization (alpha=0.25)...
# Running 9th iteration of Bayesian optimization (alpha=0.25)...
# Running 10th iteration of Bayesian optimization (alpha=0.25)...
# Running 11th iteration of Bayesian optimization (alpha=0.25)...
# Running 12th iteration of Bayesian optimization (alpha=0.25)...
# Running 13th iteration of Bayesian optimization (alpha=0.25)...
# Running 14th iteration of Bayesian optimization (alpha=0.25)...
# Running 15th iteration of Bayesian optimization (alpha=0.25)...
# Running 16th iteration of Bayesian optimization (alpha=0.25)...
# Running 17th iteration of Bayesian optimization (alpha=0.25)...
# Running 18th iteration of Bayesian optimization (alpha=0.25)...
# Running 19th iteration of Bayesian optimization (alpha=0.25)...
# Running 20th iteration of Bayesian optimization (alpha=0.25)...
# Running 21th iteration of Bayesian optimization (alpha=0.25)...
# Running 22th iteration of Bayesian optimization (alpha=0.25)...
# Running 23th iteration of Bayesian optimization (alpha=0.25)...
# Running 24th iteration of Bayesian optimization (alpha=0.25)...
# Running 25th iteration of Bayesian optimization (alpha=0.25)...
# Running 26th iteration of Bayesian optimization (alpha=0.25)...
# Running 27th iteration of Bayesian optimization (alpha=0.25)...
# Running 28th iteration of Bayesian optimization (alpha=0.25)...
# Running 29th iteration of Bayesian optimization (alpha=0.25)...
# Running 30th iteration of Bayesian optimization (alpha=0.25)...
# Running 31th iteration of Bayesian optimization (alpha=0.25)...
# Running 32th iteration of Bayesian optimization (alpha=0.25)...
# Running 33th iteration of Bayesian optimization (alpha=0.25)...
# Running 34th iteration of Bayesian optimization (alpha=0.25)...
# Running 35th iteration of Bayesian optimization (alpha=0.25)...
# Running 36th iteration of Bayesian optimization (alpha=0.25)...
# Running 37th iteration of Bayesian optimization (alpha=0.25)...
# Running 38th iteration of Bayesian optimization (alpha=0.25)...
# Running 39th iteration of Bayesian optimization (alpha=0.25)...
# Running 40th iteration of Bayesian optimization (alpha=0.25)...
# Running 41th iteration of Bayesian optimization (alpha=0.25)...
# Running 42th iteration of Bayesian optimization (alpha=0.25)...
# Running 43th iteration of Bayesian optimization (alpha=0.25)...
# Running 44th iteration of Bayesian optimization (alpha=0.25)...
# Running 45th iteration of Bayesian optimization (alpha=0.25)...
# Running 46th iteration of Bayesian optimization (alpha=0.25)...
# Running 47th iteration of Bayesian optimization (alpha=0.25)...
# Running 48th iteration of Bayesian optimization (alpha=0.25)...
# Running 49th iteration of Bayesian optimization (alpha=0.25)...
# Running 50th iteration of Bayesian optimization (alpha=0.25)...
# Running 51th iteration of Bayesian optimization (alpha=0.25)...
# Running 52th iteration of Bayesian optimization (alpha=0.25)...
# Running 53th iteration of Bayesian optimization (alpha=0.25)...
# Running 54th iteration of Bayesian optimization (alpha=0.25)...
# Running 55th iteration of Bayesian optimization (alpha=0.25)...
# Running 56th iteration of Bayesian optimization (alpha=0.25)...
# Running 57th iteration of Bayesian optimization (alpha=0.25)...
# Running 58th iteration of Bayesian optimization (alpha=0.25)...
# Running 59th iteration of Bayesian optimization (alpha=0.25)...
# Running 60th iteration of Bayesian optimization (alpha=0.25)...
# Running 61th iteration of Bayesian optimization (alpha=0.25)...
# Running 62th iteration of Bayesian optimization (alpha=0.25)...
# Running 63th iteration of Bayesian optimization (alpha=0.25)...
# Running 64th iteration of Bayesian optimization (alpha=0.25)...
# Running 65th iteration of Bayesian optimization (alpha=0.25)...
# Running 66th iteration of Bayesian optimization (alpha=0.25)...
# Running 67th iteration of Bayesian optimization (alpha=0.25)...
# Running 68th iteration of Bayesian optimization (alpha=0.25)...
# Running 69th iteration of Bayesian optimization (alpha=0.25)...
# Running 70th iteration of Bayesian optimization (alpha=0.25)...
# Running 71th iteration of Bayesian optimization (alpha=0.25)...
# Running 72th iteration of Bayesian optimization (alpha=0.25)...
# Running 73th iteration of Bayesian optimization (alpha=0.25)...
# Running 74th iteration of Bayesian optimization (alpha=0.25)...
# Running 75th iteration of Bayesian optimization (alpha=0.25)...
# Running 76th iteration of Bayesian optimization (alpha=0.25)...
# Running 77th iteration of Bayesian optimization (alpha=0.25)...
# Running 78th iteration of Bayesian optimization (alpha=0.25)...
# Running 79th iteration of Bayesian optimization (alpha=0.25)...
# Running 80th iteration of Bayesian optimization (alpha=0.25)...
# Running 81th iteration of Bayesian optimization (alpha=0.25)...
# Running 82th iteration of Bayesian optimization (alpha=0.25)...
# Running 83th iteration of Bayesian optimization (alpha=0.25)...
# Running 84th iteration of Bayesian optimization (alpha=0.25)...
# Running 85th iteration of Bayesian optimization (alpha=0.25)...
# Running 86th iteration of Bayesian optimization (alpha=0.25)...
# Running 87th iteration of Bayesian optimization (alpha=0.25)...
# Running 88th iteration of Bayesian optimization (alpha=0.25)...
# Running 89th iteration of Bayesian optimization (alpha=0.25)...
# Running 90th iteration of Bayesian optimization (alpha=0.25)...
# Running 91th iteration of Bayesian optimization (alpha=0.25)...
# Running 92th iteration of Bayesian optimization (alpha=0.25)...
# Running 93th iteration of Bayesian optimization (alpha=0.25)...
# Running 94th iteration of Bayesian optimization (alpha=0.25)...
# Running 95th iteration of Bayesian optimization (alpha=0.25)...
# Running 96th iteration of Bayesian optimization (alpha=0.25)...
# Running 97th iteration of Bayesian optimization (alpha=0.25)...
# Running 98th iteration of Bayesian optimization (alpha=0.25)...
# Running 99th iteration of Bayesian optimization (alpha=0.25)...
# Running 100th iteration of Bayesian optimization (alpha=0.25)...
# Running 101th iteration of Bayesian optimization (alpha=0.25)...
# Running 102th iteration of Bayesian optimization (alpha=0.25)...
# Running 103th iteration of Bayesian optimization (alpha=0.25)...
# Running 104th iteration of Bayesian optimization (alpha=0.25)...
# Running 105th iteration of Bayesian optimization (alpha=0.25)...
# Running 106th iteration of Bayesian optimization (alpha=0.25)...
# Running 107th iteration of Bayesian optimization (alpha=0.25)...
# Running 108th iteration of Bayesian optimization (alpha=0.25)...
# Running 109th iteration of Bayesian optimization (alpha=0.25)...
# Running 110th iteration of Bayesian optimization (alpha=0.25)...
# Running 111th iteration of Bayesian optimization (alpha=0.25)...
# Running 112th iteration of Bayesian optimization (alpha=0.25)...
# Running 113th iteration of Bayesian optimization (alpha=0.25)...
# Running 114th iteration of Bayesian optimization (alpha=0.25)...
# Running 115th iteration of Bayesian optimization (alpha=0.25)...
# Running 116th iteration of Bayesian optimization (alpha=0.25)...
# Running 117th iteration of Bayesian optimization (alpha=0.25)...
# Running 118th iteration of Bayesian optimization (alpha=0.25)...
# Running 119th iteration of Bayesian optimization (alpha=0.25)...
# Running 120th iteration of Bayesian optimization (alpha=0.25)...
# Running 121th iteration of Bayesian optimization (alpha=0.25)...
# Running 122th iteration of Bayesian optimization (alpha=0.25)...
# Running 123th iteration of Bayesian optimization (alpha=0.25)...
# Running 124th iteration of Bayesian optimization (alpha=0.25)...
# Running 125th iteration of Bayesian optimization (alpha=0.25)...
# Running 126th iteration of Bayesian optimization (alpha=0.25)...
# Running 127th iteration of Bayesian optimization (alpha=0.25)...
# Running 128th iteration of Bayesian optimization (alpha=0.25)...
# Running 129th iteration of Bayesian optimization (alpha=0.25)...
# Running 130th iteration of Bayesian optimization (alpha=0.25)...
# Running 131th iteration of Bayesian optimization (alpha=0.25)...
# Running 132th iteration of Bayesian optimization (alpha=0.25)...
# Running 133th iteration of Bayesian optimization (alpha=0.25)...
# Running 134th iteration of Bayesian optimization (alpha=0.25)...
# Running 135th iteration of Bayesian optimization (alpha=0.25)...
# Running 136th iteration of Bayesian optimization (alpha=0.25)...
# Running 137th iteration of Bayesian optimization (alpha=0.25)...
# Running 138th iteration of Bayesian optimization (alpha=0.25)...
# Running 139th iteration of Bayesian optimization (alpha=0.25)...
# Running 140th iteration of Bayesian optimization (alpha=0.25)...
# Running 141th iteration of Bayesian optimization (alpha=0.25)...
# Running 142th iteration of Bayesian optimization (alpha=0.25)...
# Running 143th iteration of Bayesian optimization (alpha=0.25)...
# Running 144th iteration of Bayesian optimization (alpha=0.25)...
# Running 145th iteration of Bayesian optimization (alpha=0.25)...
# Running 146th iteration of Bayesian optimization (alpha=0.25)...
# Running 147th iteration of Bayesian optimization (alpha=0.25)...
# Running 148th iteration of Bayesian optimization (alpha=0.25)...
# Running 149th iteration of Bayesian optimization (alpha=0.25)...
# Running 150th iteration of Bayesian optimization (alpha=0.25)...
# Running 151th iteration of Bayesian optimization (alpha=0.25)...
# Running 152th iteration of Bayesian optimization (alpha=0.25)...
# Running 153th iteration of Bayesian optimization (alpha=0.25)...
# Running 154th iteration of Bayesian optimization (alpha=0.25)...
# Running 155th iteration of Bayesian optimization (alpha=0.25)...
# Running 156th iteration of Bayesian optimization (alpha=0.25)...
# Running 157th iteration of Bayesian optimization (alpha=0.25)...
# Running 158th iteration of Bayesian optimization (alpha=0.25)...
# Running 159th iteration of Bayesian optimization (alpha=0.25)...
# Running 160th iteration of Bayesian optimization (alpha=0.25)...
# Running 161th iteration of Bayesian optimization (alpha=0.25)...
# Running 162th iteration of Bayesian optimization (alpha=0.25)...
# Running 163th iteration of Bayesian optimization (alpha=0.25)...
# Running 164th iteration of Bayesian optimization (alpha=0.25)...
# Running 165th iteration of Bayesian optimization (alpha=0.25)...
# Running 166th iteration of Bayesian optimization (alpha=0.25)...
# Running 167th iteration of Bayesian optimization (alpha=0.25)...
# Running 168th iteration of Bayesian optimization (alpha=0.25)...
# Running 169th iteration of Bayesian optimization (alpha=0.25)...
# Running 170th iteration of Bayesian optimization (alpha=0.25)...
# Running 171th iteration of Bayesian optimization (alpha=0.25)...
# Running 172th iteration of Bayesian optimization (alpha=0.25)...
# Running 173th iteration of Bayesian optimization (alpha=0.25)...
# Running 174th iteration of Bayesian optimization (alpha=0.25)...
# Running 175th iteration of Bayesian optimization (alpha=0.25)...
# Running 176th iteration of Bayesian optimization (alpha=0.25)...
# Running 177th iteration of Bayesian optimization (alpha=0.25)...
# Running 178th iteration of Bayesian optimization (alpha=0.25)...
# Running 179th iteration of Bayesian optimization (alpha=0.25)...
# Running 180th iteration of Bayesian optimization (alpha=0.25)...
# Running 181th iteration of Bayesian optimization (alpha=0.25)...
# Running 182th iteration of Bayesian optimization (alpha=0.25)...
# Running 183th iteration of Bayesian optimization (alpha=0.25)...
# Running 184th iteration of Bayesian optimization (alpha=0.25)...
# Running 185th iteration of Bayesian optimization (alpha=0.25)...
# Running 186th iteration of Bayesian optimization (alpha=0.25)...
# Running 187th iteration of Bayesian optimization (alpha=0.25)...
# Running 188th iteration of Bayesian optimization (alpha=0.25)...
# Running 189th iteration of Bayesian optimization (alpha=0.25)...
# Running 190th iteration of Bayesian optimization (alpha=0.25)...
# Running 191th iteration of Bayesian optimization (alpha=0.25)...
# Running 192th iteration of Bayesian optimization (alpha=0.25)...
# Running 193th iteration of Bayesian optimization (alpha=0.25)...
# Running 194th iteration of Bayesian optimization (alpha=0.25)...
# Running 195th iteration of Bayesian optimization (alpha=0.25)...
# Running 196th iteration of Bayesian optimization (alpha=0.25)...
# Running 197th iteration of Bayesian optimization (alpha=0.25)...
# Running 198th iteration of Bayesian optimization (alpha=0.25)...
# Running 199th iteration of Bayesian optimization (alpha=0.25)...
# Running 200th iteration of Bayesian optimization (alpha=0.25)...
# Running 201th iteration of Bayesian optimization (alpha=0.25)...
# Running 202th iteration of Bayesian optimization (alpha=0.25)...
# Running 203th iteration of Bayesian optimization (alpha=0.25)...
# Running 204th iteration of Bayesian optimization (alpha=0.25)...
# Running 205th iteration of Bayesian optimization (alpha=0.25)...
# Running 206th iteration of Bayesian optimization (alpha=0.25)...
# Running 207th iteration of Bayesian optimization (alpha=0.25)...
# Running 208th iteration of Bayesian optimization (alpha=0.25)...
# Running 209th iteration of Bayesian optimization (alpha=0.25)...
# Running 210th iteration of Bayesian optimization (alpha=0.25)...
# Running 211th iteration of Bayesian optimization (alpha=0.25)...
# Running 212th iteration of Bayesian optimization (alpha=0.25)...
# Running 213th iteration of Bayesian optimization (alpha=0.25)...
# Running 214th iteration of Bayesian optimization (alpha=0.25)...
# Running 215th iteration of Bayesian optimization (alpha=0.25)...
# Running 216th iteration of Bayesian optimization (alpha=0.25)...
# Running 217th iteration of Bayesian optimization (alpha=0.25)...
# Running 218th iteration of Bayesian optimization (alpha=0.25)...
# Running 219th iteration of Bayesian optimization (alpha=0.25)...
# Running 220th iteration of Bayesian optimization (alpha=0.25)...
# Running 221th iteration of Bayesian optimization (alpha=0.25)...
# Running 222th iteration of Bayesian optimization (alpha=0.25)...
# Running 223th iteration of Bayesian optimization (alpha=0.25)...
# Running 224th iteration of Bayesian optimization (alpha=0.25)...
# Running 225th iteration of Bayesian optimization (alpha=0.25)...
# Running 226th iteration of Bayesian optimization (alpha=0.25)...
# Running 227th iteration of Bayesian optimization (alpha=0.25)...
# Running 228th iteration of Bayesian optimization (alpha=0.25)...
# Running 229th iteration of Bayesian optimization (alpha=0.25)...
# Running 230th iteration of Bayesian optimization (alpha=0.25)...
# Running 231th iteration of Bayesian optimization (alpha=0.25)...
# Running 232th iteration of Bayesian optimization (alpha=0.25)...
# Running 233th iteration of Bayesian optimization (alpha=0.25)...
# Running 234th iteration of Bayesian optimization (alpha=0.25)...
# Running 235th iteration of Bayesian optimization (alpha=0.25)...
# Running 236th iteration of Bayesian optimization (alpha=0.25)...
# Running 237th iteration of Bayesian optimization (alpha=0.25)...
# Running 238th iteration of Bayesian optimization (alpha=0.25)...
# Running 239th iteration of Bayesian optimization (alpha=0.25)...
# Running 240th iteration of Bayesian optimization (alpha=0.25)...
# Running 241th iteration of Bayesian optimization (alpha=0.25)...
# Running 242th iteration of Bayesian optimization (alpha=0.25)...
# Running 243th iteration of Bayesian optimization (alpha=0.25)...
# Running 244th iteration of Bayesian optimization (alpha=0.25)...
# Running 245th iteration of Bayesian optimization (alpha=0.25)...
# Running 246th iteration of Bayesian optimization (alpha=0.25)...
# Running 247th iteration of Bayesian optimization (alpha=0.25)...
# Running 248th iteration of Bayesian optimization (alpha=0.25)...
# Running 249th iteration of Bayesian optimization (alpha=0.25)...
# Running 250th iteration of Bayesian optimization (alpha=0.25)...
# Running 251th iteration of Bayesian optimization (alpha=0.25)...
# Running 252th iteration of Bayesian optimization (alpha=0.25)...
# Running 253th iteration of Bayesian optimization (alpha=0.25)...
# Running 254th iteration of Bayesian optimization (alpha=0.25)...
# Running 255th iteration of Bayesian optimization (alpha=0.25)...
# Running 256th iteration of Bayesian optimization (alpha=0.25)...
# Running 257th iteration of Bayesian optimization (alpha=0.25)...
# Running 258th iteration of Bayesian optimization (alpha=0.25)...
# Running 259th iteration of Bayesian optimization (alpha=0.25)...
# Running 260th iteration of Bayesian optimization (alpha=0.25)...
# Running 261th iteration of Bayesian optimization (alpha=0.25)...
# Running 262th iteration of Bayesian optimization (alpha=0.25)...
# Running 263th iteration of Bayesian optimization (alpha=0.25)...
# Running 264th iteration of Bayesian optimization (alpha=0.25)...
# Running 265th iteration of Bayesian optimization (alpha=0.25)...
# Running 266th iteration of Bayesian optimization (alpha=0.25)...
# Running 267th iteration of Bayesian optimization (alpha=0.25)...
# Running 268th iteration of Bayesian optimization (alpha=0.25)...
# Running 269th iteration of Bayesian optimization (alpha=0.25)...
# Running 270th iteration of Bayesian optimization (alpha=0.25)...
# Running 271th iteration of Bayesian optimization (alpha=0.25)...
# Running 272th iteration of Bayesian optimization (alpha=0.25)...
# Running 273th iteration of Bayesian optimization (alpha=0.25)...
# Running 274th iteration of Bayesian optimization (alpha=0.25)...
# Running 275th iteration of Bayesian optimization (alpha=0.25)...
# Running 276th iteration of Bayesian optimization (alpha=0.25)...
# Running 277th iteration of Bayesian optimization (alpha=0.25)...
# Running 278th iteration of Bayesian optimization (alpha=0.25)...
# Running 279th iteration of Bayesian optimization (alpha=0.25)...
# Running 280th iteration of Bayesian optimization (alpha=0.25)...
# Running 281th iteration of Bayesian optimization (alpha=0.25)...
# Running 282th iteration of Bayesian optimization (alpha=0.25)...
# Running 283th iteration of Bayesian optimization (alpha=0.25)...
# Running 284th iteration of Bayesian optimization (alpha=0.25)...
# Running 285th iteration of Bayesian optimization (alpha=0.25)...
# Running 286th iteration of Bayesian optimization (alpha=0.25)...
# Running 287th iteration of Bayesian optimization (alpha=0.25)...
# Running 288th iteration of Bayesian optimization (alpha=0.25)...
# Running 289th iteration of Bayesian optimization (alpha=0.25)...
# Running 290th iteration of Bayesian optimization (alpha=0.25)...
# Running 291th iteration of Bayesian optimization (alpha=0.25)...
# Running 292th iteration of Bayesian optimization (alpha=0.25)...
# Running 293th iteration of Bayesian optimization (alpha=0.25)...
# Running 294th iteration of Bayesian optimization (alpha=0.25)...
# Running 295th iteration of Bayesian optimization (alpha=0.25)...
# Running 296th iteration of Bayesian optimization (alpha=0.25)...
# Running 297th iteration of Bayesian optimization (alpha=0.25)...
# Running 298th iteration of Bayesian optimization (alpha=0.25)...
# Running 299th iteration of Bayesian optimization (alpha=0.25)...
# Running 300th iteration of Bayesian optimization (alpha=0.25)...
# Running 301th iteration of Bayesian optimization (alpha=0.25)...
# Running 302th iteration of Bayesian optimization (alpha=0.25)...
# Running 303th iteration of Bayesian optimization (alpha=0.25)...
# Running 304th iteration of Bayesian optimization (alpha=0.25)...
# Running 305th iteration of Bayesian optimization (alpha=0.25)...
# Running 306th iteration of Bayesian optimization (alpha=0.25)...
# Running 307th iteration of Bayesian optimization (alpha=0.25)...
# Running 308th iteration of Bayesian optimization (alpha=0.25)...
# Running 309th iteration of Bayesian optimization (alpha=0.25)...
# Running 310th iteration of Bayesian optimization (alpha=0.25)...
# Running 311th iteration of Bayesian optimization (alpha=0.25)...
# Running 312th iteration of Bayesian optimization (alpha=0.25)...
# Running 313th iteration of Bayesian optimization (alpha=0.25)...
# Running 314th iteration of Bayesian optimization (alpha=0.25)...
# Running 315th iteration of Bayesian optimization (alpha=0.25)...
# Running 316th iteration of Bayesian optimization (alpha=0.25)...
# Running 317th iteration of Bayesian optimization (alpha=0.25)...
# Running 318th iteration of Bayesian optimization (alpha=0.25)...
# Running 319th iteration of Bayesian optimization (alpha=0.25)...
# Running 320th iteration of Bayesian optimization (alpha=0.25)...
# Running 321th iteration of Bayesian optimization (alpha=0.25)...
# Running 322th iteration of Bayesian optimization (alpha=0.25)...
# Running 323th iteration of Bayesian optimization (alpha=0.25)...
# Running 324th iteration of Bayesian optimization (alpha=0.25)...
# Running 325th iteration of Bayesian optimization (alpha=0.25)...
# Running 326th iteration of Bayesian optimization (alpha=0.25)...
# Running 327th iteration of Bayesian optimization (alpha=0.25)...
# Running 328th iteration of Bayesian optimization (alpha=0.25)...
# Running 329th iteration of Bayesian optimization (alpha=0.25)...
# Running 330th iteration of Bayesian optimization (alpha=0.25)...
# Running 331th iteration of Bayesian optimization (alpha=0.25)...
# Running 332th iteration of Bayesian optimization (alpha=0.25)...
# Running 333th iteration of Bayesian optimization (alpha=0.25)...
# Running 334th iteration of Bayesian optimization (alpha=0.25)...
# Running 335th iteration of Bayesian optimization (alpha=0.25)...
# Running 336th iteration of Bayesian optimization (alpha=0.25)...
# Running 337th iteration of Bayesian optimization (alpha=0.25)...
# Running 338th iteration of Bayesian optimization (alpha=0.25)...
# Running 339th iteration of Bayesian optimization (alpha=0.25)...
# Running 340th iteration of Bayesian optimization (alpha=0.25)...
# Running 341th iteration of Bayesian optimization (alpha=0.25)...
# Running 342th iteration of Bayesian optimization (alpha=0.25)...
# Running 343th iteration of Bayesian optimization (alpha=0.25)...
# Running 344th iteration of Bayesian optimization (alpha=0.25)...
# Running 345th iteration of Bayesian optimization (alpha=0.25)...
# Running 346th iteration of Bayesian optimization (alpha=0.25)...
# Running 347th iteration of Bayesian optimization (alpha=0.25)...
# Running 348th iteration of Bayesian optimization (alpha=0.25)...
# Running 349th iteration of Bayesian optimization (alpha=0.25)...
# Running 350th iteration of Bayesian optimization (alpha=0.25)...
# Running 351th iteration of Bayesian optimization (alpha=0.25)...
# Running 352th iteration of Bayesian optimization (alpha=0.25)...
# Running 353th iteration of Bayesian optimization (alpha=0.25)...
# Running 354th iteration of Bayesian optimization (alpha=0.25)...
# Running 355th iteration of Bayesian optimization (alpha=0.25)...
# Running 356th iteration of Bayesian optimization (alpha=0.25)...
# Running 357th iteration of Bayesian optimization (alpha=0.25)...
# Running 358th iteration of Bayesian optimization (alpha=0.25)...
# Running 359th iteration of Bayesian optimization (alpha=0.25)...
# Running 360th iteration of Bayesian optimization (alpha=0.25)...
# Running 361th iteration of Bayesian optimization (alpha=0.25)...
# Running 362th iteration of Bayesian optimization (alpha=0.25)...
# Running 363th iteration of Bayesian optimization (alpha=0.25)...
# Running 364th iteration of Bayesian optimization (alpha=0.25)...
# Running 365th iteration of Bayesian optimization (alpha=0.25)...
# Running 366th iteration of Bayesian optimization (alpha=0.25)...
# Running 367th iteration of Bayesian optimization (alpha=0.25)...
# Running 368th iteration of Bayesian optimization (alpha=0.25)...
# Running 369th iteration of Bayesian optimization (alpha=0.25)...
# Running 370th iteration of Bayesian optimization (alpha=0.25)...
# Running 371th iteration of Bayesian optimization (alpha=0.25)...
# Running 372th iteration of Bayesian optimization (alpha=0.25)...
# Running 373th iteration of Bayesian optimization (alpha=0.25)...
# Running 374th iteration of Bayesian optimization (alpha=0.25)...
# Running 375th iteration of Bayesian optimization (alpha=0.25)...
# Running 376th iteration of Bayesian optimization (alpha=0.25)...
# Running 377th iteration of Bayesian optimization (alpha=0.25)...
# Running 378th iteration of Bayesian optimization (alpha=0.25)...
# Running 379th iteration of Bayesian optimization (alpha=0.25)...
# Running 380th iteration of Bayesian optimization (alpha=0.25)...
# Running 381th iteration of Bayesian optimization (alpha=0.25)...
# Running 382th iteration of Bayesian optimization (alpha=0.25)...
# Running 383th iteration of Bayesian optimization (alpha=0.25)...
# Running 384th iteration of Bayesian optimization (alpha=0.25)...
# Running 385th iteration of Bayesian optimization (alpha=0.25)...
# Running 386th iteration of Bayesian optimization (alpha=0.25)...
# Running 387th iteration of Bayesian optimization (alpha=0.25)...
# Running 388th iteration of Bayesian optimization (alpha=0.25)...
# Running 389th iteration of Bayesian optimization (alpha=0.25)...
# Running 390th iteration of Bayesian optimization (alpha=0.25)...
# Running 391th iteration of Bayesian optimization (alpha=0.25)...
# Running 392th iteration of Bayesian optimization (alpha=0.25)...
# Running 393th iteration of Bayesian optimization (alpha=0.25)...
# Running 394th iteration of Bayesian optimization (alpha=0.25)...
# Running 395th iteration of Bayesian optimization (alpha=0.25)...
# Running 396th iteration of Bayesian optimization (alpha=0.25)...
# Running 397th iteration of Bayesian optimization (alpha=0.25)...
# Running 398th iteration of Bayesian optimization (alpha=0.25)...
# Running 399th iteration of Bayesian optimization (alpha=0.25)...
# Running 400th iteration of Bayesian optimization (alpha=0.25)...
# Running 401th iteration of Bayesian optimization (alpha=0.25)...
# Running 402th iteration of Bayesian optimization (alpha=0.25)...
# Running 403th iteration of Bayesian optimization (alpha=0.25)...
# Running 404th iteration of Bayesian optimization (alpha=0.25)...
# Running 405th iteration of Bayesian optimization (alpha=0.25)...
# Running 406th iteration of Bayesian optimization (alpha=0.25)...
# Running 407th iteration of Bayesian optimization (alpha=0.25)...
# Running 408th iteration of Bayesian optimization (alpha=0.25)...
# Running 409th iteration of Bayesian optimization (alpha=0.25)...
# Running 410th iteration of Bayesian optimization (alpha=0.25)...
# Running 411th iteration of Bayesian optimization (alpha=0.25)...
# Running 412th iteration of Bayesian optimization (alpha=0.25)...
# Running 413th iteration of Bayesian optimization (alpha=0.25)...
# Running 414th iteration of Bayesian optimization (alpha=0.25)...
# Running 415th iteration of Bayesian optimization (alpha=0.25)...
# Running 416th iteration of Bayesian optimization (alpha=0.25)...
# Running 417th iteration of Bayesian optimization (alpha=0.25)...
# Running 418th iteration of Bayesian optimization (alpha=0.25)...
# Running 419th iteration of Bayesian optimization (alpha=0.25)...
# Running 420th iteration of Bayesian optimization (alpha=0.25)...
# Running 421th iteration of Bayesian optimization (alpha=0.25)...
# Running 422th iteration of Bayesian optimization (alpha=0.25)...
# Running 423th iteration of Bayesian optimization (alpha=0.25)...
# Running 424th iteration of Bayesian optimization (alpha=0.25)...
# Running 425th iteration of Bayesian optimization (alpha=0.25)...
# Running 426th iteration of Bayesian optimization (alpha=0.25)...
# Running 427th iteration of Bayesian optimization (alpha=0.25)...
# Running 428th iteration of Bayesian optimization (alpha=0.25)...
# Running 429th iteration of Bayesian optimization (alpha=0.25)...
# Running 430th iteration of Bayesian optimization (alpha=0.25)...
# Running 431th iteration of Bayesian optimization (alpha=0.25)...
# Running 432th iteration of Bayesian optimization (alpha=0.25)...
# Running 433th iteration of Bayesian optimization (alpha=0.25)...
# Running 434th iteration of Bayesian optimization (alpha=0.25)...
# Running 435th iteration of Bayesian optimization (alpha=0.25)...
# Running 436th iteration of Bayesian optimization (alpha=0.25)...
# Running 437th iteration of Bayesian optimization (alpha=0.25)...
# Running 438th iteration of Bayesian optimization (alpha=0.25)...
# Running 439th iteration of Bayesian optimization (alpha=0.25)...
# Running 440th iteration of Bayesian optimization (alpha=0.25)...
# Running 441th iteration of Bayesian optimization (alpha=0.25)...
# Running 442th iteration of Bayesian optimization (alpha=0.25)...
# Running 443th iteration of Bayesian optimization (alpha=0.25)...
# Running 444th iteration of Bayesian optimization (alpha=0.25)...
# Running 445th iteration of Bayesian optimization (alpha=0.25)...
# Running 446th iteration of Bayesian optimization (alpha=0.25)...
# Running 447th iteration of Bayesian optimization (alpha=0.25)...
# Running 448th iteration of Bayesian optimization (alpha=0.25)...
# Running 449th iteration of Bayesian optimization (alpha=0.25)...
# Running 450th iteration of Bayesian optimization (alpha=0.25)...
# Running 451th iteration of Bayesian optimization (alpha=0.25)...
# Running 452th iteration of Bayesian optimization (alpha=0.25)...
# Running 453th iteration of Bayesian optimization (alpha=0.25)...
# Running 454th iteration of Bayesian optimization (alpha=0.25)...
# Running 455th iteration of Bayesian optimization (alpha=0.25)...
# Running 456th iteration of Bayesian optimization (alpha=0.25)...
# Running 457th iteration of Bayesian optimization (alpha=0.25)...
# Running 458th iteration of Bayesian optimization (alpha=0.25)...
# Running 459th iteration of Bayesian optimization (alpha=0.25)...
# Running 460th iteration of Bayesian optimization (alpha=0.25)...
# Running 461th iteration of Bayesian optimization (alpha=0.25)...
# Running 462th iteration of Bayesian optimization (alpha=0.25)...
# Running 463th iteration of Bayesian optimization (alpha=0.25)...
# Running 464th iteration of Bayesian optimization (alpha=0.25)...
# Running 465th iteration of Bayesian optimization (alpha=0.25)...
# Running 466th iteration of Bayesian optimization (alpha=0.25)...
# Running 467th iteration of Bayesian optimization (alpha=0.25)...
# Running 468th iteration of Bayesian optimization (alpha=0.25)...
# Running 469th iteration of Bayesian optimization (alpha=0.25)...
# Running 470th iteration of Bayesian optimization (alpha=0.25)...
# Running 471th iteration of Bayesian optimization (alpha=0.25)...
# Running 472th iteration of Bayesian optimization (alpha=0.25)...
# Running 473th iteration of Bayesian optimization (alpha=0.25)...
# Running 474th iteration of Bayesian optimization (alpha=0.25)...
# Running 475th iteration of Bayesian optimization (alpha=0.25)...
# Running 476th iteration of Bayesian optimization (alpha=0.25)...
# Running 477th iteration of Bayesian optimization (alpha=0.25)...
# Running 478th iteration of Bayesian optimization (alpha=0.25)...
# Running 479th iteration of Bayesian optimization (alpha=0.25)...
# Running 480th iteration of Bayesian optimization (alpha=0.25)...
# Running 481th iteration of Bayesian optimization (alpha=0.25)...
# Running 482th iteration of Bayesian optimization (alpha=0.25)...
# Running 483th iteration of Bayesian optimization (alpha=0.25)...
# Running 484th iteration of Bayesian optimization (alpha=0.25)...
# Running 485th iteration of Bayesian optimization (alpha=0.25)...
# Running 486th iteration of Bayesian optimization (alpha=0.25)...
# Running 487th iteration of Bayesian optimization (alpha=0.25)...
# Running 488th iteration of Bayesian optimization (alpha=0.25)...
# Running 489th iteration of Bayesian optimization (alpha=0.25)...
# Running 490th iteration of Bayesian optimization (alpha=0.25)...
# Running 491th iteration of Bayesian optimization (alpha=0.25)...
# Running 492th iteration of Bayesian optimization (alpha=0.25)...
# Running 493th iteration of Bayesian optimization (alpha=0.25)...
# Running 494th iteration of Bayesian optimization (alpha=0.25)...
# Running 495th iteration of Bayesian optimization (alpha=0.25)...
# Running 496th iteration of Bayesian optimization (alpha=0.25)...
# Running 497th iteration of Bayesian optimization (alpha=0.25)...
# Running 498th iteration of Bayesian optimization (alpha=0.25)...
# Running 499th iteration of Bayesian optimization (alpha=0.25)...
# Running 500th iteration of Bayesian optimization (alpha=0.25)...
# Running 501th iteration of Bayesian optimization (alpha=0.25)...
# Running 502th iteration of Bayesian optimization (alpha=0.25)...
# Running 503th iteration of Bayesian optimization (alpha=0.25)...
# Running 504th iteration of Bayesian optimization (alpha=0.25)...
# Running 505th iteration of Bayesian optimization (alpha=0.25)...
# Running 506th iteration of Bayesian optimization (alpha=0.25)...
# Running 507th iteration of Bayesian optimization (alpha=0.25)...
# Running 508th iteration of Bayesian optimization (alpha=0.25)...
# Running 509th iteration of Bayesian optimization (alpha=0.25)...
# Running 510th iteration of Bayesian optimization (alpha=0.25)...
# Running 511th iteration of Bayesian optimization (alpha=0.25)...
# Running 512th iteration of Bayesian optimization (alpha=0.25)...
# Running 513th iteration of Bayesian optimization (alpha=0.25)...
# Running 514th iteration of Bayesian optimization (alpha=0.25)...
# Running 515th iteration of Bayesian optimization (alpha=0.25)...
# Running 516th iteration of Bayesian optimization (alpha=0.25)...
# Running 517th iteration of Bayesian optimization (alpha=0.25)...
# Running 518th iteration of Bayesian optimization (alpha=0.25)...
# Running 519th iteration of Bayesian optimization (alpha=0.25)...
# Running 520th iteration of Bayesian optimization (alpha=0.25)...
# Running 521th iteration of Bayesian optimization (alpha=0.25)...
# Running 522th iteration of Bayesian optimization (alpha=0.25)...
# Running 523th iteration of Bayesian optimization (alpha=0.25)...
# Running 524th iteration of Bayesian optimization (alpha=0.25)...
# Running 525th iteration of Bayesian optimization (alpha=0.25)...
# Running 526th iteration of Bayesian optimization (alpha=0.25)...
# Running 527th iteration of Bayesian optimization (alpha=0.25)...
# Running 528th iteration of Bayesian optimization (alpha=0.25)...
# Running 529th iteration of Bayesian optimization (alpha=0.25)...
# Running 530th iteration of Bayesian optimization (alpha=0.25)...
# Running 531th iteration of Bayesian optimization (alpha=0.25)...
# Running 532th iteration of Bayesian optimization (alpha=0.25)...
# Running 533th iteration of Bayesian optimization (alpha=0.25)...
# Running 534th iteration of Bayesian optimization (alpha=0.25)...
# Running 535th iteration of Bayesian optimization (alpha=0.25)...
# Running 536th iteration of Bayesian optimization (alpha=0.25)...
# Running 537th iteration of Bayesian optimization (alpha=0.25)...
# Running 538th iteration of Bayesian optimization (alpha=0.25)...
# Running 539th iteration of Bayesian optimization (alpha=0.25)...
# Running 540th iteration of Bayesian optimization (alpha=0.25)...
# Running 541th iteration of Bayesian optimization (alpha=0.25)...
# Running 542th iteration of Bayesian optimization (alpha=0.25)...
# Running 543th iteration of Bayesian optimization (alpha=0.25)...
# Running 544th iteration of Bayesian optimization (alpha=0.25)...
# Running 545th iteration of Bayesian optimization (alpha=0.25)...
# Running 546th iteration of Bayesian optimization (alpha=0.25)...
# Running 547th iteration of Bayesian optimization (alpha=0.25)...
# Running 548th iteration of Bayesian optimization (alpha=0.25)...
# Running 549th iteration of Bayesian optimization (alpha=0.25)...
# Running 550th iteration of Bayesian optimization (alpha=0.25)...
# Running 551th iteration of Bayesian optimization (alpha=0.25)...
# Running 552th iteration of Bayesian optimization (alpha=0.25)...
# Running 553th iteration of Bayesian optimization (alpha=0.25)...
# Running 554th iteration of Bayesian optimization (alpha=0.25)...
# Running 555th iteration of Bayesian optimization (alpha=0.25)...
# Running 556th iteration of Bayesian optimization (alpha=0.25)...
# Running 557th iteration of Bayesian optimization (alpha=0.25)...
# Running 558th iteration of Bayesian optimization (alpha=0.25)...
# Running 559th iteration of Bayesian optimization (alpha=0.25)...
# Running 560th iteration of Bayesian optimization (alpha=0.25)...
# Running 561th iteration of Bayesian optimization (alpha=0.25)...
# Running 562th iteration of Bayesian optimization (alpha=0.25)...
# Running 563th iteration of Bayesian optimization (alpha=0.25)...
# Running 564th iteration of Bayesian optimization (alpha=0.25)...
# Running 565th iteration of Bayesian optimization (alpha=0.25)...
# Running 566th iteration of Bayesian optimization (alpha=0.25)...
# Running 567th iteration of Bayesian optimization (alpha=0.25)...
# Running 568th iteration of Bayesian optimization (alpha=0.25)...
# Running 569th iteration of Bayesian optimization (alpha=0.25)...
# Running 570th iteration of Bayesian optimization (alpha=0.25)...
# Running 571th iteration of Bayesian optimization (alpha=0.25)...
# Running 572th iteration of Bayesian optimization (alpha=0.25)...
# Running 573th iteration of Bayesian optimization (alpha=0.25)...
# Running 574th iteration of Bayesian optimization (alpha=0.25)...
# Running 575th iteration of Bayesian optimization (alpha=0.25)...
# Running 576th iteration of Bayesian optimization (alpha=0.25)...
# Running 577th iteration of Bayesian optimization (alpha=0.25)...
# Running 578th iteration of Bayesian optimization (alpha=0.25)...
# Running 579th iteration of Bayesian optimization (alpha=0.25)...
# Running 580th iteration of Bayesian optimization (alpha=0.25)...
# Running 581th iteration of Bayesian optimization (alpha=0.25)...
# Running 582th iteration of Bayesian optimization (alpha=0.25)...
# Running 583th iteration of Bayesian optimization (alpha=0.25)...
# Running 584th iteration of Bayesian optimization (alpha=0.25)...
# Running 585th iteration of Bayesian optimization (alpha=0.25)...
# Running 586th iteration of Bayesian optimization (alpha=0.25)...
# Running 587th iteration of Bayesian optimization (alpha=0.25)...
# Running 588th iteration of Bayesian optimization (alpha=0.25)...
# Running 589th iteration of Bayesian optimization (alpha=0.25)...
# Running 590th iteration of Bayesian optimization (alpha=0.25)...
# Running 591th iteration of Bayesian optimization (alpha=0.25)...
# Running 592th iteration of Bayesian optimization (alpha=0.25)...
# Running 593th iteration of Bayesian optimization (alpha=0.25)...
# Running 594th iteration of Bayesian optimization (alpha=0.25)...
# Running 595th iteration of Bayesian optimization (alpha=0.25)...
# Running 596th iteration of Bayesian optimization (alpha=0.25)...
# Running 597th iteration of Bayesian optimization (alpha=0.25)...
# Running 598th iteration of Bayesian optimization (alpha=0.25)...
# Running 599th iteration of Bayesian optimization (alpha=0.25)...
# Running 600th iteration of Bayesian optimization (alpha=0.25)...
# Running 601th iteration of Bayesian optimization (alpha=0.25)...
# Running 602th iteration of Bayesian optimization (alpha=0.25)...
# Running 603th iteration of Bayesian optimization (alpha=0.25)...
# Running 604th iteration of Bayesian optimization (alpha=0.25)...
# Running 605th iteration of Bayesian optimization (alpha=0.25)...
# Running 606th iteration of Bayesian optimization (alpha=0.25)...
# Running 607th iteration of Bayesian optimization (alpha=0.25)...
# Running 608th iteration of Bayesian optimization (alpha=0.25)...
# Running 609th iteration of Bayesian optimization (alpha=0.25)...
# Running 610th iteration of Bayesian optimization (alpha=0.25)...
# Running 611th iteration of Bayesian optimization (alpha=0.25)...
# Running 612th iteration of Bayesian optimization (alpha=0.25)...
# Running 613th iteration of Bayesian optimization (alpha=0.25)...
# Running 614th iteration of Bayesian optimization (alpha=0.25)...
# Running 615th iteration of Bayesian optimization (alpha=0.25)...
# Running 616th iteration of Bayesian optimization (alpha=0.25)...
# Running 617th iteration of Bayesian optimization (alpha=0.25)...
# Running 618th iteration of Bayesian optimization (alpha=0.25)...
# Running 619th iteration of Bayesian optimization (alpha=0.25)...
# Running 620th iteration of Bayesian optimization (alpha=0.25)...
# Running 621th iteration of Bayesian optimization (alpha=0.25)...
# Running 622th iteration of Bayesian optimization (alpha=0.25)...
# Running 623th iteration of Bayesian optimization (alpha=0.25)...
# Running 624th iteration of Bayesian optimization (alpha=0.25)...
# Running 625th iteration of Bayesian optimization (alpha=0.25)...
# Running 626th iteration of Bayesian optimization (alpha=0.25)...
# Running 627th iteration of Bayesian optimization (alpha=0.25)...
# Running 628th iteration of Bayesian optimization (alpha=0.25)...
# Running 629th iteration of Bayesian optimization (alpha=0.25)...
# Running 630th iteration of Bayesian optimization (alpha=0.25)...
# Running 631th iteration of Bayesian optimization (alpha=0.25)...
# Running 632th iteration of Bayesian optimization (alpha=0.25)...
# Running 633th iteration of Bayesian optimization (alpha=0.25)...
# Running 634th iteration of Bayesian optimization (alpha=0.25)...
# Running 635th iteration of Bayesian optimization (alpha=0.25)...
# Running 636th iteration of Bayesian optimization (alpha=0.25)...
# Running 637th iteration of Bayesian optimization (alpha=0.25)...
# Running 638th iteration of Bayesian optimization (alpha=0.25)...
# Running 639th iteration of Bayesian optimization (alpha=0.25)...
# Running 640th iteration of Bayesian optimization (alpha=0.25)...
# Running 641th iteration of Bayesian optimization (alpha=0.25)...
# Running 642th iteration of Bayesian optimization (alpha=0.25)...
# Running 643th iteration of Bayesian optimization (alpha=0.25)...
# Running 644th iteration of Bayesian optimization (alpha=0.25)...
# Running 645th iteration of Bayesian optimization (alpha=0.25)...
# Running 646th iteration of Bayesian optimization (alpha=0.25)...
# Running 647th iteration of Bayesian optimization (alpha=0.25)...
# Running 648th iteration of Bayesian optimization (alpha=0.25)...
# Running 649th iteration of Bayesian optimization (alpha=0.25)...
# Running 650th iteration of Bayesian optimization (alpha=0.25)...
# Running 651th iteration of Bayesian optimization (alpha=0.25)...
# Running 652th iteration of Bayesian optimization (alpha=0.25)...
# Running 653th iteration of Bayesian optimization (alpha=0.25)...
# Running 654th iteration of Bayesian optimization (alpha=0.25)...
# Running 655th iteration of Bayesian optimization (alpha=0.25)...
# Running 656th iteration of Bayesian optimization (alpha=0.25)...
# Running 657th iteration of Bayesian optimization (alpha=0.25)...
# Running 658th iteration of Bayesian optimization (alpha=0.25)...
# Running 659th iteration of Bayesian optimization (alpha=0.25)...
# Running 660th iteration of Bayesian optimization (alpha=0.25)...
# Running 661th iteration of Bayesian optimization (alpha=0.25)...
# Running 662th iteration of Bayesian optimization (alpha=0.25)...
# Running 663th iteration of Bayesian optimization (alpha=0.25)...
# Running 664th iteration of Bayesian optimization (alpha=0.25)...
# Running 665th iteration of Bayesian optimization (alpha=0.25)...
# Running 666th iteration of Bayesian optimization (alpha=0.25)...
# Running 667th iteration of Bayesian optimization (alpha=0.25)...
# Running 668th iteration of Bayesian optimization (alpha=0.25)...
# Running 669th iteration of Bayesian optimization (alpha=0.25)...
# Running 670th iteration of Bayesian optimization (alpha=0.25)...
# Running 671th iteration of Bayesian optimization (alpha=0.25)...
# Running 672th iteration of Bayesian optimization (alpha=0.25)...
# Running 673th iteration of Bayesian optimization (alpha=0.25)...
# Running 674th iteration of Bayesian optimization (alpha=0.25)...
# Running 675th iteration of Bayesian optimization (alpha=0.25)...
# Running 676th iteration of Bayesian optimization (alpha=0.25)...
# Running 677th iteration of Bayesian optimization (alpha=0.25)...
# Running 678th iteration of Bayesian optimization (alpha=0.25)...
# Running 679th iteration of Bayesian optimization (alpha=0.25)...
# Running 680th iteration of Bayesian optimization (alpha=0.25)...
# Running 681th iteration of Bayesian optimization (alpha=0.25)...
# Running 682th iteration of Bayesian optimization (alpha=0.25)...
# Running 683th iteration of Bayesian optimization (alpha=0.25)...
# Running 684th iteration of Bayesian optimization (alpha=0.25)...
# Running 685th iteration of Bayesian optimization (alpha=0.25)...
# Running 686th iteration of Bayesian optimization (alpha=0.25)...
# Running 687th iteration of Bayesian optimization (alpha=0.25)...
# Running 688th iteration of Bayesian optimization (alpha=0.25)...
# Running 689th iteration of Bayesian optimization (alpha=0.25)...
# Running 690th iteration of Bayesian optimization (alpha=0.25)...
# Running 691th iteration of Bayesian optimization (alpha=0.25)...
# Running 692th iteration of Bayesian optimization (alpha=0.25)...
# Running 693th iteration of Bayesian optimization (alpha=0.25)...
# Running 694th iteration of Bayesian optimization (alpha=0.25)...
# Running 695th iteration of Bayesian optimization (alpha=0.25)...
# Running 696th iteration of Bayesian optimization (alpha=0.25)...
# Running 697th iteration of Bayesian optimization (alpha=0.25)...
# Running 698th iteration of Bayesian optimization (alpha=0.25)...
# Running 699th iteration of Bayesian optimization (alpha=0.25)...
# Running 700th iteration of Bayesian optimization (alpha=0.25)...
# Running 701th iteration of Bayesian optimization (alpha=0.25)...
# Running 702th iteration of Bayesian optimization (alpha=0.25)...
# Running 703th iteration of Bayesian optimization (alpha=0.25)...
# Running 704th iteration of Bayesian optimization (alpha=0.25)...
# Running 705th iteration of Bayesian optimization (alpha=0.25)...
# Running 706th iteration of Bayesian optimization (alpha=0.25)...
# Running 707th iteration of Bayesian optimization (alpha=0.25)...
# Running 708th iteration of Bayesian optimization (alpha=0.25)...
# Running 709th iteration of Bayesian optimization (alpha=0.25)...
# Running 710th iteration of Bayesian optimization (alpha=0.25)...
# Running 711th iteration of Bayesian optimization (alpha=0.25)...
# Running 712th iteration of Bayesian optimization (alpha=0.25)...
# Running 713th iteration of Bayesian optimization (alpha=0.25)...
# Running 714th iteration of Bayesian optimization (alpha=0.25)...
# Running 715th iteration of Bayesian optimization (alpha=0.25)...
# Running 716th iteration of Bayesian optimization (alpha=0.25)...
# Running 717th iteration of Bayesian optimization (alpha=0.25)...
# Running 718th iteration of Bayesian optimization (alpha=0.25)...
# Running 719th iteration of Bayesian optimization (alpha=0.25)...
# Running 720th iteration of Bayesian optimization (alpha=0.25)...
# Running 721th iteration of Bayesian optimization (alpha=0.25)...
# Running 722th iteration of Bayesian optimization (alpha=0.25)...
# Running 723th iteration of Bayesian optimization (alpha=0.25)...
# Running 724th iteration of Bayesian optimization (alpha=0.25)...
# Running 725th iteration of Bayesian optimization (alpha=0.25)...
# Running 726th iteration of Bayesian optimization (alpha=0.25)...
# Running 727th iteration of Bayesian optimization (alpha=0.25)...
# Running 728th iteration of Bayesian optimization (alpha=0.25)...
# Running 729th iteration of Bayesian optimization (alpha=0.25)...
# Running 730th iteration of Bayesian optimization (alpha=0.25)...
# Running 731th iteration of Bayesian optimization (alpha=0.25)...
# Running 732th iteration of Bayesian optimization (alpha=0.25)...
# Running 733th iteration of Bayesian optimization (alpha=0.25)...
# Running 734th iteration of Bayesian optimization (alpha=0.25)...
# Running 735th iteration of Bayesian optimization (alpha=0.25)...
# Running 736th iteration of Bayesian optimization (alpha=0.25)...
# Running 737th iteration of Bayesian optimization (alpha=0.25)...
# Running 738th iteration of Bayesian optimization (alpha=0.25)...
# ...
# Running 758th iteration of Bayesian optimization (alpha=1.0)...
# Running 759th iteration of Bayesian optimization (alpha=1.0)...
# Running 760th iteration of Bayesian optimization (alpha=1.0)...
# Running 761th iteration of Bayesian optimization (alpha=1.0)...
# Running 762th iteration of Bayesian optimization (alpha=1.0)...
# Running 763th iteration of Bayesian optimization (alpha=1.0)...
# Running 764th iteration of Bayesian optimization (alpha=1.0)...
# Running 765th iteration of Bayesian optimization (alpha=1.0)...
# Running 766th iteration of Bayesian optimization (alpha=1.0)...
# Running 767th iteration of Bayesian optimization (alpha=1.0)...
# Running 768th iteration of Bayesian optimization (alpha=1.0)...
# Running 769th iteration of Bayesian optimization (alpha=1.0)...
# Running 770th iteration of Bayesian optimization (alpha=1.0)...
# Running 771th iteration of Bayesian optimization (alpha=1.0)...
# Running 772th iteration of Bayesian optimization (alpha=1.0)...
# Running 773th iteration of Bayesian optimization (alpha=1.0)...
# Running 774th iteration of Bayesian optimization (alpha=1.0)...
# Running 775th iteration of Bayesian optimization (alpha=1.0)...
# Running 776th iteration of Bayesian optimization (alpha=1.0)...
# Running 777th iteration of Bayesian optimization (alpha=1.0)...
# Running 778th iteration of Bayesian optimization (alpha=1.0)...
# Running 779th iteration of Bayesian optimization (alpha=1.0)...
# Running 780th iteration of Bayesian optimization (alpha=1.0)...
# Running 781th iteration of Bayesian optimization (alpha=1.0)...
# Running 782th iteration of Bayesian optimization (alpha=1.0)...
# Running 783th iteration of Bayesian optimization (alpha=1.0)...
# Running 784th iteration of Bayesian optimization (alpha=1.0)...
# Running 785th iteration of Bayesian optimization (alpha=1.0)...
# Running 786th iteration of Bayesian optimization (alpha=1.0)...
# Running 787th iteration of Bayesian optimization (alpha=1.0)...
# Running 788th iteration of Bayesian optimization (alpha=1.0)...
# Running 789th iteration of Bayesian optimization (alpha=1.0)...
# Running 790th iteration of Bayesian optimization (alpha=1.0)...
# Running 791th iteration of Bayesian optimization (alpha=1.0)...
# Running 792th iteration of Bayesian optimization (alpha=1.0)...
# Running 793th iteration of Bayesian optimization (alpha=1.0)...
# Running 794th iteration of Bayesian optimization (alpha=1.0)...
# Running 795th iteration of Bayesian optimization (alpha=1.0)...
# Running 796th iteration of Bayesian optimization (alpha=1.0)...
# Running 797th iteration of Bayesian optimization (alpha=1.0)...
# Running 798th iteration of Bayesian optimization (alpha=1.0)...
# Running 799th iteration of Bayesian optimization (alpha=1.0)...
# Running 800th iteration of Bayesian optimization (alpha=1.0)...
# Running 801th iteration of Bayesian optimization (alpha=1.0)...
# Running 802th iteration of Bayesian optimization (alpha=1.0)...
# Running 803th iteration of Bayesian optimization (alpha=1.0)...
# Running 804th iteration of Bayesian optimization (alpha=1.0)...
# Running 805th iteration of Bayesian optimization (alpha=1.0)...
# Running 806th iteration of Bayesian optimization (alpha=1.0)...
# Running 807th iteration of Bayesian optimization (alpha=1.0)...
# Running 808th iteration of Bayesian optimization (alpha=1.0)...
# Running 809th iteration of Bayesian optimization (alpha=1.0)...
# Running 810th iteration of Bayesian optimization (alpha=1.0)...
# Running 811th iteration of Bayesian optimization (alpha=1.0)...
# Running 812th iteration of Bayesian optimization (alpha=1.0)...
# Running 813th iteration of Bayesian optimization (alpha=1.0)...
# Running 814th iteration of Bayesian optimization (alpha=1.0)...
# Running 815th iteration of Bayesian optimization (alpha=1.0)...
# Running 816th iteration of Bayesian optimization (alpha=1.0)...
# Running 817th iteration of Bayesian optimization (alpha=1.0)...
# Running 818th iteration of Bayesian optimization (alpha=1.0)...
# Running 819th iteration of Bayesian optimization (alpha=1.0)...
# Running 820th iteration of Bayesian optimization (alpha=1.0)...
# Running 821th iteration of Bayesian optimization (alpha=1.0)...
# Running 822th iteration of Bayesian optimization (alpha=1.0)...
# Running 823th iteration of Bayesian optimization (alpha=1.0)...
# Running 824th iteration of Bayesian optimization (alpha=1.0)...
# Running 825th iteration of Bayesian optimization (alpha=1.0)...
# Running 826th iteration of Bayesian optimization (alpha=1.0)...
# Running 827th iteration of Bayesian optimization (alpha=1.0)...
# Running 828th iteration of Bayesian optimization (alpha=1.0)...
# Running 829th iteration of Bayesian optimization (alpha=1.0)...
# Running 830th iteration of Bayesian optimization (alpha=1.0)...
# Running 831th iteration of Bayesian optimization (alpha=1.0)...
# Running 832th iteration of Bayesian optimization (alpha=1.0)...
# Running 833th iteration of Bayesian optimization (alpha=1.0)...
# Running 834th iteration of Bayesian optimization (alpha=1.0)...
# Running 835th iteration of Bayesian optimization (alpha=1.0)...
# Running 836th iteration of Bayesian optimization (alpha=1.0)...
# Running 837th iteration of Bayesian optimization (alpha=1.0)...
# Running 838th iteration of Bayesian optimization (alpha=1.0)...
# Running 839th iteration of Bayesian optimization (alpha=1.0)...
# Running 840th iteration of Bayesian optimization (alpha=1.0)...
# Running 841th iteration of Bayesian optimization (alpha=1.0)...
# Running 842th iteration of Bayesian optimization (alpha=1.0)...
# Running 843th iteration of Bayesian optimization (alpha=1.0)...
# Running 844th iteration of Bayesian optimization (alpha=1.0)...
# Running 845th iteration of Bayesian optimization (alpha=1.0)...
# Running 846th iteration of Bayesian optimization (alpha=1.0)...
# Running 847th iteration of Bayesian optimization (alpha=1.0)...
# Running 848th iteration of Bayesian optimization (alpha=1.0)...
# Running 849th iteration of Bayesian optimization (alpha=1.0)...
# Running 850th iteration of Bayesian optimization (alpha=1.0)...
# Running 851th iteration of Bayesian optimization (alpha=1.0)...
# Running 852th iteration of Bayesian optimization (alpha=1.0)...
# Running 853th iteration of Bayesian optimization (alpha=1.0)...
# Running 854th iteration of Bayesian optimization (alpha=1.0)...
# Running 855th iteration of Bayesian optimization (alpha=1.0)...
# Running 856th iteration of Bayesian optimization (alpha=1.0)...
# Running 857th iteration of Bayesian optimization (alpha=1.0)...
# Running 858th iteration of Bayesian optimization (alpha=1.0)...
# Running 859th iteration of Bayesian optimization (alpha=1.0)...
# Running 860th iteration of Bayesian optimization (alpha=1.0)...
# Running 861th iteration of Bayesian optimization (alpha=1.0)...
# Running 862th iteration of Bayesian optimization (alpha=1.0)...
# Running 863th iteration of Bayesian optimization (alpha=1.0)...
# Running 864th iteration of Bayesian optimization (alpha=1.0)...
# Running 865th iteration of Bayesian optimization (alpha=1.0)...
# Running 866th iteration of Bayesian optimization (alpha=1.0)...
# Running 867th iteration of Bayesian optimization (alpha=1.0)...
# Running 868th iteration of Bayesian optimization (alpha=1.0)...
# Running 869th iteration of Bayesian optimization (alpha=1.0)...
# Running 870th iteration of Bayesian optimization (alpha=1.0)...
# Running 871th iteration of Bayesian optimization (alpha=1.0)...
# Running 872th iteration of Bayesian optimization (alpha=1.0)...
# Running 873th iteration of Bayesian optimization (alpha=1.0)...
# Running 874th iteration of Bayesian optimization (alpha=1.0)...
# Running 875th iteration of Bayesian optimization (alpha=1.0)...
# Running 876th iteration of Bayesian optimization (alpha=1.0)...
# Running 877th iteration of Bayesian optimization (alpha=1.0)...
# Running 878th iteration of Bayesian optimization (alpha=1.0)...
# Running 879th iteration of Bayesian optimization (alpha=1.0)...
# Running 880th iteration of Bayesian optimization (alpha=1.0)...
# Running 881th iteration of Bayesian optimization (alpha=1.0)...
# Running 882th iteration of Bayesian optimization (alpha=1.0)...
# Running 883th iteration of Bayesian optimization (alpha=1.0)...
# Running 884th iteration of Bayesian optimization (alpha=1.0)...
# Running 885th iteration of Bayesian optimization (alpha=1.0)...
# Running 886th iteration of Bayesian optimization (alpha=1.0)...
# Running 887th iteration of Bayesian optimization (alpha=1.0)...
# Running 888th iteration of Bayesian optimization (alpha=1.0)...
# Running 889th iteration of Bayesian optimization (alpha=1.0)...
# Running 890th iteration of Bayesian optimization (alpha=1.0)...
# Running 891th iteration of Bayesian optimization (alpha=1.0)...
# Running 892th iteration of Bayesian optimization (alpha=1.0)...
# Running 893th iteration of Bayesian optimization (alpha=1.0)...
# Running 894th iteration of Bayesian optimization (alpha=1.0)...
# Running 895th iteration of Bayesian optimization (alpha=1.0)...
# Running 896th iteration of Bayesian optimization (alpha=1.0)...
# Running 897th iteration of Bayesian optimization (alpha=1.0)...
# Running 898th iteration of Bayesian optimization (alpha=1.0)...
# Running 899th iteration of Bayesian optimization (alpha=1.0)...
# Running 900th iteration of Bayesian optimization (alpha=1.0)...
# Running 901th iteration of Bayesian optimization (alpha=1.0)...
# Running 902th iteration of Bayesian optimization (alpha=1.0)...
# Running 903th iteration of Bayesian optimization (alpha=1.0)...
# Running 904th iteration of Bayesian optimization (alpha=1.0)...
# Running 905th iteration of Bayesian optimization (alpha=1.0)...
# Running 906th iteration of Bayesian optimization (alpha=1.0)...
# Running 907th iteration of Bayesian optimization (alpha=1.0)...
# Running 908th iteration of Bayesian optimization (alpha=1.0)...
# Running 909th iteration of Bayesian optimization (alpha=1.0)...
# Running 910th iteration of Bayesian optimization (alpha=1.0)...
# Running 911th iteration of Bayesian optimization (alpha=1.0)...
# Running 912th iteration of Bayesian optimization (alpha=1.0)...
# Running 913th iteration of Bayesian optimization (alpha=1.0)...
# Running 914th iteration of Bayesian optimization (alpha=1.0)...
# Running 915th iteration of Bayesian optimization (alpha=1.0)...
# Running 916th iteration of Bayesian optimization (alpha=1.0)...
# Running 917th iteration of Bayesian optimization (alpha=1.0)...
# Running 918th iteration of Bayesian optimization (alpha=1.0)...
# Running 919th iteration of Bayesian optimization (alpha=1.0)...
# Running 920th iteration of Bayesian optimization (alpha=1.0)...
# Running 921th iteration of Bayesian optimization (alpha=1.0)...
# Running 922th iteration of Bayesian optimization (alpha=1.0)...
# Running 923th iteration of Bayesian optimization (alpha=1.0)...
# Running 924th iteration of Bayesian optimization (alpha=1.0)...
# Running 925th iteration of Bayesian optimization (alpha=1.0)...
# Running 926th iteration of Bayesian optimization (alpha=1.0)...
# Running 927th iteration of Bayesian optimization (alpha=1.0)...
# Running 928th iteration of Bayesian optimization (alpha=1.0)...
# Running 929th iteration of Bayesian optimization (alpha=1.0)...
# Running 930th iteration of Bayesian optimization (alpha=1.0)...
# Running 931th iteration of Bayesian optimization (alpha=1.0)...
# Running 932th iteration of Bayesian optimization (alpha=1.0)...
# Running 933th iteration of Bayesian optimization (alpha=1.0)...
# Running 934th iteration of Bayesian optimization (alpha=1.0)...
# Running 935th iteration of Bayesian optimization (alpha=1.0)...
# Running 936th iteration of Bayesian optimization (alpha=1.0)...
# Running 937th iteration of Bayesian optimization (alpha=1.0)...
# Running 938th iteration of Bayesian optimization (alpha=1.0)...
# Running 939th iteration of Bayesian optimization (alpha=1.0)...
# Running 940th iteration of Bayesian optimization (alpha=1.0)...
# Running 941th iteration of Bayesian optimization (alpha=1.0)...
# Running 942th iteration of Bayesian optimization (alpha=1.0)...
# Running 943th iteration of Bayesian optimization (alpha=1.0)...
# Running 944th iteration of Bayesian optimization (alpha=1.0)...
# Running 945th iteration of Bayesian optimization (alpha=1.0)...
# Running 946th iteration of Bayesian optimization (alpha=1.0)...
# Running 947th iteration of Bayesian optimization (alpha=1.0)...
# Running 948th iteration of Bayesian optimization (alpha=1.0)...
# Running 949th iteration of Bayesian optimization (alpha=1.0)...
# Running 950th iteration of Bayesian optimization (alpha=1.0)...
# Running 951th iteration of Bayesian optimization (alpha=1.0)...
# Running 952th iteration of Bayesian optimization (alpha=1.0)...
# Running 953th iteration of Bayesian optimization (alpha=1.0)...
# Running 954th iteration of Bayesian optimization (alpha=1.0)...
# Running 955th iteration of Bayesian optimization (alpha=1.0)...
# Running 956th iteration of Bayesian optimization (alpha=1.0)...
# Running 957th iteration of Bayesian optimization (alpha=1.0)...
# Running 958th iteration of Bayesian optimization (alpha=1.0)...
# Running 959th iteration of Bayesian optimization (alpha=1.0)...
# Running 960th iteration of Bayesian optimization (alpha=1.0)...
# Running 961th iteration of Bayesian optimization (alpha=1.0)...
# Running 962th iteration of Bayesian optimization (alpha=1.0)...
# Running 963th iteration of Bayesian optimization (alpha=1.0)...
# Running 964th iteration of Bayesian optimization (alpha=1.0)...
# Running 965th iteration of Bayesian optimization (alpha=1.0)...
# Running 966th iteration of Bayesian optimization (alpha=1.0)...
# Running 967th iteration of Bayesian optimization (alpha=1.0)...
# Running 968th iteration of Bayesian optimization (alpha=1.0)...
# Running 969th iteration of Bayesian optimization (alpha=1.0)...
# Running 970th iteration of Bayesian optimization (alpha=1.0)...
# Running 971th iteration of Bayesian optimization (alpha=1.0)...
# Running 972th iteration of Bayesian optimization (alpha=1.0)...
# Running 973th iteration of Bayesian optimization (alpha=1.0)...
# Running 974th iteration of Bayesian optimization (alpha=1.0)...
# Running 975th iteration of Bayesian optimization (alpha=1.0)...
# Running 976th iteration of Bayesian optimization (alpha=1.0)...
# Running 977th iteration of Bayesian optimization (alpha=1.0)...
# Running 978th iteration of Bayesian optimization (alpha=1.0)...
# Running 979th iteration of Bayesian optimization (alpha=1.0)...
# Running 980th iteration of Bayesian optimization (alpha=1.0)...
# Running 981th iteration of Bayesian optimization (alpha=1.0)...
# Running 982th iteration of Bayesian optimization (alpha=1.0)...
# Running 983th iteration of Bayesian optimization (alpha=1.0)...
# Running 984th iteration of Bayesian optimization (alpha=1.0)...
# Running 985th iteration of Bayesian optimization (alpha=1.0)...
# Running 986th iteration of Bayesian optimization (alpha=1.0)...
# Running 987th iteration of Bayesian optimization (alpha=1.0)...
# Running 988th iteration of Bayesian optimization (alpha=1.0)...
# Running 989th iteration of Bayesian optimization (alpha=1.0)...
# Running 990th iteration of Bayesian optimization (alpha=1.0)...
# Running 991th iteration of Bayesian optimization (alpha=1.0)...
# Running 992th iteration of Bayesian optimization (alpha=1.0)...
# Running 993th iteration of Bayesian optimization (alpha=1.0)...
# Running 994th iteration of Bayesian optimization (alpha=1.0)...
# Running 995th iteration of Bayesian optimization (alpha=1.0)...
# Running 996th iteration of Bayesian optimization (alpha=1.0)...
# Running 997th iteration of Bayesian optimization (alpha=1.0)...
# Running 998th iteration of Bayesian optimization (alpha=1.0)...
# Running 999th iteration of Bayesian optimization (alpha=1.0)...
# Optimization complete. Plotting optimization performance...
# Plotting optimization images...
# Running final simulation...
# Final atom number: 4.22e+05
# Final temperature: 2.43e-08 K
# Final phase space density: 1.20e+05
# Final BEC fraction: 100.00%
#
# Optimized Parameters:
# P_y: 8.8740e-02
# P_z: 3.0739e-01
# P_R: 3.6050e-03
# P_p: 7.3624e-04
# B_z: 0.0000e+00
# trap_freq_x: 2.5431e+02
# trap_freq_y: 2.1028e+02
# trap_freq_z: 6.8941e+02
# loading_rate: 2.8718e+05
#
# Plotting OD comparison for different alpha values...
