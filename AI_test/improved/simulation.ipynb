# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import imageio
from scipy.integrate import solve_ivp
from scipy.ndimage import gaussian_filter
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation
from sklearn.linear_model import RANSACRegressor
import warnings
from scipy.constants import h, hbar, k, atomic_mass, mu_0, epsilon_0, g
from scipy.special import zeta

class BECSimulation:
    def __init__(self):
        self.m = 87 * atomic_mass  # Mass of Rb-87 atom in kg
        self.a = 5.77e-9  # Scattering length for Rb-87
        self.wavelength = 780e-9  # Wavelength of cooling light
        self.k_L = 2 * np.pi / self.wavelength

        self.stages = []
        total_time = 0
        for stage_info in [
            {'name': 'MOT', 'duration': 99e-3},
            {'name': 'Raman1', 'duration': 63e-3},
            {'name': 'Raman2', 'duration': 63e-3},
            {'name': 'Raman3', 'duration': 63e-3},
            {'name': 'Raman4', 'duration': 63e-3},
            {'name': 'Raman5', 'duration': 63e-3},
            {'name': 'Evap1', 'duration': 27e-3},
            {'name': 'Evap2', 'duration': 27e-3},
            {'name': 'Evap3', 'duration': 27e-3},
            {'name': 'Evap4', 'duration': 27e-3},
            {'name': 'Evap5', 'duration': 27e-3},
            {'name': 'Evap6', 'duration': 27e-3},
        ]:
            stage = stage_info.copy()
            stage['start_time'] = total_time
            total_time += stage['duration']
            stage['end_time'] = total_time
            self.stages.append(stage)

        self.params = {
            'initial_N': 2.7e5,  # Initial atom number from paper
            'initial_T': 5e-6,  # Initial temperature (5 µK, estimated)
            'gamma_bg': 0.05,  # Background loss rate
            'wx': 18e-6,  # 18 µm horizontal beam waist
            'wy': 14e-6,  # 14 µm vertical beam waist
            'w_R': 500e-6,  # Raman beam waist
            'theta_R': np.pi/4,  # Angle between Raman beams
            'B_bias': 20.8e-4,  # Bias field (20.8 G) from paper
            'K2': 1e-16,  # Two-body loss coefficient (m^3/s)
            'eta_load': 0.5,  # Trap loading efficiency
            'intensity_noise': 1e-4,  # Relative intensity noise
            'anharmonicity': 1e-15,  # Anharmonicity coefficient
            'phase_noise_amplitude': 0.1,  # Radians
            'freq_noise_amplitude': 1e3,  # Hz
            'Omega_R_0': 2 * np.pi * 50e3,  # Base Raman Rabi frequency
            'interaction_shift': -1.33,  # Interaction shift to critical temperature
            'atom_number_calibration': 1.0,  # Atom number calibration factor
            'atom_number_uncertainty': 0.1,  # 10% uncertainty in atom number
            'B_field_fluctuation': 1e-7,  # 100 nT magnetic field fluctuation
            'imaging_resolution': 5e-6,  # 5 µm imaging resolution
        }

        for i, stage in enumerate(self.stages):
            if stage['name'].startswith('Raman'):
                self.params[f'{stage["name"]}_P_x'] = 1.0 - 0.15 * i
                self.params[f'{stage["name"]}_P_y'] = 1.0 - 0.15 * i
                self.params[f'{stage["name"]}_Omega_R'] = 2 * np.pi * (15e3 - 1e3 * i)
                self.params[f'{stage["name"]}_Gamma_OP'] = 2 * np.pi * (2e3 - 200 * i)
                self.params[f'{stage["name"]}_delta'] = 2 * np.pi * 4.33e9  # 4.33 GHz detuning from paper
            elif stage['name'].startswith('Evap'):
                self.params[f'{stage["name"]}_eta'] = 7 - 0.3 * i
                self.params[f'{stage["name"]}_P_x'] = 1.0 - 0.15 * i
                self.params[f'{stage["name"]}_P_y'] = 1.0 - 0.20 * i

    def trap_frequencies(self, P_x, P_y, t):
        U_x = max(1e-10, 1e-6 * P_x * (1 - 0.5 * t / self.stages[-1]['end_time']))
        U_y = max(1e-10, 1e-6 * P_y * (1 - 0.5 * t / self.stages[-1]['end_time']))

        nu_x = max(1, np.sqrt(4 * U_x / (self.m * self.params['wx']**2)) / (2 * np.pi))
        nu_y = max(1, np.sqrt(4 * U_y / (self.m * self.params['wy']**2)) / (2 * np.pi))
        nu_z = max(1, np.sqrt(2 * g / (self.params['wx'] + self.params['wy'])) / (2 * np.pi))

        # Implement adaptive adjustment to match paper's frequencies
        nu_mean = np.mean([nu_x, nu_y, nu_z])
        target_freq = max(1, 185 * (1 - 0.8 * t / self.stages[-1]['end_time']))
        adjustment = target_freq / nu_mean
        return nu_x * adjustment, nu_y * adjustment, nu_z * adjustment

    def collision_rate(self, N, T, nu_x, nu_y, nu_z):
        nu_mean = np.mean([nu_x, nu_y, nu_z])
        n0 = N * (self.m * nu_mean**2 / (2 * np.pi * k * T))**(3/2)
        v_mean = np.sqrt(8 * k * T / (np.pi * self.m))
        return 8 * np.pi * self.a**2 * n0 * v_mean

    def psd(self, N, T, nu_x, nu_y, nu_z):
        return N * (h * np.mean([nu_x, nu_y, nu_z]) / (k * T))**3

    def bec_fraction(self, N, T, nu_x, nu_y, nu_z):
        Tc = self.critical_temperature(N, nu_x, nu_y, nu_z)
        if T >= Tc:
            return 0
        else:
            return max(0, 1 - (T / Tc)**3)

    def raman_cooling_rate(self, T, Omega_R, Gamma_OP, delta):
        recoil_energy = (h ** 2) / (2 * self.m * self.wavelength ** 2)
        eta = recoil_energy / (k * T)
        return 200 * eta * Omega_R**2 * Gamma_OP / (4 * delta**2) * np.sqrt(self.m / (2 * k * T)) * (1 + (T / (1e-6))**2)

    def heating_rate(self, N, T, nu_x, nu_y, nu_z):
        nu_mean = np.mean([nu_x, nu_y, nu_z])
        return 2 * h * nu_mean * self.collision_rate(N, T, nu_x, nu_y, nu_z) / (3 * k)

    def light_assisted_loss_rate(self, N, T, nu_x, nu_y, nu_z, Gamma_OP):
        nu_mean = np.mean([nu_x, nu_y, nu_z])
        n0 = N * (self.m * nu_mean**2 / (2 * np.pi * k * T))**(3/2)
        beta = 1e-12  # Increased from 5e-13
        return beta * Gamma_OP * n0 * (T / (1e-6))**0.5

    def evaporation_rate(self, N, T, nu_x, nu_y, nu_z, eta, t):
        tilt_factor = 10.0  # Increased from 5.0
        gravity_assist = 1 + 2 * np.sin(np.pi * t / self.stages[-1]['end_time'])  # Increased amplitude
        return tilt_factor * gravity_assist * self.collision_rate(N, T, nu_x, nu_y, nu_z) * eta * np.exp(-eta) * (eta - 4) / (eta - 5)

    def critical_temperature(self, N, nu_x, nu_y, nu_z):
        omega_mean = 2 * np.pi * np.mean([nu_x, nu_y, nu_z])
        
        # Prevent division by zero and negative values
        N = max(N, 1e-10)
        nu_x = max(nu_x, 1e-10)
        nu_y = max(nu_y, 1e-10)
        nu_z = max(nu_z, 1e-10)
        
        Tc_ideal = hbar * omega_mean * (N / zeta(3))**(1/3) / k
        
        # Finite size correction
        delta_Tc_fs = -0.73 * (omega_mean / (2*np.pi*nu_x) + omega_mean / (2*np.pi*nu_y) + omega_mean / (2*np.pi*nu_z)) * Tc_ideal / N**(1/3)
        
        # Interaction shift
        a_ho = np.sqrt(hbar / (self.m * omega_mean))
        delta_Tc_int = -1.33 * Tc_ideal * (N**(1/6) * self.a / a_ho)
        
        return max(Tc_ideal + delta_Tc_fs + delta_Tc_int, 1e-10)  # Ensure positive temperature

    def system_evolution(self, t, state):
        N, T = state
        N = max(N, 1e-10)  # Prevent N from becoming too small
        T = max(T, 1e-10)  # Prevent T from becoming too small

        stage = next((s for s in self.stages if s['start_time'] <= t < s['end_time']), self.stages[-1])

        P_x = self.params[f'{stage["name"]}_P_x'] if f'{stage["name"]}_P_x' in self.params else 1.0
        P_y = self.params[f'{stage["name"]}_P_y'] if f'{stage["name"]}_P_y' in self.params else 1.0
        nu_x, nu_y, nu_z = self.trap_frequencies(P_x, P_y, t)

        print(f"Time: {t*1e3:.1f} ms, Stage: {stage['name']}, N: {N:.2e}, T: {T*1e6:.2f} µK")
        print(f"Trap frequencies: nu_x = {nu_x:.2f} Hz, nu_y = {nu_y:.2f} Hz, nu_z = {nu_z:.2f} Hz")

        # Smooth transition between Raman and evaporative cooling
        raman_weight = 1.0 if stage['name'].startswith('Raman') else 0.0
        evap_weight = 1.0 if stage['name'].startswith('Evap') else 0.0
        if stage['name'].startswith('Evap'):
            raman_weight = max(0, 1 - (t - stage['start_time']) / (stage['end_time'] - stage['start_time']))
            evap_weight = 1 - raman_weight

        Omega_R = self.params['Omega_R_0'] * raman_weight
        Gamma_OP = 2 * np.pi * 2000 * raman_weight
        delta = 2 * np.pi * 4.33e9
        eta = 7 * evap_weight

        gamma_cool = self.raman_cooling_rate(T, Omega_R, Gamma_OP, delta) * raman_weight
        gamma_heat = self.heating_rate(N, T, nu_x, nu_y, nu_z)
        gamma_evap = self.evaporation_rate(N, T, nu_x, nu_y, nu_z, eta, t) * evap_weight

        dNdt = max(-0.1 * N, -self.params['gamma_bg'] * N - self.light_assisted_loss_rate(N, T, nu_x, nu_y, nu_z, Gamma_OP) * raman_weight - gamma_evap * N * evap_weight)
        dTdt = max(-0.1 * T, -gamma_cool * T + gamma_heat - (eta - 3) / 3 * gamma_evap * T * evap_weight)

        print(f"Raman cooling: gamma_cool = {gamma_cool:.2e}, gamma_heat = {gamma_heat:.2e}")
        print(f"Evaporation: gamma_evap = {gamma_evap:.2e}")
        print(f"dNdt = {dNdt:.2e}, dTdt = {dTdt:.2e}")

        return [dNdt, dTdt]

    def calculate_cooling_slope(self, results):
        if len(results) < 3:
            return float('nan')
        log_psd = np.log10([max(r['PSD'], 1e-10) for r in results])
        log_N = np.log10([max(r['N'], 1e-10) for r in results])
        weights = np.array([r['N'] for r in results])  # Use atom number as weight

        # Remove any non-finite values
        mask = np.isfinite(log_psd) & np.isfinite(log_N) & np.isfinite(weights)
        log_psd = log_psd[mask]
        log_N = log_N[mask]
        weights = weights[mask]

        if len(log_psd) < 3:
            return float('nan')

        try:
            with warnings.catch_warnings():
                warnings.simplefilter('ignore', np.RankWarning)
                slope, _ = np.polyfit(log_N, log_psd, 1, w=weights)
            return -slope
        except (ValueError, np.linalg.LinAlgError):
            return float('nan')

    def run_simulation(self):
        t_span = (0, self.stages[-1]['end_time'])
        t_eval = np.linspace(0, t_span[1], 1000)

        def event_stage_change(t, y):
            for stage in self.stages:
                if stage['end_time'] > t:
                    return t - stage['end_time']
            return 0

        event_stage_change.terminal = True
        event_stage_change.direction = 1

        sol = solve_ivp(
            self.system_evolution,
            t_span,
            [self.params['initial_N'], self.params['initial_T']],
            t_eval=t_eval,
            method='RK45',
            events=event_stage_change,
            rtol=1e-8,
            atol=1e-8
        )

        results = []
        for t, N, T in zip(sol.t, sol.y[0], sol.y[1]):
            stage = next((s for s in self.stages if s['start_time'] <= t <= s['end_time']), self.stages[-1])
            P_x = self.params[f'{stage["name"]}_P_x'] if f'{stage["name"]}_P_x' in self.params else 1.0
            P_y = self.params[f'{stage["name"]}_P_y'] if f'{stage["name"]}_P_y' in self.params else 1.0
            nu_x, nu_y, nu_z = self.trap_frequencies(P_x, P_y, t)
            nu_c = self.collision_rate(N, T, nu_x, nu_y, nu_z)
            psd = self.psd(N, T, nu_x, nu_y, nu_z)
            bec_frac = self.bec_fraction(N, T, nu_x, nu_y, nu_z)

            results.append({
                'time': t,
                'stage': stage['name'],
                'N': N,
                'T': T,
                'PSD': psd,
                'nu_x': nu_x,
                'nu_y': nu_y,
                'nu_z': nu_z,
                'nu_c': nu_c,
                'BEC_fraction': bec_frac
            })

        return results

class BECVisualizer:
    def __init__(self, simulation):
        self.sim = simulation
        self.imaging_resolution = 5e-6  # 5 micrometers
        self.tof = 20e-3  # 20 ms time-of-flight
        self.vmin = None
        self.vmax = None
        self.xlim = (-1000e-6, 1000e-6)  # ±1000 µm x-axis range
        self.ylim = (-1000e-6, 1000e-6)  # ±1000 µm y-axis range

    def calculate_density_range(self, results):
        densities = []
        for result in results:
            if result['stage'] != 'MOT':  # Only consider frames after MOT
                frame_data = self.generate_frame(result)
                densities.extend(frame_data.flatten())
        self.vmin = np.min(densities)
        self.vmax = np.max(densities)

    def generate_frame(self, result, grid_size=200):
        x = np.linspace(self.xlim[0], self.xlim[1], grid_size)
        y = np.linspace(self.ylim[0], self.ylim[1], grid_size)
        X, Y = np.meshgrid(x, y)

        N, T = result['N'], result['T']
        nu_x, nu_y, nu_z = result['nu_x'], result['nu_y'], result['nu_z']
        bec_fraction = result['BEC_fraction']

        nu_x = max(nu_x, 1e-10)
        nu_y = max(nu_y, 1e-10)

        sigma_x = np.sqrt(k * T / (self.sim.m * (2*np.pi*nu_x)**2) + (h * nu_x / (2*np.pi*self.sim.m))**2 * self.tof**2)
        sigma_y = np.sqrt(k * T / (self.sim.m * (2*np.pi*nu_y)**2) + (h * nu_y / (2*np.pi*self.sim.m))**2 * self.tof**2)

        n_thermal = N * (1 - bec_fraction) * np.exp(-(X**2 / (2*sigma_x**2) + Y**2 / (2*sigma_y**2))) / (2*np.pi*sigma_x*sigma_y)
        
        if bec_fraction > 0:
            R_x = np.sqrt(2 * h * nu_x * N * bec_fraction * self.sim.a / (self.sim.m * (2*np.pi*nu_x)**2))
            R_y = np.sqrt(2 * h * nu_y * N * bec_fraction * self.sim.a / (self.sim.m * (2*np.pi*nu_y)**2))
            n_bec = N * bec_fraction * np.maximum(0, 1 - X**2/R_x**2 - Y**2/R_y**2)**(3/2) / (4*np.pi*R_x*R_y/3)
        else:
            n_bec = np.zeros_like(X)

        n_total = n_thermal + n_bec

        # Calculate column density (integrate along z-axis)
        column_density = n_total * np.sqrt(2 * np.pi) * sigma_y

        # Calculate optical depth
        cross_section = 3 * (780e-9)**2 / (2 * np.pi)  # Absorption cross-section for Rb87
        od = column_density * cross_section

        # Add realistic noise
        od_with_noise = od + np.random.normal(0, 0.05 * np.max(od), od.shape)

        # Simulate finite imaging resolution
        od_blurred = gaussian_filter(od_with_noise, sigma=self.imaging_resolution / (self.xlim[1] - self.xlim[0]) * grid_size)

        od_blurred = np.clip(od_blurred, 1e-10, np.inf)

        return od_blurred

    def create_animation(self, results, output_filename):
        fig, ax = plt.subplots(figsize=(10, 8))

        # Calculate global vmin and vmax for frames after MOT
        self.calculate_density_range(results)
        
        def update(frame):
            ax.clear()
            result = results[frame]
            frame_data = self.generate_frame(result)
            
            if result['stage'] == 'MOT':
                im = ax.imshow(frame_data, cmap='jet', norm=LogNorm(), extent=[self.xlim[0]*1e6, self.xlim[1]*1e6, self.ylim[0]*1e6, self.ylim[1]*1e6])
            else:
                im = ax.imshow(frame_data, cmap='jet', norm=LogNorm(vmin=self.vmin, vmax=self.vmax), extent=[self.xlim[0]*1e6, self.xlim[1]*1e6, self.ylim[0]*1e6, self.ylim[1]*1e6])
            
            ax.set_title(f"Time: {result['time']*1e3:.1f} ms, Stage: {result['stage']}\n"
                         f"T: {result['T']*1e6:.2f} µK, N: {result['N']:.2e}, "
                         f"BEC fraction: {result['BEC_fraction']:.2%}")
            ax.set_xlabel('x (µm)')
            ax.set_ylabel('y (µm)')
            return [im]

        anim = FuncAnimation(fig, update, frames=len(results), interval=200, blit=True)
        
        writer = animation.FFMpegWriter(fps=5, metadata=dict(artist='Me'), bitrate=1800)
        anim.save(output_filename, writer=writer)
        
        plt.close(fig)

# Main script
if __name__ == "__main__":
    # Run simulation and create visualization
    sim = BECSimulation()
    results = sim.run_simulation()

    visualizer = BECVisualizer(sim)
    visualizer.create_animation(results, 'bec_evolution.mp4')

    print("Animation creation complete. Check 'bec_evolution.mp4'.")

    # Plot additional results
    times = [result['time'] * 1e3 for result in results]  # Convert to ms
    N_values = [result['N'] for result in results]
    T_values = [result['T'] for result in results]
    PSD_values = [result['PSD'] for result in results]
    BEC_fraction_values = [result['BEC_fraction'] for result in results]

    plt.figure(figsize=(12, 10))

    plt.subplot(4, 1, 1)
    plt.semilogy(times, N_values)
    plt.ylabel('Atom Number')
    plt.title('BEC Formation Simulation Results')

    plt.subplot(4, 1, 2)
    plt.semilogy(times, T_values)
    plt.ylabel('Temperature (K)')

    plt.subplot(4, 1, 3)
    plt.semilogy(times, PSD_values)
    plt.ylabel('Phase Space Density')

    plt.subplot(4, 1, 4)
    plt.plot(times, BEC_fraction_values)
    plt.ylabel('BEC Fraction')
    plt.xlabel('Time (ms)')

    plt.tight_layout()
    plt.savefig('bec_formation_results.png')
    plt.close()

    print("Additional results plot saved as 'bec_formation_results.png'.")

    # Print final results
    final_result = results[-1]
    print(f"Final atom number: {final_result['N']:.2e}")
    print(f"Final temperature: {final_result['T']*1e6:.2f} µK")
    print(f"Final BEC fraction: {final_result['BEC_fraction']:.2%}")
    print(f"Final phase space density: {final_result['PSD']:.2e}")

    # Calculate and print the cooling slope for different stages
    raman_start = next(r for r in results if r['stage'] == 'Raman1')
    raman_end = next(r for r in results if r['stage'] == 'Evap1')
    evap_start = raman_end
    evap_end = results[-1]

    raman_slope = sim.calculate_cooling_slope([r for r in results if raman_start['time'] <= r['time'] < raman_end['time']])
    evap_slope = sim.calculate_cooling_slope([r for r in results if evap_start['time'] <= r['time'] <= evap_end['time']])
    overall_slope = sim.calculate_cooling_slope(results)

    print(f"Raman cooling slope γ: {raman_slope:.2f}")
    print(f"Evaporative cooling slope γ: {evap_slope:.2f}")
    print(f"Overall cooling slope γ: {overall_slope:.2f}")

    # Compare with paper results
    paper_final_N = 2.8e3
    paper_final_BEC_fraction = 0.76

    N_difference = (final_result['N'] - paper_final_N) / paper_final_N * 100
    BEC_fraction_difference = (final_result['BEC_fraction'] - paper_final_BEC_fraction) / paper_final_BEC_fraction * 100

    print(f"Comparison with paper results:")
    print(f"Final atom number: {final_result['N']:.2e} (Difference: {N_difference:.2f}%)")
    print(f"Final BEC fraction: {final_result['BEC_fraction']:.2%} (Difference: {BEC_fraction_difference:.2f}%)")
    print(f"Paper reported cooling slope γ: ~16")
    print(f"Our overall cooling slope γ: {overall_slope:.2f}")

    # Plot cooling process
    plt.figure(figsize=(12, 8))
    for stage in sim.stages:
        stage_results = [r for r in results if r['stage'] == stage['name']]
        if stage_results:
            log_psd = np.log10([max(r['PSD'], 1e-10) for r in stage_results])
            log_N = np.log10([max(r['N'], 1e-10) for r in stage_results])
            plt.plot(log_N, log_psd, 'o-', label=stage['name'])

    plt.xlabel('log(N)')
    plt.ylabel('log(PSD)')
    plt.legend()
    plt.title('Cooling Process: PSD vs N')
    plt.savefig('cooling_process.png')
    plt.close()

    print("Cooling process plot saved as 'cooling_process.png'.")
# Out:
# Time: 0.0 ms, Stage: MOT, N: 2.70e+05, T: 5.00 µK
# Trap frequencies: nu_x = 242.81 Hz, nu_y = 312.19 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.80e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.80e-09
# Time: 200.0 ms, Stage: Raman2, N: 2.67e+05, T: 5.00 µK
# Trap frequencies: nu_x = 175.36 Hz, nu_y = 225.47 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 4.84e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.67e+04, dTdt = -1.23e-08
# Time: 2.8 ms, Stage: MOT, N: 2.70e+05, T: 5.00 µK
# Trap frequencies: nu_x = 241.85 Hz, nu_y = 310.96 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.77e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.77e-09
# Time: 4.3 ms, Stage: MOT, N: 2.70e+05, T: 5.00 µK
# Trap frequencies: nu_x = 241.38 Hz, nu_y = 310.34 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.75e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.75e-09
# Time: 11.4 ms, Stage: MOT, N: 2.70e+05, T: 5.00 µK
# Trap frequencies: nu_x = 238.98 Hz, nu_y = 307.26 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.68e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.68e-09
# Time: 12.6 ms, Stage: MOT, N: 2.70e+05, T: 5.00 µK
# Trap frequencies: nu_x = 238.56 Hz, nu_y = 306.71 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.67e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.67e-09
# Time: 14.2 ms, Stage: MOT, N: 2.70e+05, T: 5.00 µK
# Trap frequencies: nu_x = 238.02 Hz, nu_y = 306.03 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.66e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.66e-09
# Time: 14.2 ms, Stage: MOT, N: 2.70e+05, T: 5.00 µK
# Trap frequencies: nu_x = 238.02 Hz, nu_y = 306.03 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.66e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.66e-09
# Time: 42.6 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 228.45 Hz, nu_y = 293.72 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.40e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.40e-09
# Time: 56.8 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 223.66 Hz, nu_y = 287.56 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.29e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.29e-09
# Time: 127.8 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 199.72 Hz, nu_y = 256.78 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 8.16e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.19e-08
# Time: 140.4 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 195.46 Hz, nu_y = 251.30 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 7.50e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.20e-08
# Time: 156.2 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 190.14 Hz, nu_y = 244.46 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 6.70e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.21e-08
# Time: 156.2 ms, Stage: Raman1, N: 2.67e+05, T: 5.00 µK
# Trap frequencies: nu_x = 190.14 Hz, nu_y = 244.46 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 6.68e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.67e+04, dTdt = -1.21e-08
# Time: 20.1 ms, Stage: MOT, N: 2.70e+05, T: 5.00 µK
# Trap frequencies: nu_x = 236.02 Hz, nu_y = 303.46 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.60e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.60e-09
# Time: 23.1 ms, Stage: MOT, N: 2.70e+05, T: 5.00 µK
# Trap frequencies: nu_x = 235.02 Hz, nu_y = 302.17 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.57e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.57e-09
# Time: 37.9 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 230.02 Hz, nu_y = 295.75 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.44e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.44e-09
# Time: 40.6 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 229.14 Hz, nu_y = 294.60 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.42e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.42e-09
# Time: 43.9 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 228.02 Hz, nu_y = 293.17 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.39e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.39e-09
# Time: 43.9 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 228.02 Hz, nu_y = 293.17 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.39e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.39e-09
# Time: 49.8 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 226.02 Hz, nu_y = 290.60 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.34e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.34e-09
# Time: 52.7 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 225.02 Hz, nu_y = 289.32 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.32e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.32e-09
# Time: 67.6 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 220.02 Hz, nu_y = 282.89 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.21e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.21e-09
# Time: 70.2 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 219.14 Hz, nu_y = 281.75 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.19e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.19e-09
# Time: 73.5 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 218.02 Hz, nu_y = 280.32 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.16e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.16e-09
# Time: 73.5 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 218.02 Hz, nu_y = 280.32 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.16e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.35e+04, dTdt = 1.16e-09
# Time: 132.8 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 198.02 Hz, nu_y = 254.60 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 7.89e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.20e-08
# Time: 162.5 ms, Stage: Raman2, N: 2.67e+05, T: 5.00 µK
# Trap frequencies: nu_x = 188.02 Hz, nu_y = 241.75 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 6.38e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.67e+04, dTdt = -1.21e-08
# Time: 310.7 ms, Stage: Raman4, N: 2.67e+05, T: 5.00 µK
# Trap frequencies: nu_x = 138.02 Hz, nu_y = 177.46 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 1.85e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.67e+04, dTdt = -1.26e-08
# Time: 337.1 ms, Stage: Raman4, N: 2.74e+05, T: 5.01 µK
# Trap frequencies: nu_x = 129.14 Hz, nu_y = 166.03 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 1.46e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.74e+04, dTdt = -1.26e-08
# Time: 370.0 ms, Stage: Raman5, N: 2.73e+05, T: 5.01 µK
# Trap frequencies: nu_x = 118.02 Hz, nu_y = 151.75 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 1.01e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.73e+04, dTdt = -1.27e-08
# Time: 370.0 ms, Stage: Raman5, N: 2.62e+05, T: 5.00 µK
# Trap frequencies: nu_x = 118.02 Hz, nu_y = 151.75 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.71e-11
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.62e+04, dTdt = -1.26e-08
# Time: 86.4 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 213.66 Hz, nu_y = 274.71 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.07e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.07e-09
# Time: 92.9 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 211.49 Hz, nu_y = 271.91 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.03e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.03e-09
# Time: 125.2 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 200.59 Hz, nu_y = 257.90 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 8.31e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.19e-08
# Time: 131.0 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 198.65 Hz, nu_y = 255.41 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 8.00e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.19e-08
# Time: 138.1 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 196.23 Hz, nu_y = 252.29 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 7.60e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.20e-08
# Time: 138.1 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 196.23 Hz, nu_y = 252.29 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 7.59e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.20e-08
# Time: 76.7 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 216.96 Hz, nu_y = 278.95 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.14e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.14e-09
# Time: 78.2 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 216.43 Hz, nu_y = 278.27 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.13e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.13e-09
# Time: 86.1 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 213.77 Hz, nu_y = 274.85 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.07e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.07e-09
# Time: 87.5 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 213.30 Hz, nu_y = 274.24 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.06e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.06e-09
# Time: 89.3 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 212.71 Hz, nu_y = 273.48 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.05e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.05e-09
# Time: 89.3 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 212.71 Hz, nu_y = 273.48 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.05e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.05e-09
# Time: 92.4 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 211.64 Hz, nu_y = 272.11 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.03e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.03e-09
# Time: 94.0 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 211.11 Hz, nu_y = 271.43 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.02e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.02e-09
# Time: 101.9 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 208.45 Hz, nu_y = 268.01 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.70e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 103.3 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 207.98 Hz, nu_y = 267.41 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.62e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 105.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 207.39 Hz, nu_y = 266.65 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.50e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 105.0 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 207.39 Hz, nu_y = 266.65 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.50e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.18e-08
# Time: 90.3 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 212.36 Hz, nu_y = 273.04 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.05e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.05e-09
# Time: 90.8 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 212.19 Hz, nu_y = 272.82 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.04e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.04e-09
# Time: 93.3 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 211.33 Hz, nu_y = 271.72 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.03e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.03e-09
# Time: 93.8 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 211.18 Hz, nu_y = 271.52 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.02e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.02e-09
# Time: 94.4 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.99 Hz, nu_y = 271.27 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.02e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.02e-09
# Time: 94.4 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.99 Hz, nu_y = 271.27 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.02e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.02e-09
# Time: 95.4 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.65 Hz, nu_y = 270.83 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.01e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.01e-09
# Time: 95.9 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.48 Hz, nu_y = 270.61 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.01e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.01e-09
# Time: 98.4 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.62 Hz, nu_y = 269.51 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.92e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.92e-10
# Time: 98.9 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.46 Hz, nu_y = 269.31 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.89e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.89e-10
# Time: 99.5 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.27 Hz, nu_y = 269.07 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.5 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.27 Hz, nu_y = 269.07 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 94.7 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.89 Hz, nu_y = 271.15 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.02e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.02e-09
# Time: 94.8 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.84 Hz, nu_y = 271.08 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.02e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.02e-09
# Time: 95.5 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.60 Hz, nu_y = 270.77 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.01e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.01e-09
# Time: 95.7 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.55 Hz, nu_y = 270.71 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.01e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.01e-09
# Time: 95.8 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.50 Hz, nu_y = 270.64 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.01e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.01e-09
# Time: 95.8 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.50 Hz, nu_y = 270.64 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.01e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.01e-09
# Time: 96.1 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.40 Hz, nu_y = 270.51 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.01e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.01e-09
# Time: 96.3 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.35 Hz, nu_y = 270.45 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.01e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.01e-09
# Time: 97.0 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.10 Hz, nu_y = 270.13 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.00e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.00e-09
# Time: 97.1 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.06 Hz, nu_y = 270.08 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.00e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.00e-09
# Time: 97.3 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.01 Hz, nu_y = 270.01 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.00e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.00e-09
# Time: 97.3 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 210.01 Hz, nu_y = 270.01 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 1.00e-09
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 1.00e-09
# Time: 100.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.02 Hz, nu_y = 268.74 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.81e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 101.7 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 208.53 Hz, nu_y = 268.11 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.71e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 109.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 206.07 Hz, nu_y = 264.94 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.26e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 110.3 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 205.63 Hz, nu_y = 264.38 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.20e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 111.9 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 205.08 Hz, nu_y = 263.68 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.10e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 111.9 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 205.08 Hz, nu_y = 263.68 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.08e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.18e-08
# Time: 98.4 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.62 Hz, nu_y = 269.51 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.92e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.92e-10
# Time: 99.0 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.43 Hz, nu_y = 269.26 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.89e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.89e-10
# Time: 101.9 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 208.46 Hz, nu_y = 268.02 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.70e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 102.4 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 208.29 Hz, nu_y = 267.80 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.67e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 103.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 208.07 Hz, nu_y = 267.52 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.63e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 103.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 208.07 Hz, nu_y = 267.52 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.63e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 97.7 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.85 Hz, nu_y = 269.81 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.97e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.97e-10
# Time: 98.0 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.78 Hz, nu_y = 269.71 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.95e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.95e-10
# Time: 99.1 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.39 Hz, nu_y = 269.22 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.3 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.33 Hz, nu_y = 269.13 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.5 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.24 Hz, nu_y = 269.02 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.85e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.5 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.24 Hz, nu_y = 269.02 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.85e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 97.5 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.93 Hz, nu_y = 269.91 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.98e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.98e-10
# Time: 97.6 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.90 Hz, nu_y = 269.87 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.98e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.98e-10
# Time: 98.1 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.71 Hz, nu_y = 269.63 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.94e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.94e-10
# Time: 98.2 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.68 Hz, nu_y = 269.59 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.93e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.93e-10
# Time: 98.4 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.64 Hz, nu_y = 269.54 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.93e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.93e-10
# Time: 98.4 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.64 Hz, nu_y = 269.54 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.93e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.93e-10
# Time: 98.6 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.57 Hz, nu_y = 269.45 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.91e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.91e-10
# Time: 98.7 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.53 Hz, nu_y = 269.40 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.91e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.91e-10
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.35 Hz, nu_y = 269.17 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.3 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.32 Hz, nu_y = 269.12 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.4 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.28 Hz, nu_y = 269.07 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.4 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.28 Hz, nu_y = 269.07 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 98.5 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.60 Hz, nu_y = 269.49 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.92e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.92e-10
# Time: 98.5 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.58 Hz, nu_y = 269.46 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.92e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.92e-10
# Time: 98.8 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.48 Hz, nu_y = 269.33 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.90e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.90e-10
# Time: 98.9 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.46 Hz, nu_y = 269.31 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.89e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.89e-10
# Time: 99.0 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.44 Hz, nu_y = 269.28 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.89e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.89e-10
# Time: 99.0 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.44 Hz, nu_y = 269.28 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.89e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.89e-10
# Time: 99.1 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.40 Hz, nu_y = 269.23 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.1 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.38 Hz, nu_y = 269.20 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.4 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.28 Hz, nu_y = 269.08 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.5 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.26 Hz, nu_y = 269.05 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.5 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.24 Hz, nu_y = 269.02 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.85e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.5 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.24 Hz, nu_y = 269.02 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.85e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.41 Hz, nu_y = 269.24 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.1 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.40 Hz, nu_y = 269.22 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.3 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.32 Hz, nu_y = 269.13 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.3 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.31 Hz, nu_y = 269.11 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.4 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.29 Hz, nu_y = 269.09 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.4 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.29 Hz, nu_y = 269.09 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.42 Hz, nu_y = 269.25 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.1 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.41 Hz, nu_y = 269.24 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.35 Hz, nu_y = 269.16 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.3 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.34 Hz, nu_y = 269.15 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.3 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.32 Hz, nu_y = 269.13 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.3 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.32 Hz, nu_y = 269.13 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.42 Hz, nu_y = 269.26 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.89e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.41 Hz, nu_y = 269.24 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.36 Hz, nu_y = 269.18 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.35 Hz, nu_y = 269.17 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.34 Hz, nu_y = 269.16 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.34 Hz, nu_y = 269.16 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.42 Hz, nu_y = 269.26 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.89e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.42 Hz, nu_y = 269.25 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.37 Hz, nu_y = 269.20 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.37 Hz, nu_y = 269.19 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.36 Hz, nu_y = 269.17 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.36 Hz, nu_y = 269.17 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.0 ms, Stage: MOT, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.43 Hz, nu_y = 269.26 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 9.89e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -1.34e+04, dTdt = 9.89e-10
# Time: 99.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.42 Hz, nu_y = 269.25 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.1 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.38 Hz, nu_y = 269.21 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.1 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.38 Hz, nu_y = 269.20 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.88e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.37 Hz, nu_y = 269.19 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.37 Hz, nu_y = 269.19 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.35 Hz, nu_y = 269.17 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.2 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.35 Hz, nu_y = 269.16 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.87e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.3 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.31 Hz, nu_y = 269.12 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.4 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.31 Hz, nu_y = 269.11 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.4 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.30 Hz, nu_y = 269.10 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.4 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.30 Hz, nu_y = 269.10 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.86e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 99.8 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.16 Hz, nu_y = 268.93 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.84e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 100.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 209.10 Hz, nu_y = 268.84 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.82e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 101.0 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 208.76 Hz, nu_y = 268.41 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.76e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 101.1 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 208.70 Hz, nu_y = 268.33 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.75e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 101.4 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 208.63 Hz, nu_y = 268.23 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.73e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 101.4 ms, Stage: Raman1, N: 2.69e+05, T: 5.00 µK
# Trap frequencies: nu_x = 208.63 Hz, nu_y = 268.23 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.73e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.69e+04, dTdt = -1.18e-08
# Time: 105.4 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 207.28 Hz, nu_y = 266.50 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.48e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.18e-08
# Time: 107.4 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 206.61 Hz, nu_y = 265.64 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.36e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.18e-08
# Time: 117.4 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 203.24 Hz, nu_y = 261.31 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 8.75e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.19e-08
# Time: 119.1 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 202.64 Hz, nu_y = 260.54 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 8.65e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.19e-08
# Time: 121.3 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 201.89 Hz, nu_y = 259.57 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 8.52e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.19e-08
# Time: 121.3 ms, Stage: Raman1, N: 2.68e+05, T: 5.00 µK
# Trap frequencies: nu_x = 201.89 Hz, nu_y = 259.57 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 8.52e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.68e+04, dTdt = -1.19e-08
# Time: 161.3 ms, Stage: Raman1, N: 2.67e+05, T: 5.00 µK
# Trap frequencies: nu_x = 188.42 Hz, nu_y = 242.25 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 6.44e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.67e+04, dTdt = -1.21e-08
# Time: 181.3 ms, Stage: Raman2, N: 2.66e+05, T: 5.00 µK
# Trap frequencies: nu_x = 181.68 Hz, nu_y = 233.59 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 5.55e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.66e+04, dTdt = -1.22e-08
# Time: 281.1 ms, Stage: Raman3, N: 2.64e+05, T: 5.00 µK
# Trap frequencies: nu_x = 148.00 Hz, nu_y = 190.29 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 2.42e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.64e+04, dTdt = -1.25e-08
# Time: 298.9 ms, Stage: Raman4, N: 2.63e+05, T: 5.00 µK
# Trap frequencies: nu_x = 142.02 Hz, nu_y = 182.59 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 2.05e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.63e+04, dTdt = -1.25e-08
# Time: 321.1 ms, Stage: Raman4, N: 2.63e+05, T: 5.00 µK
# Trap frequencies: nu_x = 134.53 Hz, nu_y = 172.97 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 1.65e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.63e+04, dTdt = -1.26e-08
# Time: 321.1 ms, Stage: Raman4, N: 2.63e+05, T: 5.00 µK
# Trap frequencies: nu_x = 134.53 Hz, nu_y = 172.97 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 1.65e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.63e+04, dTdt = -1.26e-08
# Time: 372.1 ms, Stage: Raman5, N: 2.61e+05, T: 5.00 µK
# Trap frequencies: nu_x = 117.34 Hz, nu_y = 150.86 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.49e-11
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.61e+04, dTdt = -1.26e-08
# Time: 397.6 ms, Stage: Raman5, N: 2.61e+05, T: 5.00 µK
# Trap frequencies: nu_x = 108.74 Hz, nu_y = 139.81 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 6.98e-11
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.61e+04, dTdt = -1.27e-08
# Time: 525.0 ms, Stage: Evap5, N: 2.57e+05, T: 4.99 µK
# Trap frequencies: nu_x = 65.76 Hz, nu_y = 84.54 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.59e-03, gamma_heat = 9.22e-12
# Evaporation: gamma_evap = 2.72e-03
# dNdt = -2.57e+04, dTdt = -6.80e-09
# Time: 547.7 ms, Stage: Evap5, N: 2.57e+05, T: 4.99 µK
# Trap frequencies: nu_x = 58.11 Hz, nu_y = 74.72 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.48e-08, gamma_heat = 5.61e-12
# Evaporation: gamma_evap = 6.76e-04
# dNdt = -2.22e+04, dTdt = -3.91e-09
# Time: 576.0 ms, Stage: Evap6, N: 2.56e+05, T: 4.99 µK
# Trap frequencies: nu_x = 48.56 Hz, nu_y = 62.44 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 2.73e-12
# Evaporation: gamma_evap = 2.20e-04
# dNdt = -1.29e+04, dTdt = -1.47e-09
# Time: 576.0 ms, Stage: Evap6, N: 2.56e+05, T: 4.99 µK
# Trap frequencies: nu_x = 48.56 Hz, nu_y = 62.44 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 2.73e-12
# Evaporation: gamma_evap = 2.21e-04
# dNdt = -1.29e+04, dTdt = -1.47e-09
# Time: 331.3 ms, Stage: Raman4, N: 2.62e+05, T: 5.00 µK
# Trap frequencies: nu_x = 131.09 Hz, nu_y = 168.55 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 1.48e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.62e+04, dTdt = -1.26e-08
# Time: 336.4 ms, Stage: Raman4, N: 2.62e+05, T: 5.00 µK
# Trap frequencies: nu_x = 129.37 Hz, nu_y = 166.34 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 1.41e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.62e+04, dTdt = -1.26e-08
# Time: 361.9 ms, Stage: Raman5, N: 2.62e+05, T: 5.00 µK
# Trap frequencies: nu_x = 120.78 Hz, nu_y = 155.28 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 1.07e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.62e+04, dTdt = -1.26e-08
# Time: 366.4 ms, Stage: Raman5, N: 2.62e+05, T: 5.00 µK
# Trap frequencies: nu_x = 119.25 Hz, nu_y = 153.32 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 1.01e-10
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.62e+04, dTdt = -1.26e-08
# Time: 372.1 ms, Stage: Raman5, N: 2.61e+05, T: 5.00 µK
# Trap frequencies: nu_x = 117.34 Hz, nu_y = 150.86 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.49e-11
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.61e+04, dTdt = -1.26e-08
# Time: 372.1 ms, Stage: Raman5, N: 2.61e+05, T: 5.00 µK
# Trap frequencies: nu_x = 117.34 Hz, nu_y = 150.86 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 9.49e-11
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.61e+04, dTdt = -1.26e-08
# Time: 382.3 ms, Stage: Raman5, N: 2.61e+05, T: 5.00 µK
# Trap frequencies: nu_x = 113.90 Hz, nu_y = 146.44 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 8.41e-11
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.61e+04, dTdt = -1.27e-08
# Time: 387.4 ms, Stage: Raman5, N: 2.61e+05, T: 5.00 µK
# Trap frequencies: nu_x = 112.18 Hz, nu_y = 144.23 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 7.91e-11
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.61e+04, dTdt = -1.27e-08
# Time: 412.9 ms, Stage: Raman5, N: 2.60e+05, T: 5.00 µK
# Trap frequencies: nu_x = 103.58 Hz, nu_y = 133.18 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.55e-03, gamma_heat = 5.74e-11
# Evaporation: gamma_evap = 0.00e+00
# dNdt = -2.60e+04, dTdt = -1.27e-08
# Time: 417.4 ms, Stage: Evap1, N: 2.60e+05, T: 5.00 µK
# Trap frequencies: nu_x = 221.97 Hz, nu_y = 11.30 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.49e-03, gamma_heat = 5.40e-11
# Evaporation: gamma_evap = 1.90e-02
# dNdt = -2.60e+04, dTdt = 1.01e-09
# Time: 423.0 ms, Stage: Evap1, N: 2.60e+05, T: 5.00 µK
# Trap frequencies: nu_x = 217.77 Hz, nu_y = 11.13 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 4.98e-04, gamma_heat = 5.01e-11
# Evaporation: gamma_evap = 2.39e-02
# dNdt = -2.60e+04, dTdt = 6.28e-09
# Time: 423.0 ms, Stage: Evap1, N: 2.60e+05, T: 5.00 µK
# Trap frequencies: nu_x = 217.77 Hz, nu_y = 11.13 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 4.98e-04, gamma_heat = 5.01e-11
# Evaporation: gamma_evap = 2.39e-02
# dNdt = -2.60e+04, dTdt = 6.28e-09
# Time: 453.6 ms, Stage: Evap2, N: 2.59e+05, T: 5.00 µK
# Trap frequencies: nu_x = 89.83 Hz, nu_y = 115.49 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.04e-04, gamma_heat = 3.23e-11
# Evaporation: gamma_evap = 8.03e-03
# dNdt = -2.59e+04, dTdt = -2.72e-09
# Time: 468.9 ms, Stage: Evap3, N: 2.59e+05, T: 5.00 µK
# Trap frequencies: nu_x = 84.67 Hz, nu_y = 108.86 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.21e-03, gamma_heat = 2.55e-11
# Evaporation: gamma_evap = 1.35e-03
# dNdt = -2.59e+04, dTdt = -1.08e-08
# Time: 545.4 ms, Stage: Evap5, N: 2.57e+05, T: 4.99 µK
# Trap frequencies: nu_x = 58.88 Hz, nu_y = 75.70 Hz, nu_z = 0.00 Hz
# ...
# Evaporation: gamma_evap = 1.17e-03
# dNdt = -2.57e+04, dTdt = -1.35e-09
# Time: 560.6 ms, Stage: Evap6, N: 2.57e+05, T: 5.00 µK
# Trap frequencies: nu_x = 53.76 Hz, nu_y = 69.12 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.71e-04, gamma_heat = 4.10e-12
# Evaporation: gamma_evap = 1.17e-03
# dNdt = -2.57e+04, dTdt = -1.35e-09
# Time: 561.4 ms, Stage: Evap6, N: 2.57e+05, T: 5.00 µK
# Trap frequencies: nu_x = 53.47 Hz, nu_y = 68.75 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.15e-04, gamma_heat = 4.01e-12
# Evaporation: gamma_evap = 9.18e-04
# dNdt = -2.57e+04, dTdt = -1.23e-09
# Time: 561.9 ms, Stage: Evap6, N: 2.57e+05, T: 5.00 µK
# Trap frequencies: nu_x = 53.32 Hz, nu_y = 68.56 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.91e-04, gamma_heat = 3.97e-12
# Evaporation: gamma_evap = 7.92e-04
# dNdt = -2.57e+04, dTdt = -1.16e-09
# Time: 564.0 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 52.60 Hz, nu_y = 67.62 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 9.81e-05, gamma_heat = 3.76e-12
# Evaporation: gamma_evap = 1.33e-04
# dNdt = -2.56e+04, dTdt = -5.98e-10
# Time: 564.4 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 52.47 Hz, nu_y = 67.46 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 8.61e-05, gamma_heat = 3.72e-12
# Evaporation: gamma_evap = 1.51e-06
# dNdt = -2.56e+04, dTdt = -4.28e-10
# Time: 564.9 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 52.30 Hz, nu_y = 67.25 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 7.27e-05, gamma_heat = 3.67e-12
# Evaporation: gamma_evap = -1.79e-04
# dNdt = -2.56e+04, dTdt = -1.62e-10
# Time: 564.9 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 52.30 Hz, nu_y = 67.25 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 7.27e-05, gamma_heat = 3.67e-12
# Evaporation: gamma_evap = -1.79e-04
# dNdt = -2.56e+04, dTdt = -1.62e-10
# Time: 567.1 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 51.56 Hz, nu_y = 66.29 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.98e-05, gamma_heat = 3.47e-12
# Evaporation: gamma_evap = -2.02e-03
# dNdt = -2.56e+04, dTdt = 3.68e-09
# Time: 568.2 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 51.18 Hz, nu_y = 65.81 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.75e-05, gamma_heat = 3.37e-12
# Evaporation: gamma_evap = -5.15e-02
# dNdt = -2.56e+04, dTdt = 1.21e-07
# Time: 573.8 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.31 Hz, nu_y = 63.40 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.16e-07, gamma_heat = 2.90e-12
# Evaporation: gamma_evap = 4.01e-04
# dNdt = -2.56e+04, dTdt = -2.10e-09
# Time: 574.8 ms, Stage: Evap6, N: 2.56e+05, T: 5.01 µK
# Trap frequencies: nu_x = 48.98 Hz, nu_y = 62.97 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.11e-08, gamma_heat = 2.81e-12
# Evaporation: gamma_evap = 3.05e-04
# dNdt = -1.76e+04, dTdt = -1.79e-09
# Time: 576.0 ms, Stage: Evap6, N: 2.56e+05, T: 5.01 µK
# Trap frequencies: nu_x = 48.56 Hz, nu_y = 62.44 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 2.72e-12
# Evaporation: gamma_evap = 2.20e-04
# dNdt = -1.29e+04, dTdt = -1.47e-09
# Time: 576.0 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.56 Hz, nu_y = 62.44 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 2.73e-12
# Evaporation: gamma_evap = 2.20e-04
# dNdt = -1.29e+04, dTdt = -1.47e-09
# Time: 565.5 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 52.12 Hz, nu_y = 67.01 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 5.91e-05, gamma_heat = 3.62e-12
# Evaporation: gamma_evap = -4.24e-04
# dNdt = -2.56e+04, dTdt = 2.55e-10
# Time: 565.7 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 52.02 Hz, nu_y = 66.89 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 5.31e-05, gamma_heat = 3.59e-12
# Evaporation: gamma_evap = -5.71e-04
# dNdt = -2.56e+04, dTdt = 5.28e-10
# Time: 567.1 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 51.55 Hz, nu_y = 66.28 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.96e-05, gamma_heat = 3.47e-12
# Evaporation: gamma_evap = -2.05e-03
# dNdt = -2.56e+04, dTdt = 3.75e-09
# Time: 567.4 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 51.47 Hz, nu_y = 66.17 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.64e-05, gamma_heat = 3.44e-12
# Evaporation: gamma_evap = -2.72e-03
# dNdt = -2.56e+04, dTdt = 5.33e-09
# Time: 567.7 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 51.36 Hz, nu_y = 66.04 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.28e-05, gamma_heat = 3.41e-12
# Evaporation: gamma_evap = -4.34e-03
# dNdt = -2.56e+04, dTdt = 9.14e-09
# Time: 567.7 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 51.36 Hz, nu_y = 66.04 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.28e-05, gamma_heat = 3.41e-12
# Evaporation: gamma_evap = -4.34e-03
# dNdt = -2.56e+04, dTdt = 9.14e-09
# Time: 568.3 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 51.17 Hz, nu_y = 65.80 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.73e-05, gamma_heat = 3.36e-12
# Evaporation: gamma_evap = -8.62e-02
# dNdt = -2.56e+04, dTdt = 2.04e-07
# Time: 568.5 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 51.08 Hz, nu_y = 65.67 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.49e-05, gamma_heat = 3.34e-12
# Evaporation: gamma_evap = 1.11e-02
# dNdt = -2.56e+04, dTdt = -2.78e-08
# Time: 569.9 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 50.61 Hz, nu_y = 65.07 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 6.51e-06, gamma_heat = 3.22e-12
# Evaporation: gamma_evap = 1.72e-03
# dNdt = -2.56e+04, dTdt = -5.43e-09
# Time: 570.2 ms, Stage: Evap6, N: 2.56e+05, T: 4.99 µK
# Trap frequencies: nu_x = 50.53 Hz, nu_y = 64.96 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 5.51e-06, gamma_heat = 3.20e-12
# Evaporation: gamma_evap = 1.49e-03
# dNdt = -2.56e+04, dTdt = -4.87e-09
# Time: 570.5 ms, Stage: Evap6, N: 2.56e+05, T: 4.99 µK
# Trap frequencies: nu_x = 50.42 Hz, nu_y = 64.83 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 4.43e-06, gamma_heat = 3.17e-12
# Evaporation: gamma_evap = 1.27e-03
# dNdt = -2.56e+04, dTdt = -4.35e-09
# Time: 570.5 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 50.42 Hz, nu_y = 64.83 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 4.43e-06, gamma_heat = 3.17e-12
# Evaporation: gamma_evap = 1.27e-03
# dNdt = -2.56e+04, dTdt = -4.35e-09
# Time: 571.6 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 50.05 Hz, nu_y = 64.35 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.81e-06, gamma_heat = 3.08e-12
# Evaporation: gamma_evap = 8.03e-04
# dNdt = -2.56e+04, dTdt = -3.20e-09
# Time: 572.1 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.86 Hz, nu_y = 64.11 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.06e-06, gamma_heat = 3.03e-12
# Evaporation: gamma_evap = 6.63e-04
# dNdt = -2.56e+04, dTdt = -2.84e-09
# Time: 574.9 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.93 Hz, nu_y = 62.92 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 7.09e-09, gamma_heat = 2.81e-12
# Evaporation: gamma_evap = 2.95e-04
# dNdt = -1.67e+04, dTdt = -1.75e-09
# Time: 575.4 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.77 Hz, nu_y = 62.70 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 6.75e-10, gamma_heat = 2.77e-12
# Evaporation: gamma_evap = 2.59e-04
# dNdt = -1.40e+04, dTdt = -1.62e-09
# Time: 576.0 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.56 Hz, nu_y = 62.44 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 2.73e-12
# Evaporation: gamma_evap = 2.21e-04
# dNdt = -1.29e+04, dTdt = -1.47e-09
# Time: 576.0 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.56 Hz, nu_y = 62.44 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 2.73e-12
# Evaporation: gamma_evap = 2.21e-04
# dNdt = -1.29e+04, dTdt = -1.47e-09
# Time: 570.9 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 50.28 Hz, nu_y = 64.64 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 3.20e-06, gamma_heat = 3.13e-12
# Evaporation: gamma_evap = 1.05e-03
# dNdt = -2.56e+04, dTdt = -3.80e-09
# Time: 571.1 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 50.20 Hz, nu_y = 64.55 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.69e-06, gamma_heat = 3.12e-12
# Evaporation: gamma_evap = 9.56e-04
# dNdt = -2.56e+04, dTdt = -3.59e-09
# Time: 572.2 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.84 Hz, nu_y = 64.08 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 9.90e-07, gamma_heat = 3.03e-12
# Evaporation: gamma_evap = 6.48e-04
# dNdt = -2.56e+04, dTdt = -2.80e-09
# Time: 572.4 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.78 Hz, nu_y = 64.00 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 8.05e-07, gamma_heat = 3.01e-12
# Evaporation: gamma_evap = 6.09e-04
# dNdt = -2.56e+04, dTdt = -2.70e-09
# Time: 572.6 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.70 Hz, nu_y = 63.89 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 6.11e-07, gamma_heat = 2.99e-12
# Evaporation: gamma_evap = 5.64e-04
# dNdt = -2.56e+04, dTdt = -2.58e-09
# Time: 572.6 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.70 Hz, nu_y = 63.89 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 6.11e-07, gamma_heat = 2.99e-12
# Evaporation: gamma_evap = 5.64e-04
# dNdt = -2.56e+04, dTdt = -2.58e-09
# Time: 573.1 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.55 Hz, nu_y = 63.71 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 3.53e-07, gamma_heat = 2.96e-12
# Evaporation: gamma_evap = 4.95e-04
# dNdt = -2.56e+04, dTdt = -2.38e-09
# Time: 573.3 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.48 Hz, nu_y = 63.61 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.60e-07, gamma_heat = 2.94e-12
# Evaporation: gamma_evap = 4.64e-04
# dNdt = -2.56e+04, dTdt = -2.29e-09
# Time: 574.4 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.11 Hz, nu_y = 63.15 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 3.45e-08, gamma_heat = 2.85e-12
# Evaporation: gamma_evap = 3.42e-04
# dNdt = -2.13e+04, dTdt = -1.91e-09
# Time: 574.6 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.05 Hz, nu_y = 63.06 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 2.10e-08, gamma_heat = 2.84e-12
# Evaporation: gamma_evap = 3.24e-04
# dNdt = -1.94e+04, dTdt = -1.85e-09
# Time: 574.8 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.97 Hz, nu_y = 62.96 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.02e-08, gamma_heat = 2.82e-12
# Evaporation: gamma_evap = 3.04e-04
# dNdt = -1.74e+04, dTdt = -1.78e-09
# Time: 574.8 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.97 Hz, nu_y = 62.96 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.02e-08, gamma_heat = 2.82e-12
# Evaporation: gamma_evap = 3.04e-04
# dNdt = -1.74e+04, dTdt = -1.78e-09
# Time: 572.9 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.61 Hz, nu_y = 63.79 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 4.52e-07, gamma_heat = 2.97e-12
# Evaporation: gamma_evap = 5.23e-04
# dNdt = -2.56e+04, dTdt = -2.46e-09
# Time: 573.0 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.57 Hz, nu_y = 63.74 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 3.85e-07, gamma_heat = 2.96e-12
# Evaporation: gamma_evap = 5.04e-04
# dNdt = -2.56e+04, dTdt = -2.41e-09
# Time: 573.6 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.37 Hz, nu_y = 63.47 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.55e-07, gamma_heat = 2.91e-12
# Evaporation: gamma_evap = 4.21e-04
# dNdt = -2.56e+04, dTdt = -2.16e-09
# Time: 573.7 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.33 Hz, nu_y = 63.42 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.29e-07, gamma_heat = 2.90e-12
# Evaporation: gamma_evap = 4.08e-04
# dNdt = -2.56e+04, dTdt = -2.12e-09
# Time: 573.9 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.28 Hz, nu_y = 63.37 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.01e-07, gamma_heat = 2.89e-12
# Evaporation: gamma_evap = 3.93e-04
# dNdt = -2.56e+04, dTdt = -2.07e-09
# Time: 573.9 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.28 Hz, nu_y = 63.37 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.01e-07, gamma_heat = 2.89e-12
# Evaporation: gamma_evap = 3.93e-04
# dNdt = -2.56e+04, dTdt = -2.07e-09
# Time: 574.1 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.20 Hz, nu_y = 63.26 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 6.21e-08, gamma_heat = 2.87e-12
# Evaporation: gamma_evap = 3.67e-04
# dNdt = -2.43e+04, dTdt = -1.99e-09
# Time: 574.2 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 49.16 Hz, nu_y = 63.21 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 4.76e-08, gamma_heat = 2.86e-12
# Evaporation: gamma_evap = 3.55e-04
# dNdt = -2.28e+04, dTdt = -1.95e-09
# Time: 574.8 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.96 Hz, nu_y = 62.94 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 8.84e-09, gamma_heat = 2.82e-12
# Evaporation: gamma_evap = 3.00e-04
# dNdt = -1.71e+04, dTdt = -1.77e-09
# Time: 574.9 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.92 Hz, nu_y = 62.90 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 5.98e-09, gamma_heat = 2.81e-12
# Evaporation: gamma_evap = 2.92e-04
# dNdt = -1.64e+04, dTdt = -1.74e-09
# Time: 575.1 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.87 Hz, nu_y = 62.84 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 3.46e-09, gamma_heat = 2.80e-12
# Evaporation: gamma_evap = 2.81e-04
# dNdt = -1.55e+04, dTdt = -1.70e-09
# Time: 575.1 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.87 Hz, nu_y = 62.84 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 3.46e-09, gamma_heat = 2.80e-12
# Evaporation: gamma_evap = 2.81e-04
# dNdt = -1.55e+04, dTdt = -1.70e-09
# Time: 575.3 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.81 Hz, nu_y = 62.76 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 1.42e-09, gamma_heat = 2.78e-12
# Evaporation: gamma_evap = 2.68e-04
# dNdt = -1.46e+04, dTdt = -1.65e-09
# Time: 575.4 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.78 Hz, nu_y = 62.72 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 8.30e-10, gamma_heat = 2.78e-12
# Evaporation: gamma_evap = 2.61e-04
# dNdt = -1.42e+04, dTdt = -1.63e-09
# Time: 575.8 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.62 Hz, nu_y = 62.52 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 5.53e-12, gamma_heat = 2.74e-12
# Evaporation: gamma_evap = 2.31e-04
# dNdt = -1.30e+04, dTdt = -1.51e-09
# Time: 575.9 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.60 Hz, nu_y = 62.48 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 5.27e-13, gamma_heat = 2.73e-12
# Evaporation: gamma_evap = 2.27e-04
# dNdt = -1.29e+04, dTdt = -1.49e-09
# Time: 576.0 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.56 Hz, nu_y = 62.44 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 2.73e-12
# Evaporation: gamma_evap = 2.21e-04
# dNdt = -1.29e+04, dTdt = -1.47e-09
# Time: 576.0 ms, Stage: Evap6, N: 2.56e+05, T: 5.00 µK
# Trap frequencies: nu_x = 48.56 Hz, nu_y = 62.44 Hz, nu_z = 0.00 Hz
# Raman cooling: gamma_cool = 0.00e+00, gamma_heat = 2.73e-12
# Evaporation: gamma_evap = 2.21e-04
# dNdt = -1.29e+04, dTdt = -1.47e-09
# Animation creation complete. Check 'bec_evolution.mp4'.
# Additional results plot saved as 'bec_formation_results.png'.
# Final atom number: 2.56e+05
# Final temperature: 5.00 µK
# Final BEC fraction: 0.00%
# Final phase space density: 1.15e-05
# Raman cooling slope γ: -67.14
# Evaporative cooling slope γ: -138.14
# Overall cooling slope γ: -81.27
# Comparison with paper results:
# Final atom number: 2.56e+05 (Difference: 9048.90%)
# Final BEC fraction: 0.00% (Difference: -100.00%)
# Paper reported cooling slope γ: ~16
# Our overall cooling slope γ: -81.27
# Cooling process plot saved as 'cooling_process.png'.

# %%
x_values = np.linspace(0, len(results) - 1, 20, dtype=int)
for x in x_values:
    result = results[x]
    print(f"Time: {result['time']*1e3:.1f} ms, Stage: {result['stage']}, "
            f"T: {result['T']*1e6:.2f} µK, N: {result['N']:.2e}, "
            f"BEC fraction: {result['BEC_fraction']:.2%}")
# Out:
# Time: 0.0 ms, Stage: MOT, T: 5.00 µK, N: 2.70e+05, BEC fraction: 0.00%
# Time: 30.0 ms, Stage: MOT, T: 5.00 µK, N: 2.70e+05, BEC fraction: 0.00%
# Time: 60.5 ms, Stage: MOT, T: 5.00 µK, N: 2.69e+05, BEC fraction: 0.00%
# Time: 90.5 ms, Stage: MOT, T: 5.00 µK, N: 2.69e+05, BEC fraction: 0.00%
# Time: 121.1 ms, Stage: Raman1, T: 5.00 µK, N: 2.68e+05, BEC fraction: 0.00%
# Time: 151.1 ms, Stage: Raman1, T: 5.00 µK, N: 2.67e+05, BEC fraction: 0.00%
# Time: 181.6 ms, Stage: Raman2, T: 5.00 µK, N: 2.66e+05, BEC fraction: 0.00%
# Time: 212.2 ms, Stage: Raman2, T: 5.00 µK, N: 2.66e+05, BEC fraction: 0.00%
# Time: 242.2 ms, Stage: Raman3, T: 5.00 µK, N: 2.65e+05, BEC fraction: 0.00%
# Time: 272.7 ms, Stage: Raman3, T: 5.00 µK, N: 2.64e+05, BEC fraction: 0.00%
# Time: 302.7 ms, Stage: Raman4, T: 5.00 µK, N: 2.63e+05, BEC fraction: 0.00%
# Time: 333.3 ms, Stage: Raman4, T: 5.00 µK, N: 2.62e+05, BEC fraction: 0.00%
# Time: 363.2 ms, Stage: Raman5, T: 5.00 µK, N: 2.62e+05, BEC fraction: 0.00%
# Time: 393.8 ms, Stage: Raman5, T: 5.00 µK, N: 2.61e+05, BEC fraction: 0.00%
# Time: 424.4 ms, Stage: Evap1, T: 5.00 µK, N: 2.60e+05, BEC fraction: 0.00%
# Time: 454.3 ms, Stage: Evap2, T: 5.00 µK, N: 2.59e+05, BEC fraction: 0.00%
# Time: 484.9 ms, Stage: Evap3, T: 5.00 µK, N: 2.58e+05, BEC fraction: 0.00%
# Time: 514.9 ms, Stage: Evap4, T: 5.00 µK, N: 2.58e+05, BEC fraction: 0.00%
# Time: 545.4 ms, Stage: Evap5, T: 5.00 µK, N: 2.57e+05, BEC fraction: 0.00%
# Time: 576.0 ms, Stage: Evap6, T: 5.00 µK, N: 2.56e+05, BEC fraction: 0.00%
