# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import imageio
from scipy.integrate import solve_ivp
from scipy.ndimage import gaussian_filter
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation
from sklearn.linear_model import RANSACRegressor
import warnings
from scipy.constants import h, hbar, k, atomic_mass, mu_0, epsilon_0, g
from scipy.special import zeta

class BECSimulation:
    def __init__(self):
        self.m = 87 * atomic_mass  # Mass of Rb-87 atom in kg
        self.a = 5.77e-9  # Scattering length for Rb-87
        self.wavelength = 780e-9  # Wavelength of cooling light
        self.k_L = 2 * np.pi / self.wavelength

        self.stages = []
        total_time = 0
        for stage_info in [
            {'name': 'MOTLoading', 'duration': 89e-3},
            {'name': 'MOTCompression', 'duration': 10e-3},
            {'name': 'MagneticFieldAdjustment', 'duration': 1e-3},
            {'name': 'Raman1', 'duration': 63e-3},
            {'name': 'Raman2', 'duration': 63e-3},
            {'name': 'Raman3', 'duration': 63e-3},
            {'name': 'Raman4', 'duration': 63e-3},
            {'name': 'Raman5', 'duration': 63e-3},
            {'name': 'Evap1', 'duration': 27e-3},
            {'name': 'Evap2', 'duration': 27e-3},
            {'name': 'Evap3', 'duration': 27e-3},
            {'name': 'Evap4', 'duration': 27e-3},
            {'name': 'Evap5', 'duration': 27e-3},
            {'name': 'Evap6', 'duration': 25e-3},  # Adjusted to reach 575 ms total
        ]:
            stage = stage_info.copy()
            stage['start_time'] = total_time
            total_time += stage['duration']
            stage['end_time'] = total_time
            self.stages.append(stage)

        self.params = {
            'initial_N': 2.7e5,
            'initial_T': 30e-6,
            'gamma_bg': 0.001,  # Further reduced background loss rate
            'wx': 18e-6,  # 18 µm horizontal beam waist
            'wy': 14e-6,  # 14 µm vertical beam waist
            'w_R': 500e-6,  # Raman beam waist
            'theta_R': np.pi/4,  # Angle between Raman beams
            'B_bias': 20.8e-4,  # Bias field (20.8 G) from paper
            'K2': 1e-20,  # Further reduced two-body loss coefficient
            'K3': 1e-42,  # Adjusted three-body loss coefficient
            'eta_load': 0.5,  # Trap loading efficiency
            'tilt_factor': 3.0,  # Increased tilt factor for more efficient evaporation
            'gray_molasses_duration': 1e-3,  # 1 ms gray molasses at the end of compression
            'gray_molasses_T_final': 35e-6,
            'intensity_noise': 1e-4,
            'anharmonicity': 1e-15,
            'phase_noise_amplitude': 0.1,
            'freq_noise_amplitude': 1e3,
            'Omega_R_0': 2 * np.pi * 50e3,
            'interaction_shift': -1.33,
            'atom_number_calibration': 1.0,
            'atom_number_uncertainty': 0.1,
            'B_field_fluctuation': 1e-7,
            'imaging_resolution': 5e-6,
            'raman_cooling_efficiency': 0.99,  # Increased Raman cooling efficiency
            'evap_efficiency': 0.95,  # Increased evaporation efficiency
            'min_temperature': 1e-9,  # 1 nK minimum temperature
        }

        for i, stage in enumerate(self.stages):
            if stage['name'].startswith('Raman'):
                self.params[f'{stage["name"]}_P_x'] = 1.0 - 0.02 * i
                self.params[f'{stage["name"]}_P_y'] = 1.0 - 0.02 * i
                self.params[f'{stage["name"]}_Omega_R'] = 2 * np.pi * (40e3 - 1e3 * i)  # Increased Rabi frequency
                self.params[f'{stage["name"]}_Gamma_OP'] = 2 * np.pi * (4e3 - 100 * i)  # Increased optical pumping rate
                self.params[f'{stage["name"]}_delta'] = 2 * np.pi * 4.33e9
            elif stage['name'].startswith('Evap'):
                self.params[f'{stage["name"]}_eta'] = 12 - 0.5 * i  # Adjusted eta values for more efficient evaporation
                self.params[f'{stage["name"]}_P_x'] = 1.0 - 0.15 * i
                self.params[f'{stage["name"]}_P_y'] = 1.0 - 0.18 * i

    def trap_frequencies(self, P_x, P_y, t):
        U_x = max(0, 1e-6 * P_x * (1 - 0.2 * t / self.stages[-1]['end_time']))
        U_y = max(0, 1e-6 * P_y * (1 - 0.2 * t / self.stages[-1]['end_time']))

        nu_x = max(1e-10, np.sqrt(4 * U_x / (self.m * self.params['wx']**2)) / (2 * np.pi))
        nu_y = max(1e-10, np.sqrt(4 * U_y / (self.m * self.params['wy']**2)) / (2 * np.pi))
        nu_z = max(1e-10, np.sqrt(2 * g / (self.params['wx'] + self.params['wy'])) / (2 * np.pi))

        nu_mean = np.mean([nu_x, nu_y, nu_z])
        target_freq = 185 + 15 * (1 - t / self.stages[-1]['end_time'])  # Dynamic adjustment of trap frequencies
        adjustment = target_freq / nu_mean
        return nu_x * adjustment, nu_y * adjustment, nu_z * adjustment

    def collision_rate(self, N, T, nu_x, nu_y, nu_z):
        nu_mean = max(np.mean([nu_x, nu_y, nu_z]), 1e-10)
        n0 = max(N * (self.m * nu_mean**2 / (2 * np.pi * k * max(T, 1e-10)))**(3/2), 1e-10)
        v_mean = np.sqrt(8 * k * max(T, 1e-10) / (np.pi * self.m))
        return 8 * np.pi * self.a**2 * n0 * v_mean

    def psd(self, N, T, nu_x, nu_y, nu_z):
        return max(N * (h * np.mean([nu_x, nu_y, nu_z]) / (k * max(T, 1e-10)))**3, 1e-10)

    def bec_fraction(self, N, T, nu_x, nu_y, nu_z):
        Tc = self.critical_temperature(N, nu_x, nu_y, nu_z)
        if T >= Tc:
            return 0
        else:
            fraction = 1 - (T / Tc)**3
            return max(0, min(fraction, 1)) * (1 - np.exp(-(Tc - T) / (0.1 * Tc)))  # Smoother transition

    def raman_cooling_rate(self, T, Omega_R, Gamma_OP, delta):
        recoil_energy = (h ** 2) / (2 * self.m * self.wavelength ** 2)
        eta = recoil_energy / (k * T)
        base_rate = 1e5 * eta * Omega_R**2 * Gamma_OP / (4 * delta**2) * np.sqrt(self.m / (2 * k * T)) * (1 + (T / (1e-6))**2)
        return base_rate * self.params['raman_cooling_efficiency']

    def heating_rate(self, N, T, nu_x, nu_y, nu_z):
        nu_mean = np.mean([nu_x, nu_y, nu_z])
        return 1.5 * h * nu_mean * self.collision_rate(N, T, nu_x, nu_y, nu_z) / (3 * k)

    def light_assisted_loss_rate(self, N, T, nu_x, nu_y, nu_z, Gamma_OP):
        nu_mean = np.mean([nu_x, nu_y, nu_z])
        n0 = N * (self.m * nu_mean**2 / (2 * np.pi * k * T))**(3/2)
        beta = 5e-15  # Further adjusted coefficient
        return beta * Gamma_OP * n0 * (T / (1e-6))**0.5

    def evaporation_rate(self, N, T, nu_x, nu_y, nu_z, eta, t):
        tilt_factor = self.params['tilt_factor'] * (1 + t / self.stages[-1]['end_time'])  # Increase tilt factor over time
        collision_rate = self.collision_rate(N, T, nu_x, nu_y, nu_z)
        trap_depth = eta * k * T
        evap_rate = tilt_factor * collision_rate * np.exp(-eta) * (eta - 4) / (eta - 5)
        return evap_rate * self.params['evap_efficiency'] * (1 + T / (1e-6)) * (1 + t / self.stages[-1]['end_time'])  # Time-dependent efficiency


    def mot_loading(self, N, T, t, stage_duration):
        N_final = 6e5  # Adjusted final atom number after MOT loading
        T_final = 100e-6  # Final temperature after MOT loading (estimate)
        N_new = N_final + (N - N_final) * np.exp(-3 * t / stage_duration)
        T_new = T_final + (T - T_final) * np.exp(-3 * t / stage_duration)
        return N_new, T_new

    def mot_compression(self, N, T, t, stage_duration):
        N_final = 2.7e5  # Final atom number after compression (from paper)
        T_final = 35e-6  # Temperature at the end of compression (from paper)
        N_new = N_final + (N - N_final) * np.exp(-5 * t / stage_duration)
        T_new = T_final + (T - T_final) * np.exp(-5 * t / stage_duration)
        return N_new, T_new

    def gray_molasses_cooling(self, T, t):
        T_final = self.params['gray_molasses_T_final']
        return T_final + (T - T_final) * np.exp(-10 * t / self.params['gray_molasses_duration'])

    def critical_temperature(self, N, nu_x, nu_y, nu_z):
        omega_mean = 2 * np.pi * np.mean([nu_x, nu_y, nu_z])
        N = max(N, 1e-10)  # Ensure N is not too small
        Tc_ideal = hbar * omega_mean * (N / zeta(3))**(1/3) / k
        
        # Finite size correction
        delta_Tc_fs = -0.73 * (omega_mean / (2*np.pi*max(nu_x, 1e-10)) + omega_mean / (2*np.pi*max(nu_y, 1e-10)) + omega_mean / (2*np.pi*max(nu_z, 1e-10))) * Tc_ideal / N**(1/3)
        
        # Interaction shift
        a_ho = np.sqrt(hbar / (self.m * omega_mean))
        delta_Tc_int = self.params['interaction_shift'] * Tc_ideal * (N**(1/6) * self.a / a_ho)
        
        Tc = max(Tc_ideal + delta_Tc_fs + delta_Tc_int, 1e-9)
        
        return Tc

    def system_evolution(self, t, state):
        N, T = state
        N = max(N, 1e-10)
        T = max(T, self.params['min_temperature'])

        stage = next((s for s in self.stages if s['start_time'] <= t < s['end_time']), self.stages[-1])

        # Initialize nu_x, nu_y, nu_z with default values
        nu_x = nu_y = nu_z = 1.0  # Default to 1 Hz if not set

        if stage['name'] == 'MOTLoading':
            N, T = self.mot_loading(N, T, t - stage['start_time'], stage['duration'])
            dNdt = (N - state[0]) / stage['duration']
            dTdt = (T - state[1]) / stage['duration']
        elif stage['name'] == 'MOTCompression':
            N, T = self.mot_compression(N, T, t - stage['start_time'], stage['duration'])
            dNdt = (N - state[0]) / stage['duration']
            dTdt = (T - state[1]) / stage['duration']
            
            # Apply gray molasses cooling at the end of compression
            if t > (stage['end_time'] - self.params['gray_molasses_duration']):
                T = self.gray_molasses_cooling(T, t - (stage['end_time'] - self.params['gray_molasses_duration']))
                dTdt = (T - state[1]) / self.params['gray_molasses_duration']
        elif stage['name'] == 'MagneticFieldAdjustment':
            dNdt = -self.params['gamma_bg'] * N
            dTdt = 0  # Assume temperature doesn't change during this brief period
        else:
            P_x = self.params[f'{stage["name"]}_P_x'] if f'{stage["name"]}_P_x' in self.params else 1.0
            P_y = self.params[f'{stage["name"]}_P_y'] if f'{stage["name"]}_P_y' in self.params else 1.0
            nu_x, nu_y, nu_z = self.trap_frequencies(P_x, P_y, t)

            if stage['name'].startswith('Raman'):
                Omega_R = self.params[f'{stage["name"]}_Omega_R']
                Gamma_OP = self.params[f'{stage["name"]}_Gamma_OP']
                delta = self.params[f'{stage["name"]}_delta']
                gamma_cool = self.raman_cooling_rate(T, Omega_R, Gamma_OP, delta)
                gamma_heat = self.heating_rate(N, T, nu_x, nu_y, nu_z)
                dNdt = -self.params['gamma_bg'] * N - self.light_assisted_loss_rate(N, T, nu_x, nu_y, nu_z, Gamma_OP)
                dTdt = -gamma_cool * T + gamma_heat
            elif stage['name'].startswith('Evap'):
                eta = self.params[f'{stage["name"]}_eta']
                gamma_evap = self.evaporation_rate(N, T, nu_x, nu_y, nu_z, eta, t)
                dNdt = -self.params['gamma_bg'] * N - gamma_evap * N
                dTdt = -(eta - 3) / 3 * gamma_evap * T

        # Add three-body loss
        n0 = N * (self.m * np.mean([nu_x, nu_y, nu_z])**2 / (2 * np.pi * k * T))**(3/2)
        dNdt -= self.params['K3'] * n0**2 * N

        # Enhance cooling and evaporation effects
        dTdt *= 1.5
        dNdt *= 1.1

        # Prevent temperature from going below minimum
        if T + dTdt * 1e-3 < self.params['min_temperature']:
            dTdt = (self.params['min_temperature'] - T) / 1e-3

        psd = self.psd(N, T, nu_x, nu_y, nu_z)
        bec_frac = self.bec_fraction(N, T, nu_x, nu_y, nu_z)

        print(f"Time: {t*1e3:.1f} ms, Stage: {stage['name']}, T: {T*1e6:.2f} µK, N: {N:.2e}, PSD: {psd:.2e}, BEC fraction: {bec_frac:.2%}")

        return [dNdt, dTdt]

    def calculate_cooling_slope(self, results):
        if len(results) < 3:
            return float('nan')
        log_psd = np.log10([max(r['PSD'], 1e-10) for r in results])
        log_N = np.log10([max(r['N'], 1e-10) for r in results])
        weights = np.array([r['N'] for r in results])  # Use atom number as weight

        # Remove any non-finite values
        mask = np.isfinite(log_psd) & np.isfinite(log_N) & np.isfinite(weights)
        log_psd = log_psd[mask]
        log_N = log_N[mask]
        weights = weights[mask]

        if len(log_psd) < 3:
            return float('nan')

        try:
            with warnings.catch_warnings():
                warnings.simplefilter('ignore', np.RankWarning)
                slope, _ = np.polyfit(log_N, log_psd, 1, w=weights)
            return -slope
        except (ValueError, np.linalg.LinAlgError):
            return float('nan')

    def run_simulation(self):
        t_span = (0, self.stages[-1]['end_time'])
        t_eval = np.linspace(0, t_span[1], 1000)

        def event_stage_change(t, y):
            for stage in self.stages:
                if stage['end_time'] > t:
                    return t - stage['end_time']
            return 0

        event_stage_change.terminal = True
        event_stage_change.direction = 1

        sol = solve_ivp(
            self.system_evolution,
            t_span,
            [self.params['initial_N'], self.params['initial_T']],
            t_eval=t_eval,
            method='RK45',
            events=event_stage_change,
            rtol=1e-8,
            atol=1e-8
        )

        results = []
        for t, N, T in zip(sol.t, sol.y[0], sol.y[1]):
            stage = next((s for s in self.stages if s['start_time'] <= t <= s['end_time']), self.stages[-1])
            P_x = self.params[f'{stage["name"]}_P_x'] if f'{stage["name"]}_P_x' in self.params else 1.0
            P_y = self.params[f'{stage["name"]}_P_y'] if f'{stage["name"]}_P_y' in self.params else 1.0
            nu_x, nu_y, nu_z = self.trap_frequencies(P_x, P_y, t)
            nu_c = self.collision_rate(N, T, nu_x, nu_y, nu_z)
            psd = self.psd(N, T, nu_x, nu_y, nu_z)
            bec_frac = self.bec_fraction(N, T, nu_x, nu_y, nu_z)

            results.append({
                'time': t,
                'stage': stage['name'],
                'N': N,
                'T': T,
                'PSD': psd,
                'nu_x': nu_x,
                'nu_y': nu_y,
                'nu_z': nu_z,
                'nu_c': nu_c,
                'BEC_fraction': bec_frac
            })

        return results

class BECVisualizer:
    def __init__(self, simulation):
        self.sim = simulation
        self.imaging_resolution = 5e-6  # 5 micrometers
        self.tof = 20e-3  # 20 ms time-of-flight
        self.vmin = None
        self.vmax = None
        self.xlim = (-1000e-6, 1000e-6)  # ±1000 µm x-axis range
        self.ylim = (-1000e-6, 1000e-6)  # ±1000 µm y-axis range

    def calculate_density_range(self, results):
        densities = []
        for result in results:
            if result['stage'] != 'MOTLoading' and result['stage'] != 'MOTCompression':  # Only consider frames after MOT stages
                frame_data = self.generate_frame(result)
                densities.extend(frame_data.flatten())
        self.vmin = np.min(densities)
        self.vmax = np.max(densities)

    def generate_frame(self, result, grid_size=200):
        x = np.linspace(self.xlim[0], self.xlim[1], grid_size)
        y = np.linspace(self.ylim[0], self.ylim[1], grid_size)
        X, Y = np.meshgrid(x, y)

        N, T = result['N'], result['T']
        nu_x, nu_y, nu_z = result['nu_x'], result['nu_y'], result['nu_z']
        bec_fraction = result['BEC_fraction']

        nu_x = max(nu_x, 1e-10)
        nu_y = max(nu_y, 1e-10)

        epsilon = 1e-10
        sigma_x = np.sqrt(max(k * T / (self.sim.m * (2*np.pi*nu_x)**2), epsilon) + (h * nu_x / (2*np.pi*self.sim.m))**2 * self.tof**2)
        sigma_y = np.sqrt(max(k * T / (self.sim.m * (2*np.pi*nu_y)**2), epsilon) + (h * nu_y / (2*np.pi*self.sim.m))**2 * self.tof**2)

        n_thermal = N * (1 - bec_fraction) * np.exp(-(X**2 / (2*sigma_x**2) + Y**2 / (2*sigma_y**2))) / (2*np.pi*sigma_x*sigma_y)
        
        if bec_fraction > 0:
            R_x = np.sqrt(2 * h * nu_x * N * bec_fraction * self.sim.a / (self.sim.m * (2*np.pi*nu_x)**2))
            R_y = np.sqrt(2 * h * nu_y * N * bec_fraction * self.sim.a / (self.sim.m * (2*np.pi*nu_y)**2))
            n_bec = N * bec_fraction * np.maximum(0, 1 - X**2/R_x**2 - Y**2/R_y**2)**(3/2) / (4*np.pi*R_x*R_y/3)
        else:
            n_bec = np.zeros_like(X)

        n_total = n_thermal + n_bec

        # Calculate column density (integrate along z-axis)
        column_density = n_total * np.sqrt(2 * np.pi) * sigma_y

        # Calculate optical depth
        cross_section = 3 * (780e-9)**2 / (2 * np.pi)  # Absorption cross-section for Rb87
        od = column_density * cross_section

        # Add realistic noise
        od_with_noise = od + np.random.normal(0, 0.05 * np.max(od), od.shape)

        # Simulate finite imaging resolution
        od_blurred = gaussian_filter(od_with_noise, sigma=self.imaging_resolution / (self.xlim[1] - self.xlim[0]) * grid_size)

        od_blurred = np.clip(od_blurred, 1e-10, np.inf)

        return od_blurred

    def create_animation(self, results, output_filename):
        fig, ax = plt.subplots(figsize=(10, 8))

        # Calculate global vmin and vmax for frames after MOT stages
        self.calculate_density_range(results)
        
        def update(frame):
            ax.clear()
            result = results[frame]
            frame_data = self.generate_frame(result)
            
            if result['stage'] == 'MOTLoading' or result['stage'] == 'MOTCompression':
                im = ax.imshow(frame_data, cmap='jet', norm=LogNorm(), extent=[self.xlim[0]*1e6, self.xlim[1]*1e6, self.ylim[0]*1e6, self.ylim[1]*1e6])
            else:
                im = ax.imshow(frame_data, cmap='jet', norm=LogNorm(vmin=self.vmin, vmax=self.vmax), extent=[self.xlim[0]*1e6, self.xlim[1]*1e6, self.ylim[0]*1e6, self.ylim[1]*1e6])
            
            ax.set_title(f"Time: {result['time']*1e3:.1f} ms, Stage: {result['stage']}\n"
                         f"T: {result['T']*1e6:.2f} µK, N: {result['N']:.2e}, "
                         f"BEC fraction: {result['BEC_fraction']:.2%}")
            ax.set_xlabel('x (µm)')
            ax.set_ylabel('y (µm)')
            return [im]

        anim = FuncAnimation(fig, update, frames=len(results), interval=200, blit=True)
        
        writer = animation.FFMpegWriter(fps=5, metadata=dict(artist='Me'), bitrate=1800)
        anim.save(output_filename, writer=writer)
        
        plt.close(fig)

# Main script
if __name__ == "__main__":
    # Run simulation and create visualization
    sim = BECSimulation()
    results = sim.run_simulation()

    visualizer = BECVisualizer(sim)
    visualizer.create_animation(results, 'bec_evolution.mp4')

    print("Animation creation complete. Check 'bec_evolution.mp4'.")

    # Plot additional results
    times = [result['time'] * 1e3 for result in results]  # Convert to ms
    N_values = [result['N'] for result in results]
    T_values = [result['T'] for result in results]
    PSD_values = [result['PSD'] for result in results]
    BEC_fraction_values = [result['BEC_fraction'] for result in results]

    plt.figure(figsize=(12, 10))

    plt.subplot(4, 1, 1)
    plt.semilogy(times, N_values)
    plt.ylabel('Atom Number')
    plt.title('BEC Formation Simulation Results')

    plt.subplot(4, 1, 2)
    plt.semilogy(times, T_values)
    plt.ylabel('Temperature (K)')

    plt.subplot(4, 1, 3)
    plt.semilogy(times, PSD_values)
    plt.ylabel('Phase Space Density')

    plt.subplot(4, 1, 4)
    plt.plot(times, BEC_fraction_values)
    plt.ylabel('BEC Fraction')
    plt.xlabel('Time (ms)')

    plt.tight_layout()
    plt.savefig('bec_formation_results.png')
    plt.close()

    print("Additional results plot saved as 'bec_formation_results.png'.")

    # Print final results
    final_result = results[-1]
    print(f"Final atom number: {final_result['N']:.2e}")
    print(f"Final temperature: {final_result['T']*1e6:.2f} µK")
    print(f"Final BEC fraction: {final_result['BEC_fraction']:.2%}")
    print(f"Final phase space density: {final_result['PSD']:.2e}")

    # Calculate and print the cooling slope for different stages
    raman_start = next(r for r in results if r['stage'] == 'Raman1')
    raman_end = next(r for r in results if r['stage'] == 'Evap1')
    evap_start = raman_end
    evap_end = results[-1]

    raman_slope = sim.calculate_cooling_slope([r for r in results if raman_start['time'] <= r['time'] < raman_end['time']])
    evap_slope = sim.calculate_cooling_slope([r for r in results if evap_start['time'] <= r['time'] <= evap_end['time']])
    overall_slope = sim.calculate_cooling_slope(results)

    print(f"Raman cooling slope γ: {raman_slope:.2f}")
    print(f"Evaporative cooling slope γ: {evap_slope:.2f}")
    print(f"Overall cooling slope γ: {overall_slope:.2f}")

    # Compare with paper results
    paper_final_N = 2.8e3
    paper_final_BEC_fraction = 0.76

    N_difference = (final_result['N'] - paper_final_N) / paper_final_N * 100
    BEC_fraction_difference = (final_result['BEC_fraction'] - paper_final_BEC_fraction) / paper_final_BEC_fraction * 100

    print(f"Comparison with paper results:")
    print(f"Final atom number: {final_result['N']:.2e} (Difference: {N_difference:.2f}%)")
    print(f"Final BEC fraction: {final_result['BEC_fraction']:.2%} (Difference: {BEC_fraction_difference:.2f}%)")
    print(f"Paper reported cooling slope γ: ~16")
    print(f"Our overall cooling slope γ: {overall_slope:.2f}")

    # Plot cooling process
    plt.figure(figsize=(12, 8))
    for stage in sim.stages:
        stage_results = [r for r in results if r['stage'] == stage['name']]
        if stage_results:
            log_psd = np.log10([max(r['PSD'], 1e-10) for r in stage_results])
            log_N = np.log10([max(r['N'], 1e-10) for r in stage_results])
            plt.plot(log_N, log_psd, 'o-', label=stage['name'])

    plt.xlabel('log(N)')
    plt.ylabel('log(PSD)')
    plt.legend()
    plt.title('Cooling Process: PSD vs N')
    plt.savefig('cooling_process.png')
    plt.close()

    print("Cooling process plot saved as 'cooling_process.png'.")

    # Additional analysis: Trap frequencies and collision rates
    plt.figure(figsize=(12, 8))
    plt.subplot(2, 1, 1)
    plt.plot(times, [r['nu_x'] for r in results], label='νx')
    plt.plot(times, [r['nu_y'] for r in results], label='νy')
    plt.plot(times, [r['nu_z'] for r in results], label='νz')
    plt.ylabel('Trap Frequency (Hz)')
    plt.legend()
    plt.title('Trap Frequencies and Collision Rates')

    plt.subplot(2, 1, 2)
    plt.plot(times, [r['nu_c'] for r in results], label='Collision Rate')
    plt.plot(times, [np.mean([r['nu_x'], r['nu_y'], r['nu_z']]) for r in results], label='Mean Trap Frequency')
    plt.ylabel('Frequency (Hz)')
    plt.xlabel('Time (ms)')
    plt.legend()

    plt.tight_layout()
    plt.savefig('trap_and_collision_rates.png')
    plt.close()

    print("Trap frequencies and collision rates plot saved as 'trap_and_collision_rates.png'.")

    # Analyze collision rate vs trap frequency
    collision_rates = [r['nu_c'] for r in results]
    mean_trap_freqs = [np.mean([r['nu_x'], r['nu_y'], r['nu_z']]) for r in results]
    ratio = [c / f if f != 0 else 0 for c, f in zip(collision_rates, mean_trap_freqs)]

    plt.figure(figsize=(10, 6))
    plt.plot(times, ratio)
    plt.axhline(y=1, color='r', linestyle='--')
    plt.ylabel('Collision Rate / Mean Trap Frequency')
    plt.xlabel('Time (ms)')
    plt.title('Ratio of Collision Rate to Mean Trap Frequency')
    plt.savefig('collision_rate_ratio.png')
    plt.close()

    print("Collision rate ratio plot saved as 'collision_rate_ratio.png'.")

    # Print some statistics about the ratio
    print(f"Mean ratio of collision rate to trap frequency: {np.mean(ratio):.2f}")
    print(f"Maximum ratio: {np.max(ratio):.2f}")
    print(f"Minimum ratio: {np.min(ratio):.2f}")

    # Analyze cooling efficiency
    cooling_efficiency = []
    for i in range(1, len(results)):
        dN = results[i]['N'] - results[i-1]['N']
        dPSD = results[i]['PSD'] - results[i-1]['PSD']
        if dN != 0 and results[i-1]['N'] != 0 and results[i-1]['PSD'] > 0 and results[i]['PSD'] > 0:
            efficiency = (np.log10(results[i]['PSD']) - np.log10(results[i-1]['PSD'])) / (np.log10(results[i-1]['N']) - np.log10(results[i]['N']))
            cooling_efficiency.append(efficiency)

    plt.figure(figsize=(10, 6))
    plt.plot(times[1:len(cooling_efficiency)+1], cooling_efficiency)
    plt.ylabel('Cooling Efficiency')
    plt.xlabel('Time (ms)')
    plt.title('Cooling Efficiency over Time')
    plt.savefig('cooling_efficiency.png')
    plt.close()

    print("Cooling efficiency plot saved as 'cooling_efficiency.png'.")

    # Analyze PSD increase rate
    psd_increase_rate = []
    for i in range(1, len(results)):
        dt = results[i]['time'] - results[i-1]['time']
        if dt > 0:
            rate = (np.log10(results[i]['PSD']) - np.log10(results[i-1]['PSD'])) / dt
            psd_increase_rate.append(rate)

    plt.figure(figsize=(10, 6))
    plt.plot(times[1:len(psd_increase_rate)+1], psd_increase_rate)
    plt.ylabel('PSD Increase Rate (log10(PSD)/s)')
    plt.xlabel('Time (ms)')
    plt.title('PSD Increase Rate over Time')
    plt.savefig('psd_increase_rate.png')
    plt.close()

    print("PSD increase rate plot saved as 'psd_increase_rate.png'.")

    print("Simulation and analysis complete.")
# Out:
# Time: 0.0 ms, Stage: MOTLoading, T: 30.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 0.0 ms, Stage: MOTLoading, T: 30.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 0.0 ms, Stage: MOTLoading, T: 30.05 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 0.0 ms, Stage: MOTLoading, T: 30.07 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 0.1 ms, Stage: MOTLoading, T: 30.19 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 0.1 ms, Stage: MOTLoading, T: 30.21 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 0.1 ms, Stage: MOTLoading, T: 30.24 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 0.1 ms, Stage: MOTLoading, T: 30.24 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 0.3 ms, Stage: MOTLoading, T: 30.71 µK, N: 2.73e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 0.4 ms, Stage: MOTLoading, T: 30.94 µK, N: 2.74e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 0.9 ms, Stage: MOTLoading, T: 32.11 µK, N: 2.80e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 1.0 ms, Stage: MOTLoading, T: 32.31 µK, N: 2.81e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 1.1 ms, Stage: MOTLoading, T: 32.57 µK, N: 2.82e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 1.1 ms, Stage: MOTLoading, T: 32.57 µK, N: 2.82e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 2.5 ms, Stage: MOTLoading, T: 35.67 µK, N: 2.97e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 3.2 ms, Stage: MOTLoading, T: 37.23 µK, N: 3.04e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 6.6 ms, Stage: MOTLoading, T: 44.55 µK, N: 3.38e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 7.2 ms, Stage: MOTLoading, T: 45.79 µK, N: 3.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 7.9 ms, Stage: MOTLoading, T: 47.32 µK, N: 3.51e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 7.9 ms, Stage: MOTLoading, T: 47.32 µK, N: 3.51e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 9.3 ms, Stage: MOTLoading, T: 49.99 µK, N: 3.63e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 10.0 ms, Stage: MOTLoading, T: 51.32 µK, N: 3.69e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 13.5 ms, Stage: MOTLoading, T: 57.47 µK, N: 3.97e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 14.1 ms, Stage: MOTLoading, T: 58.50 µK, N: 4.02e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 14.8 ms, Stage: MOTLoading, T: 59.76 µK, N: 4.08e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 14.8 ms, Stage: MOTLoading, T: 59.76 µK, N: 4.08e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 16.2 ms, Stage: MOTLoading, T: 61.90 µK, N: 4.17e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 16.9 ms, Stage: MOTLoading, T: 62.94 µK, N: 4.22e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 20.2 ms, Stage: MOTLoading, T: 67.79 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 20.8 ms, Stage: MOTLoading, T: 68.59 µK, N: 4.48e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 21.6 ms, Stage: MOTLoading, T: 69.57 µK, N: 4.52e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 21.6 ms, Stage: MOTLoading, T: 69.57 µK, N: 4.52e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 23.0 ms, Stage: MOTLoading, T: 71.30 µK, N: 4.60e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 23.7 ms, Stage: MOTLoading, T: 72.14 µK, N: 4.64e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 27.1 ms, Stage: MOTLoading, T: 76.00 µK, N: 4.82e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 27.7 ms, Stage: MOTLoading, T: 76.63 µK, N: 4.85e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 28.5 ms, Stage: MOTLoading, T: 77.41 µK, N: 4.89e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 28.5 ms, Stage: MOTLoading, T: 77.41 µK, N: 4.89e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 29.9 ms, Stage: MOTLoading, T: 78.80 µK, N: 4.95e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 30.6 ms, Stage: MOTLoading, T: 79.46 µK, N: 4.98e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 34.2 ms, Stage: MOTLoading, T: 82.51 µK, N: 5.12e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 34.8 ms, Stage: MOTLoading, T: 83.01 µK, N: 5.15e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 35.6 ms, Stage: MOTLoading, T: 83.61 µK, N: 5.17e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 35.6 ms, Stage: MOTLoading, T: 83.61 µK, N: 5.17e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 37.1 ms, Stage: MOTLoading, T: 84.71 µK, N: 5.23e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 37.9 ms, Stage: MOTLoading, T: 85.23 µK, N: 5.25e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 41.7 ms, Stage: MOTLoading, T: 87.60 µK, N: 5.36e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 42.4 ms, Stage: MOTLoading, T: 87.98 µK, N: 5.38e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 43.2 ms, Stage: MOTLoading, T: 88.44 µK, N: 5.40e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 43.2 ms, Stage: MOTLoading, T: 88.44 µK, N: 5.40e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 44.8 ms, Stage: MOTLoading, T: 89.29 µK, N: 5.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 45.7 ms, Stage: MOTLoading, T: 89.69 µK, N: 5.46e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 49.7 ms, Stage: MOTLoading, T: 91.50 µK, N: 5.55e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 50.5 ms, Stage: MOTLoading, T: 91.79 µK, N: 5.56e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 51.4 ms, Stage: MOTLoading, T: 92.13 µK, N: 5.58e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 51.4 ms, Stage: MOTLoading, T: 92.13 µK, N: 5.58e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 53.2 ms, Stage: MOTLoading, T: 92.78 µK, N: 5.61e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 54.1 ms, Stage: MOTLoading, T: 93.08 µK, N: 5.63e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 58.6 ms, Stage: MOTLoading, T: 94.42 µK, N: 5.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 59.3 ms, Stage: MOTLoading, T: 94.64 µK, N: 5.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 60.3 ms, Stage: MOTLoading, T: 94.89 µK, N: 5.72e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 60.3 ms, Stage: MOTLoading, T: 94.89 µK, N: 5.72e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 62.4 ms, Stage: MOTLoading, T: 95.37 µK, N: 5.74e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 63.4 ms, Stage: MOTLoading, T: 95.60 µK, N: 5.75e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 68.6 ms, Stage: MOTLoading, T: 96.57 µK, N: 5.81e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 69.5 ms, Stage: MOTLoading, T: 96.73 µK, N: 5.81e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 70.6 ms, Stage: MOTLoading, T: 96.90 µK, N: 5.82e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 70.6 ms, Stage: MOTLoading, T: 96.90 µK, N: 5.82e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 73.3 ms, Stage: MOTLoading, T: 97.29 µK, N: 5.84e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 74.7 ms, Stage: MOTLoading, T: 97.46 µK, N: 5.85e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 81.4 ms, Stage: MOTLoading, T: 98.18 µK, N: 5.89e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 82.6 ms, Stage: MOTLoading, T: 98.28 µK, N: 5.90e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 84.1 ms, Stage: MOTLoading, T: 98.41 µK, N: 5.90e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 84.1 ms, Stage: MOTLoading, T: 98.40 µK, N: 5.90e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 86.8 ms, Stage: MOTLoading, T: 98.61 µK, N: 5.91e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 88.1 ms, Stage: MOTLoading, T: 98.70 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 94.9 ms, Stage: MOTCompression, T: 37.18 µK, N: 2.80e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 96.1 ms, Stage: MOTCompression, T: 36.92 µK, N: 2.78e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.6 ms, Stage: MOTCompression, T: 35.76 µK, N: 2.73e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.6 ms, Stage: MOTCompression, T: 35.21 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 84.6 ms, Stage: MOTLoading, T: 98.45 µK, N: 5.91e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 84.9 ms, Stage: MOTLoading, T: 98.47 µK, N: 5.91e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 86.2 ms, Stage: MOTLoading, T: 98.57 µK, N: 5.91e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 86.5 ms, Stage: MOTLoading, T: 98.58 µK, N: 5.91e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 86.8 ms, Stage: MOTLoading, T: 98.60 µK, N: 5.91e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 86.8 ms, Stage: MOTLoading, T: 98.60 µK, N: 5.91e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.3 ms, Stage: MOTLoading, T: 98.64 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.6 ms, Stage: MOTLoading, T: 98.66 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.2 ms, Stage: MOTCompression, T: 71.14 µK, N: 4.28e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.5 ms, Stage: MOTCompression, T: 66.74 µK, N: 4.08e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.5 ms, Stage: MOTCompression, T: 66.35 µK, N: 4.07e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 86.9 ms, Stage: MOTLoading, T: 98.61 µK, N: 5.91e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.0 ms, Stage: MOTLoading, T: 98.62 µK, N: 5.91e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.2 ms, Stage: MOTLoading, T: 98.63 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.3 ms, Stage: MOTLoading, T: 98.64 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.3 ms, Stage: MOTLoading, T: 98.64 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.3 ms, Stage: MOTLoading, T: 98.64 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.4 ms, Stage: MOTLoading, T: 98.65 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.5 ms, Stage: MOTLoading, T: 98.65 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.8 ms, Stage: MOTLoading, T: 98.67 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.8 ms, Stage: MOTLoading, T: 98.67 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.9 ms, Stage: MOTLoading, T: 98.68 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 87.9 ms, Stage: MOTLoading, T: 98.68 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.5 ms, Stage: MOTCompression, T: 66.18 µK, N: 4.06e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 92.2 ms, Stage: MOTCompression, T: 36.54 µK, N: 2.83e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 92.7 ms, Stage: MOTCompression, T: 29.49 µK, N: 2.49e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 93.3 ms, Stage: MOTCompression, T: 30.92 µK, N: 2.54e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 93.3 ms, Stage: MOTCompression, T: 38.14 µK, N: 2.85e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 88.1 ms, Stage: MOTLoading, T: 98.69 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 88.2 ms, Stage: MOTLoading, T: 98.70 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 88.7 ms, Stage: MOTLoading, T: 98.73 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 88.8 ms, Stage: MOTLoading, T: 98.74 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.2 ms, Stage: MOTCompression, T: 71.56 µK, N: 4.30e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.3 ms, Stage: MOTCompression, T: 69.48 µK, N: 4.21e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.8 ms, Stage: MOTCompression, T: 60.97 µK, N: 3.84e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.9 ms, Stage: MOTCompression, T: 60.02 µK, N: 3.81e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 90.0 ms, Stage: MOTCompression, T: 58.38 µK, N: 3.73e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 90.0 ms, Stage: MOTCompression, T: 57.86 µK, N: 3.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.29 µK, N: 4.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.1 ms, Stage: MOTCompression, T: 73.59 µK, N: 4.39e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.2 ms, Stage: MOTCompression, T: 70.37 µK, N: 4.25e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.3 ms, Stage: MOTCompression, T: 69.98 µK, N: 4.23e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.3 ms, Stage: MOTCompression, T: 69.27 µK, N: 4.20e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.3 ms, Stage: MOTCompression, T: 69.04 µK, N: 4.19e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.1 ms, Stage: MOTCompression, T: 73.69 µK, N: 4.39e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.1 ms, Stage: MOTCompression, T: 73.50 µK, N: 4.38e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.1 ms, Stage: MOTCompression, T: 73.21 µK, N: 4.37e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.1 ms, Stage: MOTCompression, T: 73.18 µK, N: 4.37e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.80 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.80 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.61 µK, N: 4.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.34 µK, N: 4.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.1 ms, Stage: MOTCompression, T: 73.07 µK, N: 4.36e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.1 ms, Stage: MOTCompression, T: 72.93 µK, N: 4.36e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.1 ms, Stage: MOTCompression, T: 72.64 µK, N: 4.35e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.1 ms, Stage: MOTCompression, T: 72.51 µK, N: 4.34e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.80 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.17 µK, N: 4.41e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 73.94 µK, N: 4.40e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 73.83 µK, N: 4.40e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.01 µK, N: 4.41e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.69 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.65 µK, N: 4.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.58 µK, N: 4.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.58 µK, N: 4.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.87 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.87 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.72 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.62 µK, N: 4.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.12 µK, N: 4.41e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.07 µK, N: 4.41e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 73.95 µK, N: 4.40e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 73.90 µK, N: 4.40e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.83 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.77 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.52 µK, N: 4.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.50 µK, N: 4.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.44 µK, N: 4.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.41 µK, N: 4.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.87 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.84 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.69 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.68 µK, N: 4.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.64 µK, N: 4.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.63 µK, N: 4.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.87 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.76 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.72 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.70 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.73 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.82 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.81 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.79 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.79 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.86 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.85 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.84 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.84 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.88 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.88 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.87 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.87 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTLoading, T: 98.75 µK, N: 5.92e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.88 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.87 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.85 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.85 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.84 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.84 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.83 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.83 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.81 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.80 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.80 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.80 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.72 µK, N: 4.44e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.68 µK, N: 4.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.47 µK, N: 4.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.43 µK, N: 4.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.39 µK, N: 4.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.0 ms, Stage: MOTCompression, T: 74.39 µK, N: 4.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.1 ms, Stage: MOTCompression, T: 73.57 µK, N: 4.39e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.1 ms, Stage: MOTCompression, T: 73.17 µK, N: 4.37e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.2 ms, Stage: MOTCompression, T: 71.19 µK, N: 4.28e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.2 ms, Stage: MOTCompression, T: 70.85 µK, N: 4.27e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.2 ms, Stage: MOTCompression, T: 70.43 µK, N: 4.25e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.2 ms, Stage: MOTCompression, T: 70.43 µK, N: 4.25e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.4 ms, Stage: MOTCompression, T: 67.79 µK, N: 4.14e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.5 ms, Stage: MOTCompression, T: 66.49 µK, N: 4.08e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.8 ms, Stage: MOTCompression, T: 60.71 µK, N: 3.83e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 89.9 ms, Stage: MOTCompression, T: 59.78 µK, N: 3.79e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 90.0 ms, Stage: MOTCompression, T: 58.66 µK, N: 3.74e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 90.0 ms, Stage: MOTCompression, T: 58.66 µK, N: 3.74e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 90.1 ms, Stage: MOTCompression, T: 56.78 µK, N: 3.66e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 90.2 ms, Stage: MOTCompression, T: 55.88 µK, N: 3.62e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 90.6 ms, Stage: MOTCompression, T: 51.89 µK, N: 3.45e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 90.6 ms, Stage: MOTCompression, T: 51.26 µK, N: 3.43e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 90.7 ms, Stage: MOTCompression, T: 50.50 µK, N: 3.39e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 90.7 ms, Stage: MOTCompression, T: 50.49 µK, N: 3.39e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 90.9 ms, Stage: MOTCompression, T: 49.17 µK, N: 3.34e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 90.9 ms, Stage: MOTCompression, T: 48.54 µK, N: 3.31e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 91.3 ms, Stage: MOTCompression, T: 45.79 µK, N: 3.19e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 91.4 ms, Stage: MOTCompression, T: 45.37 µK, N: 3.17e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 91.5 ms, Stage: MOTCompression, T: 44.85 µK, N: 3.15e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 91.5 ms, Stage: MOTCompression, T: 44.85 µK, N: 3.15e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 91.6 ms, Stage: MOTCompression, T: 43.93 µK, N: 3.11e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 91.7 ms, Stage: MOTCompression, T: 43.50 µK, N: 3.09e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 92.1 ms, Stage: MOTCompression, T: 41.63 µK, N: 3.01e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 92.2 ms, Stage: MOTCompression, T: 41.35 µK, N: 3.00e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 92.3 ms, Stage: MOTCompression, T: 41.00 µK, N: 2.98e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 92.3 ms, Stage: MOTCompression, T: 41.00 µK, N: 2.98e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 92.5 ms, Stage: MOTCompression, T: 40.38 µK, N: 2.95e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 92.5 ms, Stage: MOTCompression, T: 40.10 µK, N: 2.94e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 93.0 ms, Stage: MOTCompression, T: 38.87 µK, N: 2.89e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 93.1 ms, Stage: MOTCompression, T: 38.69 µK, N: 2.88e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 93.2 ms, Stage: MOTCompression, T: 38.47 µK, N: 2.87e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 93.2 ms, Stage: MOTCompression, T: 38.47 µK, N: 2.87e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 93.4 ms, Stage: MOTCompression, T: 38.07 µK, N: 2.85e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 93.5 ms, Stage: MOTCompression, T: 37.88 µK, N: 2.84e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 93.9 ms, Stage: MOTCompression, T: 37.12 µK, N: 2.80e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 94.0 ms, Stage: MOTCompression, T: 37.00 µK, N: 2.80e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 94.1 ms, Stage: MOTCompression, T: 36.87 µK, N: 2.79e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 94.1 ms, Stage: MOTCompression, T: 36.87 µK, N: 2.79e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 94.4 ms, Stage: MOTCompression, T: 36.62 µK, N: 2.78e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 94.5 ms, Stage: MOTCompression, T: 36.51 µK, N: 2.78e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 95.0 ms, Stage: MOTCompression, T: 36.05 µK, N: 2.75e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 95.1 ms, Stage: MOTCompression, T: 35.98 µK, N: 2.75e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 95.3 ms, Stage: MOTCompression, T: 35.91 µK, N: 2.75e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 95.3 ms, Stage: MOTCompression, T: 35.91 µK, N: 2.75e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 95.6 ms, Stage: MOTCompression, T: 35.75 µK, N: 2.74e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 95.7 ms, Stage: MOTCompression, T: 35.68 µK, N: 2.74e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 96.5 ms, Stage: MOTCompression, T: 35.42 µK, N: 2.72e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 96.6 ms, Stage: MOTCompression, T: 35.38 µK, N: 2.72e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 96.8 ms, Stage: MOTCompression, T: 35.34 µK, N: 2.72e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 96.8 ms, Stage: MOTCompression, T: 35.34 µK, N: 2.72e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.1 ms, Stage: MOTCompression, T: 35.28 µK, N: 2.72e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.2 ms, Stage: MOTCompression, T: 35.26 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.0 ms, Stage: MOTCompression, T: 35.16 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.1 ms, Stage: MOTCompression, T: 35.06 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.3 ms, Stage: MOTCompression, T: 35.02 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.3 ms, Stage: MOTCompression, T: 35.01 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 96.9 ms, Stage: MOTCompression, T: 35.31 µK, N: 2.72e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.0 ms, Stage: MOTCompression, T: 35.30 µK, N: 2.72e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.3 ms, Stage: MOTCompression, T: 35.24 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.4 ms, Stage: MOTCompression, T: 35.23 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.4 ms, Stage: MOTCompression, T: 35.22 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.4 ms, Stage: MOTCompression, T: 35.22 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.6 ms, Stage: MOTCompression, T: 35.20 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.7 ms, Stage: MOTCompression, T: 35.19 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.0 ms, Stage: MOTCompression, T: 35.16 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.1 ms, Stage: MOTCompression, T: 35.09 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.1 ms, Stage: MOTCompression, T: 35.05 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.1 ms, Stage: MOTCompression, T: 35.05 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.5 ms, Stage: MOTCompression, T: 35.21 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.5 ms, Stage: MOTCompression, T: 35.21 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.7 ms, Stage: MOTCompression, T: 35.19 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.7 ms, Stage: MOTCompression, T: 35.18 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.8 ms, Stage: MOTCompression, T: 35.18 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.8 ms, Stage: MOTCompression, T: 35.18 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.8 ms, Stage: MOTCompression, T: 35.17 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 97.9 ms, Stage: MOTCompression, T: 35.17 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.0 ms, Stage: MOTCompression, T: 35.11 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.1 ms, Stage: MOTCompression, T: 35.09 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.1 ms, Stage: MOTCompression, T: 35.06 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.1 ms, Stage: MOTCompression, T: 35.05 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.2 ms, Stage: MOTCompression, T: 35.02 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.2 ms, Stage: MOTCompression, T: 35.01 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.3 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.4 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.4 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.4 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.5 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.6 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.9 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.1 ms, Stage: MagneticFieldAdjustment, T: 35.72 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.1 ms, Stage: MagneticFieldAdjustment, T: 37.75 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.4 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.5 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.5 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.5 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.5 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.5 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.6 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.6 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.6 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.7 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.7 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.7 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.8 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.9 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.3 ms, Stage: MagneticFieldAdjustment, T: 36.37 µK, N: 3.40e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.3 ms, Stage: MagneticFieldAdjustment, T: 34.35 µK, N: 3.38e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.4 ms, Stage: MagneticFieldAdjustment, T: 34.96 µK, N: 3.39e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.4 ms, Stage: MagneticFieldAdjustment, T: 37.56 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.7 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.7 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.8 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.8 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.8 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.8 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.8 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.9 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.9 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 98.9 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.71e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.1 ms, Stage: MagneticFieldAdjustment, T: 37.32 µK, N: 3.41e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.2 ms, Stage: MagneticFieldAdjustment, T: 37.77 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.6 ms, Stage: MagneticFieldAdjustment, T: 34.47 µK, N: 3.36e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.7 ms, Stage: MagneticFieldAdjustment, T: 27.26 µK, N: 3.24e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.8 ms, Stage: MagneticFieldAdjustment, T: 27.65 µK, N: 3.24e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.8 ms, Stage: MagneticFieldAdjustment, T: 37.71 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.83 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.1 ms, Stage: MagneticFieldAdjustment, T: 39.98 µK, N: 3.46e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.1 ms, Stage: MagneticFieldAdjustment, T: 44.10 µK, N: 3.54e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.1 ms, Stage: MagneticFieldAdjustment, T: 43.59 µK, N: 3.53e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.1 ms, Stage: MagneticFieldAdjustment, T: 37.98 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.88 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.80 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.84 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.93 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.80 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.87 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.1 ms, Stage: MagneticFieldAdjustment, T: 37.32 µK, N: 3.41e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.1 ms, Stage: MagneticFieldAdjustment, T: 36.10 µK, N: 3.39e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.1 ms, Stage: MagneticFieldAdjustment, T: 36.17 µK, N: 3.39e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.1 ms, Stage: MagneticFieldAdjustment, T: 37.86 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.88 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.91 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.74 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.39 µK, N: 3.41e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.41 µK, N: 3.41e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.90 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.87 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.84 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.85 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.88 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.87 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.82 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.82 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.93 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 38.01 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 38.00 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.88 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MOTCompression, T: 35.00 µK, N: 2.70e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.88 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.88 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.88 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.88 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.88 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# Time: 99.0 ms, Stage: MagneticFieldAdjustment, T: 37.89 µK, N: 3.42e+05, PSD: 1.00e-10, BEC fraction: 0.00%
# ...
# Time: 523.0 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 523.0 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 523.0 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 523.1 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 523.1 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 523.2 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 523.2 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 523.2 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 523.2 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 523.5 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 523.6 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 524.4 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 524.5 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 524.7 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 524.7 ms, Stage: Evap5, T: 13.37 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 527.7 ms, Stage: Evap5, T: 13.36 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 529.2 ms, Stage: Evap5, T: 13.36 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 536.7 ms, Stage: Evap5, T: 13.36 µK, N: 1.36e+05, PSD: 4.07e-05, BEC fraction: 0.00%
# Time: 538.0 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.07e-05, BEC fraction: 0.00%
# Time: 539.7 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 539.7 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 546.7 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 550.3 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 567.9 ms, Stage: Evap6, T: 13.21 µK, N: 1.35e+05, PSD: 4.11e-05, BEC fraction: 0.00%
# Time: 571.1 ms, Stage: Evap6, T: 13.00 µK, N: 1.33e+05, PSD: 4.23e-05, BEC fraction: 0.00%
# Time: 575.0 ms, Stage: Evap6, T: 13.02 µK, N: 1.33e+05, PSD: 4.21e-05, BEC fraction: 0.00%
# Time: 575.0 ms, Stage: Evap6, T: 13.29 µK, N: 1.36e+05, PSD: 4.04e-05, BEC fraction: 0.00%
# Time: 541.8 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 542.9 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 548.3 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.3 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.5 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.5 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 540.2 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 540.4 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 541.7 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 541.9 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 542.1 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 542.1 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 542.6 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 542.9 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 544.1 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 544.3 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 544.6 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 544.6 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 549.6 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 552.0 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 564.4 ms, Stage: Evap6, T: 13.25 µK, N: 1.35e+05, PSD: 4.09e-05, BEC fraction: 0.00%
# Time: 566.6 ms, Stage: Evap6, T: 13.10 µK, N: 1.34e+05, PSD: 4.17e-05, BEC fraction: 0.00%
# Time: 569.3 ms, Stage: Evap6, T: 13.12 µK, N: 1.34e+05, PSD: 4.16e-05, BEC fraction: 0.00%
# Time: 569.3 ms, Stage: Evap6, T: 13.30 µK, N: 1.36e+05, PSD: 4.04e-05, BEC fraction: 0.00%
# Time: 546.2 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 547.1 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 551.1 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 551.8 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 552.7 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 552.7 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 545.2 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 545.5 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 546.8 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 547.1 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 547.4 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 547.4 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 548.0 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 548.2 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.6 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.9 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.2 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.2 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 547.6 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 547.6 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 548.1 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 548.1 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 548.2 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 548.2 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 548.4 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 548.5 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 548.9 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.0 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.1 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.1 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.7 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 551.6 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 555.7 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 556.5 ms, Stage: Evap6, T: 13.35 µK, N: 1.36e+05, PSD: 4.04e-05, BEC fraction: 0.00%
# Time: 557.4 ms, Stage: Evap6, T: 13.35 µK, N: 1.36e+05, PSD: 4.04e-05, BEC fraction: 0.00%
# Time: 557.4 ms, Stage: Evap6, T: 13.33 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.7 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.1 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 551.8 ms, Stage: Evap6, T: 13.33 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 552.1 ms, Stage: Evap6, T: 13.31 µK, N: 1.36e+05, PSD: 4.07e-05, BEC fraction: 0.00%
# Time: 552.5 ms, Stage: Evap6, T: 13.31 µK, N: 1.36e+05, PSD: 4.07e-05, BEC fraction: 0.00%
# Time: 552.5 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.4 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.6 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.4 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.5 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.7 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.7 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.2 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.3 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.7 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.8 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.8 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.8 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.0 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.1 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.5 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.5 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 550.6 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 550.6 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.9 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.0 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.2 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.3 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.4 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.4 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.9 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.9 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.1 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.1 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.1 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.1 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.9 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.9 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.0 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.0 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.0 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.0 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.9 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 549.9 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.0 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.0 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.0 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.0 ms, Stage: Evap5, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.0 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.0 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.1 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.1 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.1 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.1 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.2 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.2 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.2 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.2 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.3 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.3 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.5 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 550.7 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 551.3 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 551.4 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 551.6 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 551.6 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 554.2 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 555.5 ms, Stage: Evap6, T: 13.33 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 562.1 ms, Stage: Evap6, T: 13.32 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 563.3 ms, Stage: Evap6, T: 13.32 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 564.7 ms, Stage: Evap6, T: 13.32 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 564.7 ms, Stage: Evap6, T: 13.32 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 566.8 ms, Stage: Evap6, T: 13.31 µK, N: 1.36e+05, PSD: 4.04e-05, BEC fraction: 0.00%
# Time: 567.8 ms, Stage: Evap6, T: 13.31 µK, N: 1.36e+05, PSD: 4.04e-05, BEC fraction: 0.00%
# Time: 572.9 ms, Stage: Evap6, T: 13.30 µK, N: 1.36e+05, PSD: 4.04e-05, BEC fraction: 0.00%
# Time: 573.9 ms, Stage: Evap6, T: 13.30 µK, N: 1.36e+05, PSD: 4.04e-05, BEC fraction: 0.00%
# Time: 575.0 ms, Stage: Evap6, T: 13.30 µK, N: 1.36e+05, PSD: 4.04e-05, BEC fraction: 0.00%
# Time: 575.0 ms, Stage: Evap6, T: 13.30 µK, N: 1.36e+05, PSD: 4.04e-05, BEC fraction: 0.00%
# Animation creation complete. Check 'bec_evolution.mp4'.
# Additional results plot saved as 'bec_formation_results.png'.
# Final atom number: 1.36e+05
# Final temperature: 13.30 µK
# Final BEC fraction: 0.00%
# Final phase space density: 4.04e-05
# Raman cooling slope γ: 2.44
# Evaporative cooling slope γ: -8.50
# Overall cooling slope γ: 3.35
# Comparison with paper results:
# Final atom number: 1.36e+05 (Difference: 4747.14%)
# Final BEC fraction: 0.00% (Difference: -100.00%)
# Paper reported cooling slope γ: ~16
# Our overall cooling slope γ: 3.35
# Cooling process plot saved as 'cooling_process.png'.
# Trap frequencies and collision rates plot saved as 'trap_and_collision_rates.png'.
# Collision rate ratio plot saved as 'collision_rate_ratio.png'.
# Mean ratio of collision rate to trap frequency: 0.00
# Maximum ratio: 0.00
# Minimum ratio: 0.00
# Cooling efficiency plot saved as 'cooling_efficiency.png'.
# PSD increase rate plot saved as 'psd_increase_rate.png'.
# Simulation and analysis complete.

# %%
x_values = np.linspace(0, len(results) - 1, 50, dtype=int)
for x in x_values:
    result = results[x]
    print(f"Time: {result['time']*1e3:.1f} ms, Stage: {result['stage']}, "
            f"T: {result['T']*1e6:.2f} µK, N: {result['N']:.2e}, "
            f"PSD: {result['PSD']:.2e}, "
            f"BEC fraction: {result['BEC_fraction']:.2%}")
# Out:
# Time: 0.0 ms, Stage: MOTLoading, T: 30.00 µK, N: 2.70e+05, PSD: 8.84e-06, BEC fraction: 0.00%
# Time: 11.5 ms, Stage: MOTLoading, T: 32.29 µK, N: 2.78e+05, PSD: 7.27e-06, BEC fraction: 0.00%
# Time: 23.0 ms, Stage: MOTLoading, T: 37.80 µK, N: 2.97e+05, PSD: 4.83e-06, BEC fraction: 0.00%
# Time: 35.1 ms, Stage: MOTLoading, T: 45.20 µK, N: 3.24e+05, PSD: 3.06e-06, BEC fraction: 0.00%
# Time: 46.6 ms, Stage: MOTLoading, T: 52.59 µK, N: 3.52e+05, PSD: 2.10e-06, BEC fraction: 0.00%
# Time: 58.1 ms, Stage: MOTLoading, T: 59.62 µK, N: 3.80e+05, PSD: 1.55e-06, BEC fraction: 0.00%
# Time: 70.2 ms, Stage: MOTLoading, T: 66.28 µK, N: 4.07e+05, PSD: 1.20e-06, BEC fraction: 0.00%
# Time: 81.7 ms, Stage: MOTLoading, T: 71.80 µK, N: 4.31e+05, PSD: 9.96e-07, BEC fraction: 0.00%
# Time: 93.8 ms, Stage: MOTCompression, T: 60.44 µK, N: 3.95e+05, PSD: 1.53e-06, BEC fraction: 0.00%
# Time: 105.3 ms, Stage: Raman1, T: 36.89 µK, N: 3.39e+05, PSD: 5.73e-06, BEC fraction: 0.00%
# Time: 116.8 ms, Stage: Raman1, T: 34.85 µK, N: 3.32e+05, PSD: 6.62e-06, BEC fraction: 0.00%
# Time: 128.9 ms, Stage: Raman1, T: 32.88 µK, N: 3.24e+05, PSD: 7.66e-06, BEC fraction: 0.00%
# Time: 140.4 ms, Stage: Raman1, T: 31.16 µK, N: 3.16e+05, PSD: 8.75e-06, BEC fraction: 0.00%
# Time: 152.5 ms, Stage: Raman1, T: 29.49 µK, N: 3.08e+05, PSD: 1.00e-05, BEC fraction: 0.00%
# Time: 164.0 ms, Stage: Raman2, T: 28.04 µK, N: 3.00e+05, PSD: 1.13e-05, BEC fraction: 0.00%
# Time: 175.6 ms, Stage: Raman2, T: 26.78 µK, N: 2.92e+05, PSD: 1.26e-05, BEC fraction: 0.00%
# Time: 187.6 ms, Stage: Raman2, T: 25.55 µK, N: 2.84e+05, PSD: 1.40e-05, BEC fraction: 0.00%
# Time: 199.1 ms, Stage: Raman2, T: 24.46 µK, N: 2.76e+05, PSD: 1.54e-05, BEC fraction: 0.00%
# Time: 210.7 ms, Stage: Raman2, T: 23.43 µK, N: 2.68e+05, PSD: 1.69e-05, BEC fraction: 0.00%
# Time: 222.7 ms, Stage: Raman2, T: 22.42 µK, N: 2.59e+05, PSD: 1.86e-05, BEC fraction: 0.00%
# Time: 234.3 ms, Stage: Raman3, T: 21.57 µK, N: 2.51e+05, PSD: 2.02e-05, BEC fraction: 0.00%
# Time: 246.3 ms, Stage: Raman3, T: 20.75 µK, N: 2.43e+05, PSD: 2.18e-05, BEC fraction: 0.00%
# Time: 257.9 ms, Stage: Raman3, T: 20.01 µK, N: 2.35e+05, PSD: 2.34e-05, BEC fraction: 0.00%
# Time: 269.4 ms, Stage: Raman3, T: 19.31 µK, N: 2.27e+05, PSD: 2.50e-05, BEC fraction: 0.00%
# Time: 281.5 ms, Stage: Raman3, T: 18.61 µK, N: 2.18e+05, PSD: 2.68e-05, BEC fraction: 0.00%
# Time: 293.0 ms, Stage: Raman4, T: 18.00 µK, N: 2.10e+05, PSD: 2.84e-05, BEC fraction: 0.00%
# Time: 305.1 ms, Stage: Raman4, T: 17.42 µK, N: 2.02e+05, PSD: 3.00e-05, BEC fraction: 0.00%
# Time: 316.6 ms, Stage: Raman4, T: 16.89 µK, N: 1.95e+05, PSD: 3.15e-05, BEC fraction: 0.00%
# Time: 328.1 ms, Stage: Raman4, T: 16.39 µK, N: 1.88e+05, PSD: 3.30e-05, BEC fraction: 0.00%
# Time: 340.2 ms, Stage: Raman4, T: 15.89 µK, N: 1.80e+05, PSD: 3.46e-05, BEC fraction: 0.00%
# Time: 351.7 ms, Stage: Raman4, T: 15.43 µK, N: 1.73e+05, PSD: 3.61e-05, BEC fraction: 0.00%
# Time: 363.8 ms, Stage: Raman5, T: 15.01 µK, N: 1.65e+05, PSD: 3.74e-05, BEC fraction: 0.00%
# Time: 375.3 ms, Stage: Raman5, T: 14.62 µK, N: 1.59e+05, PSD: 3.86e-05, BEC fraction: 0.00%
# Time: 386.8 ms, Stage: Raman5, T: 14.25 µK, N: 1.52e+05, PSD: 3.98e-05, BEC fraction: 0.00%
# Time: 398.9 ms, Stage: Raman5, T: 13.88 µK, N: 1.45e+05, PSD: 4.10e-05, BEC fraction: 0.00%
# Time: 410.4 ms, Stage: Raman5, T: 13.53 µK, N: 1.39e+05, PSD: 4.21e-05, BEC fraction: 0.00%
# Time: 421.9 ms, Stage: Evap1, T: 13.40 µK, N: 1.37e+05, PSD: 4.24e-05, BEC fraction: 0.00%
# Time: 434.0 ms, Stage: Evap1, T: 13.40 µK, N: 1.37e+05, PSD: 4.22e-05, BEC fraction: 0.00%
# Time: 445.5 ms, Stage: Evap2, T: 13.39 µK, N: 1.36e+05, PSD: 4.20e-05, BEC fraction: 0.00%
# Time: 457.6 ms, Stage: Evap2, T: 13.39 µK, N: 1.36e+05, PSD: 4.18e-05, BEC fraction: 0.00%
# Time: 469.1 ms, Stage: Evap3, T: 13.39 µK, N: 1.36e+05, PSD: 4.16e-05, BEC fraction: 0.00%
# Time: 480.6 ms, Stage: Evap3, T: 13.39 µK, N: 1.36e+05, PSD: 4.14e-05, BEC fraction: 0.00%
# Time: 492.7 ms, Stage: Evap3, T: 13.38 µK, N: 1.36e+05, PSD: 4.12e-05, BEC fraction: 0.00%
# Time: 504.2 ms, Stage: Evap4, T: 13.38 µK, N: 1.36e+05, PSD: 4.11e-05, BEC fraction: 0.00%
# Time: 516.3 ms, Stage: Evap4, T: 13.37 µK, N: 1.36e+05, PSD: 4.09e-05, BEC fraction: 0.00%
# Time: 527.8 ms, Stage: Evap5, T: 13.36 µK, N: 1.36e+05, PSD: 4.08e-05, BEC fraction: 0.00%
# Time: 539.3 ms, Stage: Evap5, T: 13.35 µK, N: 1.36e+05, PSD: 4.06e-05, BEC fraction: 0.00%
# Time: 551.4 ms, Stage: Evap6, T: 13.34 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 562.9 ms, Stage: Evap6, T: 13.32 µK, N: 1.36e+05, PSD: 4.05e-05, BEC fraction: 0.00%
# Time: 575.0 ms, Stage: Evap6, T: 13.30 µK, N: 1.36e+05, PSD: 4.04e-05, BEC fraction: 0.00%
